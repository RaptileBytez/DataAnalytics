# %% [markdown]
# # Practicing Python Collections

# %%
import json

# %%
with open('../../data/players_data.json') as fp:
    players = json.load(fp)

# %%
columns = [
    'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP', 'Starts', 'Min', 'Goals', 'Shots', 'SoT', 'Assists'
]

# %% [markdown]
# Get the details of first player

# %%
print(players[0])
# Out:
# ['Brenden Aaronson', 'USA', 'MFFW', 'Leeds United', 'Premier League', 22, 2000, 20, 19, 1596, 1, 1.53, 0.28, 0.11]

# %% [markdown]
# The list is ['Brenden Aaronson', 'USA', 'MFFW', 'Leeds United', 'Premier League', 22, 2000, 20, 19, 1596, 1, 1.53, 0.28, 0.11] The details for the player "Brenden Aaronson" are as follows:
# | Number | Field | Information | Comment |
# |--------|-------|-------------|---------|
# |1.  | Player | Brenden Aaronson |        # Name of the player |
# |2.  | Nation | USA              |       # Nationality of the player |
# |3.  | Pos | MFFW                |       # Position of the player |
# |4.  | Squad | Leeds United      |       # Club/Squad of the player |
# |5.  | Comp | Premier League     |       # Competition of the player |
# |6.  | Age | 22                  |       # Age of the player |
# |7.  | Born | 2000               |       # Birth year of the player |
# |8.  | MP | 20                   |       # Matches Played |
# |9.  | Starts | 19               |       # Matches Started |
# |10. | Min | 1596                |      # Minutes Played |
# |11. | Goals | 1                 |      # Goals Scored |
# |12. | Shots | 1.53              |      # Shots per 90 minutes |
# |13. | SoT | 0.28                |      # Shots on Target per 90 minutes |
# |14. | Assists | 0.11            |      # Assists per 90 minutes |
#
# Similarly, the other entries in the list follow the same format, providing information about different players and their performance statistics.

# %% [markdown]
# ## Analytical Questions

# %% [markdown]
# ### 1. Who's the player with most assist in the Premier League?
# Find the player with the highest number of assists that played AT LEAST1000 minutes. The assists value is computed "per minute". Provide the full name of the player, followed by their assists number. Only consider players who have played at least 1000 minutes.

# %%
top_player = ""
assist_stat = 0
for player in players:
    if player[4] == 'Premier League' and player[9] > 1000 and player[13] > assist_stat:
        top_player = player[0]
        assist_stat = player[13]
top_player, assist_stat
# Out:
# ('Kevin De Bruyne', 0.62)

# %% [markdown]
# ### 2. Find the player with the highest goals-to-shots ratio in the Premier League. Only consider players who have taken at least 10 shots.
#
# Only consider players:
#
# - who have taken at least 10 shots per 90 minutes( as shots per 90 minutes is a normalized value, it is not the total number of shots taken by the player in the season so, we need to consider only those players who have taken at least 10 shots per 90 minutes not the total number of shots taken by the player in the season)
# - played in the Premier League

# %%
top_player = ""
top_ratio = 0
for player in players:
    name = player[0]
    comp = player[4]
    shots = player[11]
    goals = player[10]
    if comp == 'Premier League' and shots >= 10:
        print(name, comp, shots, goals)
        try:
            ratio = goals / shots
        except ZeroDivisionError:
            ratio = 0
            
        if ratio > top_ratio:
            top_ratio = ratio
            top_player = name
top_player, top_ratio
# Out:
# Nathaniel Chalobah Premier League 10.0 0
# Halil Derviþoðlu Premier League 10.0 0
# João Gomes Premier League 10.0 1
# Darko Gyabi Premier League 10.0 0
# Djed Spence Premier League 10.0 0
# ('João Gomes', 0.1)

# %% [markdown]
# ### 3. Determine the average age of players in each squad.
#
# Create a dictionary named average_age_per_squad where the keys are the squad names, and the values are the average ages rounded to the nearest whole number.

# %%
squad_age_count = {}

for player in players:
    squad_name = player[3]
    age = player[5]
    if squad_name not in squad_age_count:
        squad_age_count[squad_name] = {'sum_age': age, 'count': 1}
    else:
        squad_age_count[squad_name]['sum_age'] += age
        squad_age_count[squad_name]['count'] += 1

average_age_per_squad = {key : round(values['sum_age'] / values['count']) for key, values in squad_age_count.items()}
average_age_per_squad
# Out:
# {'Leeds United': 25,
#  'Reims': 23,
#  'Angers': 26,
#  'Lens': 26,
#  'Lorient': 24,
#  'Hellas Verona': 25,
#  'Auxerre': 27,
#  'Rennes': 24,
#  'Betis': 28,
#  'Toulouse': 24,
#  'Roma': 26,
#  'Inter': 28,
#  'Nantes': 26,
#  'Sevilla': 27,
#  'Southampton': 25,
#  'Köln': 25,
#  'Fulham': 27,
#  'Dortmund': 25,
#  'Leverkusen': 25,
#  'Milan': 26,
#  'Bologna': 26,
#  'Cremonese': 26,
#  'Troyes': 25,
#  'Werder Bremen': 26,
#  'Valladolid': 27,
#  'Spezia': 25,
#  'West Ham': 27,
#  'Monaco': 24,
#  'Crystal Palace': 26,
#  'Stuttgart': 24,
#  'Strasbourg': 26,
#  'Celta Vigo': 26,
#  'Torino': 24,
#  'Wolves': 26,
#  'Brentford': 25,
#  'Mainz 05': 25,
#  'Manchester City': 26,
#  'Almería': 26,
#  'Empoli': 24,
#  'Hoffenheim': 25,
#  'Real Madrid': 28,
#  'Cádiz': 28,
#  'Eint Frankfurt': 26,
#  'Barcelona': 26,
#  'Lazio': 27,
#  'Villarreal': 27,
#  'Leicester City': 26,
#  'Liverpool': 26,
#  'Getafe': 27,
#  'Elche': 28,
#  'Real Sociedad': 24,
#  'Clermont Foot': 27,
#  'Everton': 26,
#  'Valencia': 24,
#  'Newcastle Utd': 27,
#  'Ajaccio': 27,
#  'Schalke 04': 27,
#  'Sassuolo': 25,
#  'Athletic Club': 28,
#  'Mallorca': 28,
#  'Sampdoria': 27,
#  'Fiorentina': 26,
#  'Lille': 25,
#  'Bournemouth': 26,
#  'Manchester Utd': 26,
#  'Monza': 27,
#  'Bochum': 28,
#  'Lyon': 26,
#  'Aston Villa': 27,
#  'Brest': 26,
#  'Wolfsburg': 25,
#  'Chelsea': 25,
#  'Udinese': 26,
#  'Lecce': 25,
#  'Nice': 25,
#  "Nott'ham Forest": 27,
#  'Osasuna': 28,
#  'RB Leipzig': 26,
#  'Marseille': 26,
#  'Rayo Vallecano': 28,
#  'Espanyol': 25,
#  'Atlético Madrid': 28,
#  'Augsburg': 25,
#  'Union Berlin': 27,
#  "M'Gladbach": 26,
#  'Tottenham': 26,
#  'Paris S-G': 25,
#  'Bayern Munich': 26,
#  'Hertha BSC': 27,
#  'Atalanta': 26,
#  'Salernitana': 27,
#  'Juventus': 27,
#  'Girona': 26,
#  'Brighton': 25,
#  'Montpellier': 25,
#  'Napoli': 26,
#  'Freiburg': 26,
#  'Arsenal': 25}

# %% [markdown]
# ### 4. Which player has the highest playing time in the Premier League?
#
# Find the player who has played the most minutes in Premier League.

# %%
player_most_played = None
max_play_time = 0
for player in players:
    name = player[0]
    time = player[9]
    corp = player[4]
    if corp != 'Premier League':
        continue
    else:
        if time > max_play_time:
            max_play_time = time
            player_most_played = name
player_most_played
# Out:
# 'Tim Ream'

# %% [markdown]
# ### 5. What is the highest number of minutes played by a player in La Liga?
#
# Find the maximum minutes played in La Liga. Here La Liga is the Premier League/Comeptition name.

# %%
max_time = 0
for player in players:
    corp = player[4]
    time_played = player[9]
    if corp != 'La Liga':
        continue
    else:
        if time_played > max_time:
            max_time = time_played
max_time
# Out:
# 1890

# %% [markdown]
# ### 6. Which team, on average, scores the highest number of goals per game in the Bundesliga?
#
# Consider only teams that:
#
# - where players have played at least 10 matches
# - are in the Bundesliga competition.
#
# Average Goals per Game is defined as: the total goals scored divided by the number of games played by the team.
#
# Find the highest average goals per game and the name of the team which scored the highest goals per game

# %%
qualified_teams = {}
for player in players:
    squad_name = player[3]  # Index 3 corresponds to the 'Squad' column
    matches_played = player[7]  # Index 7 corresponds to the 'MP' column
    goals_scored = player[10]  # Index 10 corresponds to the 'Goals' column

    if player[4] == 'Bundesliga' and matches_played >= 10:
        if squad_name in qualified_teams:
            qualified_teams[squad_name]['matches_played'] += matches_played
            qualified_teams[squad_name]['goals_scored'] += goals_scored
        else:
            qualified_teams[squad_name] = {'matches_played': matches_played, 'goals_scored': goals_scored}

# Calculate the average goals per game for each qualified team
average_goals_per_game = {
    squad: data['goals_scored'] / data['matches_played'] for squad, data in qualified_teams.items()
}

# Find the team with the highest average goals per game
highest_average_goals = max(average_goals_per_game.values())
highest_average_goals_team = [squad for squad, avg_goals in average_goals_per_game.items() if avg_goals == highest_average_goals][0]

print("Highest Average Goals Per Game:", highest_average_goals)
print("Team with Highest Average Goals Per Game:", highest_average_goals_team)
# Out:
# Highest Average Goals Per Game: 0.20863309352517986
# Team with Highest Average Goals Per Game: Bayern Munich

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### 7. Transform the list of lists into a list of dictionaries
#
# Create a new variable named players_dict that contains ALL the players but each player represented as a dictionary, containing only the keys:
#
# - player
# - nation
# - position
# - squad
# - competition
# - age
#
# The resulting variable should have this structure:
# <code>
# [{'player': 'Brenden Aaronson',
#   'nation': 'USA',
#   'position': 'MFFW',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Yunis Abdelhamid',
#   'nation': 'MAR',
#   'position': 'DF',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 35}]
# </code>

# %%
players_dict = []
for player in players:
    player_data = {
        'player': player[0],       # Index 0 corresponds to the 'Player' column
        'nation': player[1],       # Index 1 corresponds to the 'Nation' column
        'position': player[2],     # Index 2 corresponds to the 'Pos' column
        'squad': player[3],        # Index 3 corresponds to the 'Squad' column
        'competition': player[4],  # Index 4 corresponds to the 'Comp' column
        'age': player[5],          # Index 5 corresponds to the 'Age' column
    }
    players_dict.append(player_data)

players_dict
# Out:
# [{'player': 'Brenden Aaronson',
#   'nation': 'USA',
#   'position': 'MFFW',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Yunis Abdelhamid',
#   'nation': 'MAR',
#   'position': 'DF',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 35},
#  {'player': 'Himad Abdelli',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Salis Abdul Samed',
#   'nation': 'GHA',
#   'position': 'MF',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Laurent Abergel',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Lorient',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'Oliver Abildgaard',
#   'nation': 'DEN',
#   'position': 'MF',
#   'squad': 'Hellas Verona',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Matthis Abline',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Auxerre',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Matthis Abline',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Abner',
#   'nation': 'BRA',
#   'position': 'DF',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Zakaria Aboukhlal',
#   'nation': 'MAR',
#   'position': 'FWMF',
#   'squad': 'Toulouse',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Tammy Abraham',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Roma',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Francesco Acerbi',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 35},
#  {'player': 'Mohamed Achi',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Nantes',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Marcos Acuña',
#   'nation': 'ARG',
#   'position': 'DF',
#   'squad': 'Sevilla',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Che Adams',
#   'nation': 'SCO',
#   'position': 'FW',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Tyler Adams',
#   'nation': 'USA',
#   'position': 'MF',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Sargis Adamyan',
#   'nation': 'ARM',
#   'position': 'FWMF',
#   'squad': 'Köln',
#   'competition': 'Bundesliga',
#   'age': 29},
#  {'player': 'Tosin Adarabioyo',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Fulham',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Martin Adeline',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Karim Adeyemi',
#   'nation': 'GER',
#   'position': 'FWMF',
#   'squad': 'Dortmund',
#   'competition': 'Bundesliga',
#   'age': 21},
#  {'player': 'Amine Adli',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 22},
#  {'player': 'Yacine Adli',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Milan',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Michel Aebischer',
#   'nation': 'SUI',
#   'position': 'FWMF',
#   'squad': 'Bologna',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Felix Afena-Gyan',
#   'nation': 'GHA',
#   'position': 'FWMF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Emmanuel Agbadou',
#   'nation': 'CIV',
#   'position': 'DF',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Lucien Agoume',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Troyes',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Felix Agu',
#   'nation': 'GER',
#   'position': 'DFFW',
#   'squad': 'Werder Bremen',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Álvaro Aguado',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Kevin Agudelo',
#   'nation': 'COL',
#   'position': 'MFFW',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Nayef Aguerd',
#   'nation': 'MAR',
#   'position': 'DF',
#   'squad': 'West Ham',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Ruben Aguilar',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Naouirou Ahamada',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Crystal Palace',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Naouirou Ahamada',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Stuttgart',
#   'competition': 'Bundesliga',
#   'age': 20},
#  {'player': 'Amar Ahmed',
#   'nation': 'SWE',
#   'position': 'FW',
#   'squad': 'Troyes',
#   'competition': 'Ligue 1',
#   'age': 18},
#  {'player': 'Jean-Eudes Aholou',
#   'nation': 'CIV',
#   'position': 'MF',
#   'squad': 'Strasbourg',
#   'competition': 'Ligue 1',
#   'age': 28},
#  {'player': 'Joseph Aidoo',
#   'nation': 'GHA',
#   'position': 'DF',
#   'squad': 'Celta Vigo',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Ola Aina',
#   'nation': 'NGA',
#   'position': 'DF',
#   'squad': 'Torino',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Rayan Aït Nouri',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Wolves',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Emanuel Aiwum',
#   'nation': 'AUT',
#   'position': 'DF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Kristoffer Ajer',
#   'nation': 'NOR',
#   'position': 'DF',
#   'squad': 'Brentford',
#   'competition': 'Premier League',
#   'age': 24},
#  {'player': 'Ludovic Ajorque',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Strasbourg',
#   'competition': 'Ligue 1',
#   'age': 28},
#  {'player': 'Ludovic Ajorque',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Mainz 05',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Manuel Akanji',
#   'nation': 'SUI',
#   'position': 'DF',
#   'squad': 'Manchester City',
#   'competition': 'Premier League',
#   'age': 27},
#  {'player': 'Nathan Aké',
#   'nation': 'NED',
#   'position': 'DF',
#   'squad': 'Manchester City',
#   'competition': 'Premier League',
#   'age': 27},
#  {'player': 'Sergio Akieme',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Almería',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Maghnes Akliouche',
#   'nation': 'FRA',
#   'position': 'MFDF',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Paul Akouokou',
#   'nation': 'CIV',
#   'position': 'MF',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Jean-Daniel Akpa-Akpro',
#   'nation': 'CIV',
#   'position': 'MF',
#   'squad': 'Empoli',
#   'competition': 'Serie A',
#   'age': 30},
#  {'player': 'Kevin Akpoguma',
#   'nation': 'NGA',
#   'position': 'DF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'David Alaba',
#   'nation': 'AUT',
#   'position': 'DF',
#   'squad': 'Real Madrid',
#   'competition': 'La Liga',
#   'age': 30},
#  {'player': 'Tomás Alarcón',
#   'nation': 'CHI',
#   'position': 'MF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 24},
#  {'player': 'Lucas Alario',
#   'nation': 'ARG',
#   'position': 'FW',
#   'squad': 'Eint Frankfurt',
#   'competition': 'Bundesliga',
#   'age': 30},
#  {'player': 'Jordi Alba',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 33},
#  {'player': 'Luis Alberto',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Lazio',
#   'competition': 'Serie A',
#   'age': 30},
#  {'player': 'Raúl Albiol',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Villarreal',
#   'competition': 'La Liga',
#   'age': 37},
#  {'player': 'Marc Albrighton',
#   'nation': 'ENG',
#   'position': 'FWMF',
#   'squad': 'Leicester City',
#   'competition': 'Premier League',
#   'age': 33},
#  {'player': 'Thiago Alcántara',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 31},
#  {'player': 'Carlos Alcaraz',
#   'nation': 'ARG',
#   'position': 'MF',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Rubén Alcaraz',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Omar Alderete',
#   'nation': 'PAR',
#   'position': 'DF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Iván Alejo',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Doðan Alemdar',
#   'nation': 'TUR',
#   'position': 'GK',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Carles Aleñá',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Trent Alexander-Arnold',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 24},
#  {'player': 'Alejandro Alfaro',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 20},
#  {'player': 'Ángel Algobia',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 23},
#  {'player': 'Mohamed Ali Cho',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Real Sociedad',
#   'competition': 'La Liga',
#   'age': 19},
#  {'player': 'Faride Alidou',
#   'nation': 'GER',
#   'position': 'DFMF',
#   'squad': 'Eint Frankfurt',
#   'competition': 'Bundesliga',
#   'age': 21},
#  {'player': 'Alisson',
#   'nation': 'BRA',
#   'position': 'GK',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 30},
#  {'player': 'Jim Allevinah',
#   'nation': 'GAB',
#   'position': 'DFFW',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 27},
#  {'player': 'Dele Alli',
#   'nation': 'ENG',
#   'position': 'MF',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Domingos André Ribeiro Almeida',
#   'nation': 'POR',
#   'position': 'MF',
#   'squad': 'Valencia',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Miguel Almirón',
#   'nation': 'PAR',
#   'position': 'FW',
#   'squad': 'Newcastle Utd',
#   'competition': 'Premier League',
#   'age': 29},
#  {'player': 'Marcos Alonso',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 32},
#  {'player': 'Mickaël Alphonse',
#   'nation': 'GLP',
#   'position': 'DF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 33},
#  {'player': 'Éder Álvarez Balanta',
#   'nation': 'COL',
#   'position': 'MF',
#   'squad': 'Schalke 04',
#   'competition': 'Bundesliga',
#   'age': 29},
#  {'player': 'Carlos Álvarez',
#   'nation': 'ESP',
#   'position': 'FW',
#   'squad': 'Sevilla',
#   'competition': 'La Liga',
#   'age': 19},
#  {'player': 'Gastón Álvarez',
#   'nation': 'URU',
#   'position': 'DF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Julián Álvarez',
#   'nation': 'ARG',
#   'position': 'FWMF',
#   'squad': 'Manchester City',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Agustín Álvarez Martínez',
#   'nation': 'URU',
#   'position': 'FWMF',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 21},
#  {'player': 'Yeray Álvarez',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Ibrahim Amadou',
#   'nation': 'FRA',
#   'position': 'DFMF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Daniel Amartey',
#   'nation': 'GHA',
#   'position': 'DF',
#   'squad': 'Leicester City',
#   'competition': 'Premier League',
#   'age': 28},
#  {'player': 'Amath',
#   'nation': 'SEN',
#   'position': 'MFFW',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Jordan Amavi',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Kelvin Amian',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Bruno Amione',
#   'nation': 'ARG',
#   'position': 'DF',
#   'squad': 'Hellas Verona',
#   'competition': 'Serie A',
#   'age': 21},
#  {'player': 'Bruno Amione',
#   'nation': 'ARG',
#   'position': 'DF',
#   'squad': 'Sampdoria',
#   'competition': 'Serie A',
#   'age': 21},
#  {'player': 'Nadiem Amiri',
#   'nation': 'GER',
#   'position': 'MFFW',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Ethan Ampadu',
#   'nation': 'WAL',
#   'position': 'DFMF',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Sofyan Amrabat',
#   'nation': 'MAR',
#   'position': 'MF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Joachim Andersen',
#   'nation': 'DEN',
#   'position': 'DF',
#   'squad': 'Crystal Palace',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Elliot Anderson',
#   'nation': 'SCO',
#   'position': 'FWMF',
#   'squad': 'Newcastle Utd',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Felipe Anderson',
#   'nation': 'BRA',
#   'position': 'FW',
#   'squad': 'Lazio',
#   'competition': 'Serie A',
#   'age': 29},
#  {'player': 'Benjamin André',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Lille',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Komnen Andri?',
#   'nation': 'SRB',
#   'position': 'FW',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 27},
#  {'player': 'Robert Andrich',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Angeliño',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Fabrizio Angileri',
#   'nation': 'ARG',
#   'position': 'DF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Jaidon Anthony',
#   'nation': 'ENG',
#   'position': 'MFFW',
#   'squad': 'Bournemouth',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Janis Antiste',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Waldemar Anton',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Stuttgart',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Marcos Antônio',
#   'nation': 'BRA',
#   'position': 'MF',
#   'squad': 'Lazio',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Michail Antonio',
#   'nation': 'JAM',
#   'position': 'FW',
#   'squad': 'West Ham',
#   'competition': 'Premier League',
#   'age': 32},
#  {'player': 'Antony',
#   'nation': 'BRA',
#   'position': 'FW',
#   'squad': 'Manchester Utd',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Valentin Antov',
#   'nation': 'BUL',
#   'position': 'DF',
#   'squad': 'Monza',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Christopher Antwi-Adjei',
#   'nation': 'GHA',
#   'position': 'FWMF',
#   'squad': 'Bochum',
#   'competition': 'Bundesliga',
#   'age': 29},
#  {'player': 'Anuar',
#   'nation': 'MAR',
#   'position': 'MFFW',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Houssem Aouar',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Lyon',
#   'competition': 'Ligue 1',
#   'age': 24},
#  {'player': 'Adil Aouchiche',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Lorient',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Dennis Appiah',
#   'nation': 'FRA',
#   'position': 'DFMF',
#   'squad': 'Nantes',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'Mauro Arambarri',
#   'nation': 'URU',
#   'position': 'MF',
#   'squad': 'Getafe',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Charles Aránguiz',
#   'nation': 'CHI',
#   'position': 'MF',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 33},
#  {'player': 'Ronald Araújo',
#   'nation': 'URU',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 23},
#  {'player': 'Cameron Archer',
#   'nation': 'ENG',
#   'position': 'FWMF',
#   'squad': 'Aston Villa',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Taïryk Arconte',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Alphonse Areola',
#   'nation': 'FRA',
#   'position': 'GK',
#   'squad': 'West Ham',
#   'competition': 'Premier League',
#   'age': 29},
#  {'player': 'Joe Aribo',
#   'nation': 'NGA',
#   'position': 'MFFW',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Adam Armstrong',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Stuart Armstrong',
#   'nation': 'SCO',
#   'position': 'MFFW',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 30},
#  {'player': 'Marko Arnautovi?',
#   'nation': 'AUT',
#   'position': 'FW',
#   'squad': 'Bologna',
#   'competition': 'Serie A',
#   'age': 33},
#  {'player': 'Maximilian Arnold',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Kepa Arrizabalaga',
#   'nation': 'ESP',
#   'position': 'GK',
#   'squad': 'Chelsea',
#   'competition': 'Premier League',
#   'age': 28},
#  {'player': 'Roberto Arroyo',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 19},
#  {'player': 'Tolgay Arslan',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Udinese',
#   'competition': 'Serie A',
#   'age': 32},
#  {'player': 'Arthur',
#   'nation': 'BRA',
#   'position': 'FW',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Santiago Arzamendia',
#   'nation': 'PAR',
#   'position': 'MFDF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 24},
#  {'player': 'Takuma Asano',
#   'nation': 'JPN',
#   'position': 'FWMF',
#   'squad': 'Bochum',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Santiago Ascacíbar',
#   'nation': 'ARG',
#   'position': 'MF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Sergio Asenjo',
#   'nation': 'ESP',
#   'position': 'GK',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 33},
#  {'player': 'Marco Asensio',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Real Madrid',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Kristoffer Askildsen',
#   'nation': 'NOR',
#   'position': 'MF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Fisnik Asllani',
#   'nation': 'KVX',
#   'position': 'FWMF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 20},
#  {'player': 'Kristjan Asllani',
#   'nation': 'ALB',
#   'position': 'MF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Iago Aspas',
#   'nation': 'ESP',
#   'position': 'FW',
#   'squad': 'Celta Vigo',
#   'competition': 'La Liga',
#   'age': 35},
#  {'player': 'Lorenz Assignon',
#   'nation': 'TOG',
#   'position': 'DF',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Youcef Atal',
#   'nation': 'ALG',
#   'position': 'DFMF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Pierre-Emerick Aubameyang',
#   'nation': 'GAB',
#   'position': 'FW',
#   'squad': 'Chelsea',
#   'competition': 'Premier League',
#   'age': 33},
#  {'player': 'Pierre-Emerick Aubameyang',
#   'nation': 'GAB',
#   'position': 'FW',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 33},
#  {'player': 'Emil Audero',
#   'nation': 'ITA',
#   'position': 'GK',
#   'squad': 'Sampdoria',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Tommaso Augello',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Sampdoria',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Ludwig Augustinsson',
#   'nation': 'SWE',
#   'position': 'DF',
#   'squad': 'Aston Villa',
#   'competition': 'Premier League',
#   'age': 28},
#  {'player': 'Ludwig Augustinsson',
#   'nation': 'SWE',
#   'position': 'DF',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Serge Aurier',
#   'nation': 'CIV',
#   'position': 'DF',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 30},
#  {'player': 'Mathias Autret',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Auxerre',
#   'competition': 'Ligue 1',
#   'age': 31},
#  {'player': 'Ezequiel Ávila',
#   'nation': 'ARG',
#   'position': 'FWMF',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 29},
#  {'player': 'Cédric Avinel',
#   'nation': 'GLP',
#   'position': 'DF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 36},
#  {'player': 'Taiwo Awoniyi',
#   'nation': 'NGA',
#   'position': 'FW',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Mehmet-Can Aydin',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Schalke 04',
#   'competition': 'Bundesliga',
#   'age': 21},
#  {'player': 'André Ayew',
#   'nation': 'GHA',
#   'position': 'FW',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 33},
#  {'player': 'Jordan Ayew',
#   'nation': 'GHA',
#   'position': 'FWMF',
#   'squad': 'Crystal Palace',
#   'competition': 'Premier League',
#   'age': 31},
#  {'player': 'Kaan Ayhan',
#   'nation': 'TUR',
#   'position': 'DF',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Luke Ayling',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 31},
#  {'player': 'Ayman Azhil',
#   'nation': 'MAR',
#   'position': 'MF',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 21},
#  {'player': 'Sardar Azmoun',
#   'nation': 'IRN',
#   'position': 'MFFW',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'César Azpilicueta',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Chelsea',
#   'competition': 'Premier League',
#   'age': 33},
#  {'player': 'Sanoussy Ba',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'RB Leipzig',
#   'competition': 'Bundesliga',
#   'age': 19},
#  {'player': 'Iddrisu Baba',
#   'nation': 'GHA',
#   'position': 'MF',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Sr?an Babi?',
#   'nation': 'SRB',
#   'position': 'DF',
#   'squad': 'Almería',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Loïc Bade',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Sevilla',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Loïc Bade',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Édgar Badía',
#   'nation': 'ESP',
#   'position': 'GK',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Benoît Badiashile',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Chelsea',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Benoît Badiashile',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Alex Baena',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Villarreal',
#   'competition': 'La Liga',
#   'age': 21},
#  {'player': 'Jaime Báez',
#   'nation': 'URU',
#   'position': 'DF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 27},
#  {'player': 'Leon Bailey',
#   'nation': 'JAM',
#   'position': 'FWMF',
#   'squad': 'Aston Villa',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Eric Bailly',
#   'nation': 'CIV',
#   'position': 'DF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 28},
#  {'player': 'Dénys Bain',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Auxerre',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Brandon Baiye',
#   'nation': 'BEL',
#   'position': 'MF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Stefan Bajcetic',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 18},
#  {'player': 'Nedim Bajrami',
#   'nation': 'ALB',
#   'position': 'MFFW',
#   'squad': 'Empoli',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Nedim Bajrami',
#   'nation': 'ALB',
#   'position': 'MF',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Cédric Bakambu',
#   'nation': 'COD',
#   'position': 'MF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 31},
#  {'player': 'Mitchel Bakker',
#   'nation': 'NED',
#   'position': 'MFDF',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 22},
#  {'player': 'Ridle Baku',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Tommaso Baldanzi',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Empoli',
#   'competition': 'Serie A',
#   'age': 19},
#  {'player': 'Alejandro Balde',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 19},
#  {'player': 'Thierno Balde',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Troyes',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Carlos Baleba',
#   'nation': 'CMR',
#   'position': 'MF',
#   'squad': 'Lille',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Mikel Balenziaga',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 34},
#  {'player': 'Leonardo Balerdi',
#   'nation': 'ARG',
#   'position': 'DF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 24},
#  {'player': 'Iván Balliu',
#   'nation': 'ALB',
#   'position': 'DF',
#   'squad': 'Rayo Vallecano',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Fodé Ballo-Touré',
#   'nation': 'SEN',
#   'position': 'DF',
#   'squad': 'Milan',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Folarin Balogun',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Abdoulaye Bamba',
#   'nation': 'CIV',
#   'position': 'DF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Jonathan Bamba',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Lille',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Patrick Bamford',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 29},
#  {'player': 'Lameck Banda',
#   'nation': 'ZAM',
#   'position': 'FWMF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Filippo Bandinelli',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Empoli',
#   'competition': 'Serie A',
#   'age': 27},
#  {'player': 'Léo Baptistão',
#   'nation': 'BRA',
#   'position': 'FWMF',
#   'squad': 'Almería',
#   'competition': 'La Liga',
#   'age': 30},
#  {'player': 'Shandon Baptiste',
#   'nation': 'GRN',
#   'position': 'MF',
#   'squad': 'Brentford',
#   'competition': 'Premier League',
#   'age': 24},
#  {'player': 'Antonín Barák',
#   'nation': 'CZE',
#   'position': 'MF',
#   'squad': 'Hellas Verona',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Antonín Barák',
#   'nation': 'CZE',
#   'position': 'MF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Andrea Barberis',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Monza',
#   'competition': 'Serie A',
#   'age': 29},
#  {'player': 'Bradley Barcola',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Lyon',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Melvin Bard',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Keidi Bare',
#   'nation': 'ALB',
#   'position': 'MF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Nicolò Barella',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Kike Barja',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Ross Barkley',
#   'nation': 'ENG',
#   'position': 'FWMF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Aymen Barkok',
#   'nation': 'MAR',
#   'position': 'MF',
#   'squad': 'Mainz 05',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Harvey Barnes',
#   'nation': 'ENG',
#   'position': 'MFFW',
#   'squad': 'Leicester City',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Leandro Barreiro Martins',
#   'nation': 'LUX',
#   'position': 'MF',
#   'squad': 'Mainz 05',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Ander Barrenetxea',
#   'nation': 'ESP',
#   'position': 'FWDF',
#   'squad': 'Real Sociedad',
#   'competition': 'La Liga',
#   'age': 21},
#  {'player': 'Mickaël Barreto',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Pablo Barrios',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Atlético Madrid',
#   'competition': 'La Liga',
#   'age': 19},
#  {'player': 'Musa Barrow',
#   'nation': 'GAM',
#   'position': 'FWMF',
#   'squad': 'Bologna',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Federico Baschirotto',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Toma Ba\x9ai?',
#   'nation': 'CRO',
#   'position': 'MF',
#   'squad': 'Lazio',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Gil Bastião Dias',
#   'nation': 'POR',
#   'position': 'FW',
#   'squad': 'Stuttgart',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Alessandro Bastoni',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Simone Bastoni',
#   'nation': 'ITA',
#   'position': 'MFDF',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Rodrigo Battaglia',
#   'nation': 'ARG',
#   'position': 'MF',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Maximilian Bauer',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Oliver Baumann',
#   'nation': 'GER',
#   'position': 'GK',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 32},
#  {'player': 'Timo Baumgartl',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Union Berlin',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Julian Baumgartlinger',
#   'nation': 'AUT',
#   'position': 'MF',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 35},
#  {'player': 'Christoph Baumgartner',
#   'nation': 'AUT',
#   'position': 'MFFW',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Cyrille Bayala',
#   'nation': 'BFA',
#   'position': 'MF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Brian Bayeye',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Torino',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Noah Joel Sarenren Bazee',
#   'nation': 'NGA',
#   'position': 'FW',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Gavin Bazunu',
#   'nation': 'IRL',
#   'position': 'GK',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Bebé',
#   'nation': 'CPV',
#   'position': 'FW',
#   'squad': 'Rayo Vallecano',
#   'competition': 'La Liga',
#   'age': 32},
#  {'player': 'Ihlas Bebou',
#   'nation': 'TOG',
#   'position': 'FWDF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Rodrigo Becão',
#   'nation': 'BRA',
#   'position': 'DF',
#   'squad': 'Udinese',
#   'competition': 'Serie A',
#   'age': 27},
#  {'player': 'Mads Bech Sørensen',
#   'nation': 'DEN',
#   'position': 'DFMF',
#   'squad': 'Brentford',
#   'competition': 'Premier League',
#   'age': 24},
#  {'player': 'Julius Beck',
#   'nation': 'DEN',
#   'position': 'MF',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 17},
#  {'player': 'Sheraldo Becker',
#   'nation': 'SUR',
#   'position': 'FW',
#   'squad': 'Union Berlin',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Jan Bednarek',
#   'nation': 'POL',
#   'position': 'DF',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Jan Bednarek',
#   'nation': 'POL',
#   'position': 'DF',
#   'squad': 'Aston Villa',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Donny van de Beek',
#   'nation': 'NED',
#   'position': 'MF',
#   'squad': 'Manchester Utd',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Asmir Begovi?',
#   'nation': 'BIH',
#   'position': 'GK',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 35},
#  {'player': 'Yanis Begraoui',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Toulouse',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Kevin Behrens',
#   'nation': 'GER',
#   'position': 'FW',
#   'squad': 'Union Berlin',
#   'competition': 'Bundesliga',
#   'age': 32},
#  {'player': 'Alexis Beka Beka',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Jérémie Bela',
#   'nation': 'ANG',
#   'position': 'DFMF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Youcef Belaïli',
#   'nation': 'ALG',
#   'position': 'MFFW',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'Youcef Belaïli',
#   'nation': 'ALG',
#   'position': 'FWMF',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'Haris Belkebla',
#   'nation': 'ALG',
#   'position': 'MF',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Stefan Bell',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Mainz 05',
#   'competition': 'Bundesliga',
#   'age': 31},
#  {'player': 'Armel Bella Kotchap',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Raoul Bellanova',
#   'nation': 'ITA',
#   'position': 'DFMF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Karim Bellarabi',
#   'nation': 'GER',
#   'position': 'FW',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 32},
#  {'player': 'Jean-Ricner Bellegarde',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Strasbourg',
#   'competition': 'Ligue 1',
#   'age': 24},
#  {'player': 'Héctor Bellerín',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Jude Bellingham',
#   'nation': 'ENG',
#   'position': 'MF',
#   'squad': 'Dortmund',
#   'competition': 'Bundesliga',
#   'age': 19},
#  {'player': 'Jeanöel Belocian',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 17},
#  {'player': 'Andrea Belotti',
#   'nation': 'ITA',
#   'position': 'FW',
#   'squad': 'Roma',
#   'competition': 'Serie A',
#   'age': 29},
#  {'player': 'Fran Beltrán',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Celta Vigo',
#   'competition': 'La Liga',
#   'age': 24},
#  {'player': 'Eliesse Ben Seghir',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 17},
#  {'player': 'Salim Ben Seghir',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Wissam Ben Yedder',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Marco Benassi',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Marco Benassi',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Ismaël Bennacer',
#   'nation': 'ALG',
#   'position': 'MF',
#   'squad': 'Milan',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Saïd Benrahma',
#   'nation': 'ALG',
#   'position': 'FWMF',
#   'squad': 'West Ham',
#   'competition': 'Premier League',
#   'age': 27},
#  {'player': 'Ramy Bensebaini',
#   'nation': 'ALG',
#   'position': 'DF',
#   'squad': "M'Gladbach",
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'Nabil Bentaleb',
#   'nation': 'ALG',
#   'position': 'MF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 28},
#  {'player': 'Rodrigo Bentancur',
#   'nation': 'URU',
#   'position': 'MF',
#   'squad': 'Tottenham',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Karim Benzema',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Real Madrid',
#   'competition': 'La Liga',
#   'age': 35},
#  {'player': 'Domenico Berardi',
#   'nation': 'ITA',
#   'position': 'FW',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Yuri Berchiche',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 33},
#  {'player': 'Álex Berenguer',
#   'nation': 'ESP',
#   'position': 'FW',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Bartosz Bereszy?ski',
#   'nation': 'POL',
#   'position': 'DF',
#   'squad': 'Sampdoria',
#   'competition': 'Serie A',
#   'age': 30},
#  {'player': 'Patrick Berg',
#   'nation': 'NOR',
#   'position': 'MFFW',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Mitchell van Bergen',
#   'nation': 'NED',
#   'position': 'FWDF',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Mergim Berisha',
#   'nation': 'GER',
#   'position': 'FW',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Quentin Bernard',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Auxerre',
#   'competition': 'Ligue 1',
#   'age': 33},
#  {'player': 'Paul Bernardoni',
#   'nation': 'FRA',
#   'position': 'GK',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Juan Bernat',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Paris S-G',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Victor Bernth Kristiansen',
#   'nation': 'DEN',
#   'position': 'DF',
#   'squad': 'Leicester City',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Jason Berthomier',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 33},
#  {'player': 'Beto',
#   'nation': 'GNB',
#   'position': 'FW',
#   'squad': 'Udinese',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Owen Bevan',
#   'nation': 'WAL',
#   'position': 'DF',
#   'squad': 'Bournemouth',
#   'competition': 'Premier League',
#   'age': 19},
#  {'player': 'Matteo Bianchetti',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 29},
#  {'player': 'Alessandro Bianco',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Giulian Biancone',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Ermin Bi?ak?i?',
#   'nation': 'BIH',
#   'position': 'DF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 33},
#  {'player': 'Pedro Bigas',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 32},
#  {'player': 'Jaka Bijol',
#   'nation': 'SVN',
#   'position': 'DF',
#   'squad': 'Udinese',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'El Bilal Touré',
#   'nation': 'MLI',
#   'position': 'FW',
#   'squad': 'Almería',
#   'competition': 'La Liga',
#   'age': 21},
#  {'player': 'El Bilal Touré',
#   'nation': 'MLI',
#   'position': 'FW',
#   'squad': 'Reims',
#   'competition': 'Ligue 1',
#   'age': 21},
#  {'player': 'Philip Billing',
#   'nation': 'DEN',
#   'position': 'MFFW',
#   'squad': 'Bournemouth',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Jean-Claude Billong',
#   'nation': 'CMR',
#   'position': 'MF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Cristiano Biraghi',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 30},
#  {'player': 'Samuele Birindelli',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Monza',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Veljko Birman?evi?',
#   'nation': 'SRB',
#   'position': 'FWMF',
#   'squad': 'Toulouse',
#   'competition': 'Ligue 1',
#   'age': 24},
#  {'player': 'Tom Bischof',
#   'nation': 'GER',
#   'position': 'MFFW',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 17},
#  {'player': 'Yves Bissouma',
#   'nation': 'MLI',
#   'position': 'MF',
#   'squad': 'Tottenham',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Kristijan Bistrovi?',
#   'nation': 'CRO',
#   'position': 'MF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Leonardo Bittencourt',
#   'nation': 'GER',
#   'position': 'MFDF',
#   'squad': 'Werder Bremen',
#   'competition': 'Bundesliga',
#   'age': 29},
#  {'player': 'Marco Bizot',
#   'nation': 'NED',
#   'position': 'GK',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 31},
#  {'player': 'Blanco',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Lautaro Blanco',
#   'nation': 'ARG',
#   'position': 'MFDF',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 23},
#  {'player': 'Rubén Blanco',
#   'nation': 'ESP',
#   'position': 'GK',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 27},
#  {'player': 'Ludovic Blas',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Nantes',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Janis Blaswich',
#   'nation': 'GER',
#   'position': 'GK',
#   'squad': 'RB Leipzig',
#   'competition': 'Bundesliga',
#   'age': 31},
#  {'player': 'Miha Bla?i?',
#   'nation': 'SVN',
#   'position': 'DF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Joaquín Blázquez',
#   'nation': 'ARG',
#   'position': 'GK',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Alexis Blin',
#   'nation': 'FRA',
#   'position': 'MFDF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Daley Blind',
#   'nation': 'NED',
#   'position': 'MFDF',
#   'squad': 'Bayern Munich',
#   'competition': 'Bundesliga',
#   'age': 32},
#  {'player': 'Myron Boadu',
#   'nation': 'NED',
#   'position': 'FW',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Jérôme Boateng',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Lyon',
#   'competition': 'Ligue 1',
#   'age': 34},
#  {'player': 'Kevin-Prince Boateng',
#   'nation': 'GHA',
#   'position': 'MF',
#   'squad': 'Hertha BSC',
#   'competition': 'Bundesliga',
#   'age': 35},
#  {'player': 'Antonin Bobichon',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 27},
#  {'player': 'Jean-Paul Boëtius',
#   'nation': 'NED',
#   'position': 'MF',
#   'squad': 'Hertha BSC',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Jeremie Boga',
#   'nation': 'CIV',
#   'position': 'MFFW',
#   'squad': 'Atalanta',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Emil Bohinen',
#   'nation': 'NOR',
#   'position': 'MF',
#   'squad': 'Salernitana',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Quentin Boisgard',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Lorient',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Willy Boly',
#   'nation': 'CIV',
#   'position': 'DF',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 32},
#  {'player': 'Giacomo Bonaventura',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 33},
#  {'player': 'Federico Bonazzoli',
#   'nation': 'ITA',
#   'position': 'FW',
#   'squad': 'Salernitana',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Warren Bondo',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Monza',
#   'competition': 'Serie A',
#   'age': 19},
#  {'player': 'Theo Bongonda',
#   'nation': 'COD',
#   'position': 'MF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Kevin Bonifazi',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Bologna',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Leonardo Bonucci',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Juventus',
#   'competition': 'Serie A',
#   'age': 35},
#  {'player': 'Neto Borges',
#   'nation': 'BRA',
#   'position': 'DF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Yvandro Borges Sanches',
#   'nation': 'LUX',
#   'position': 'FWMF',
#   'squad': "M'Gladbach",
#   'competition': 'Bundesliga',
#   'age': 18},
#  {'player': 'Sebastiaan Bornauw',
#   'nation': 'BEL',
#   'position': 'DF',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Rafael Borré',
#   'nation': 'COL',
#   'position': 'FWMF',
#   'squad': 'Eint Frankfurt',
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'Erik Botheim',
#   'nation': 'NOR',
#   'position': 'FW',
#   'squad': 'Salernitana',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Sven Botman',
#   'nation': 'NED',
#   'position': 'DF',
#   'squad': 'Newcastle Utd',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Kenji-Van Boto',
#   'nation': 'MAD',
#   'position': 'DF',
#   'squad': 'Auxerre',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Kouamé Botué',
#   'nation': 'BFA',
#   'position': 'FWMF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 20},
#  {'player': 'Badredine Bouanani',
#   'nation': 'ALG',
#   'position': 'FWMF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 18},
#  {'player': 'Hicham Boudaoui',
#   'nation': 'ALG',
#   'position': 'MF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Franci Bouebari',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Strasbourg',
#   'competition': 'Ligue 1',
#   'age': 19},
#  {'player': 'Sofiane Boufal',
#   'nation': 'MAR',
#   'position': 'FWMF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Wassim Boullif',
#   'nation': 'ESP',
#   'position': 'DFMF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 18},
#  {'player': 'Yassine Bounou',
#   'nation': 'MAR',
#   'position': 'GK',
#   'squad': 'Sevilla',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Ismaëlben Boura',
#   'nation': 'FRA',
#   'position': 'DFFW',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Mehdi Bourabia',
#   'nation': 'MAR',
#   'position': 'MF',
#   'squad': 'Spezia',
#   'competition': 'Serie A',
#   'age': 31},
#  {'player': 'Benjamin Bourigeaud',
#   'nation': 'FRA',
#   'position': 'MFFW',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Edoardo Bove',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Roma',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Jarrod Bowen',
#   'nation': 'ENG',
#   'position': 'FWMF',
#   'squad': 'West Ham',
#   'competition': 'Premier League',
#   'age': 26},
#  {'player': 'Lucas Boyé',
#   'nation': 'ARG',
#   'position': 'FW',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Jayden Braaf',
#   'nation': 'NED',
#   'position': 'MF',
#   'squad': 'Hellas Verona',
#   'competition': 'Serie A',
#   'age': 20},
#  {'player': 'Domagoj Bradari?',
#   'nation': 'CRO',
#   'position': 'DF',
#   'squad': 'Salernitana',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Bilal Brahimi',
#   'nation': 'ALG',
#   'position': 'FWMF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Martin Braithwaite',
#   'nation': 'DEN',
#   'position': 'FWMF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Juan Brandáriz',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Almería',
#   'competition': 'La Liga',
#   'age': 23},
#  {'player': 'Julian Brandt',
#   'nation': 'GER',
#   'position': 'MFFW',
#   'squad': 'Dortmund',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Darko Bra\x9aanac',
#   'nation': 'SRB',
#   'position': 'MF',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Lilian Brassier',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Brest',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Claudio Bravo',
#   'nation': 'CHI',
#   'position': 'GK',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 39},
#  {'player': 'Fabian Bredlow',
#   'nation': 'GER',
#   'position': 'GK',
#   'squad': 'Stuttgart',
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'James Bree',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Southampton',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Josip Brekalo',
#   'nation': 'CRO',
#   'position': 'FW',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Josip Brekalo',
#   'nation': 'CRO',
#   'position': 'MFFW',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Gleison Bremer',
#   'nation': 'BRA',
#   'position': 'DF',
#   'squad': 'Juventus',
#   'competition': 'Serie A',
#   'age': 25},
#  {'player': 'Armando Broja',
# ...
#   'age': 27},
#  {'player': 'Tyrese Francois',
#   'nation': 'AUS',
#   'position': 'FW',
#   'squad': 'Fulham',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Bartol Franji?',
#   'nation': 'CRO',
#   'position': 'MF',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 23},
#  {'player': 'Przemys?aw Frankowski',
#   'nation': 'POL',
#   'position': 'DFMF',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 27},
#  {'player': 'Ryan Fraser',
#   'nation': 'SCO',
#   'position': 'FW',
#   'squad': 'Newcastle Utd',
#   'competition': 'Premier League',
#   'age': 28},
#  {'player': 'Davide Frattesi',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Sassuolo',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Fred',
#   'nation': 'BRA',
#   'position': 'MF',
#   'squad': 'Manchester Utd',
#   'competition': 'Premier League',
#   'age': 29},
#  {'player': 'Ryan Fredericks',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Bournemouth',
#   'competition': 'Premier League',
#   'age': 30},
#  {'player': 'Iván Fresneda',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 18},
#  {'player': 'Remo Freuler',
#   'nation': 'SUI',
#   'position': 'MF',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 30},
#  {'player': 'Michael Frey',
#   'nation': 'SUI',
#   'position': 'FW',
#   'squad': 'Schalke 04',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Marco Friedl',
#   'nation': 'AUT',
#   'position': 'DF',
#   'squad': 'Werder Bremen',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Marvin Friedrich',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': "M'Gladbach",
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'Jeremie Frimpong',
#   'nation': 'NED',
#   'position': 'DFMF',
#   'squad': 'Leverkusen',
#   'competition': 'Bundesliga',
#   'age': 22},
#  {'player': 'Chris Führich',
#   'nation': 'GER',
#   'position': 'FWMF',
#   'squad': 'Stuttgart',
#   'competition': 'Bundesliga',
#   'age': 25},
#  {'player': 'Angelo Fulgini',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'Angelo Fulgini',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Mainz 05',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Niclas Füllkrug',
#   'nation': 'GER',
#   'position': 'FW',
#   'squad': 'Werder Bremen',
#   'competition': 'Bundesliga',
#   'age': 30},
#  {'player': 'Matteo Gabbia',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Milan',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Manolo Gabbiadini',
#   'nation': 'ITA',
#   'position': 'FWMF',
#   'squad': 'Sampdoria',
#   'competition': 'Serie A',
#   'age': 31},
#  {'player': 'Gianluca Gaetano',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Napoli',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Roberto Gagliardini',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Adolfo Gaich',
#   'nation': 'ARG',
#   'position': 'FW',
#   'squad': 'Hellas Verona',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Cody Gakpo',
#   'nation': 'NED',
#   'position': 'FW',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Javi Galán',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Celta Vigo',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Iñigo Ruiz de Galarreta',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 29},
#  {'player': 'Pablo Galdames Millán',
#   'nation': 'CHI',
#   'position': 'DF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Conor Gallagher',
#   'nation': 'ENG',
#   'position': 'MFFW',
#   'squad': 'Chelsea',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Antonino Gallo',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 23},
#  {'player': 'Gauthier Gallon',
#   'nation': 'FRA',
#   'position': 'GK',
#   'squad': 'Troyes',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Cristian Gamboa',
#   'nation': 'CRC',
#   'position': 'DF',
#   'squad': 'Bochum',
#   'competition': 'Bundesliga',
#   'age': 33},
#  {'player': 'Kévin Gameiro',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Strasbourg',
#   'competition': 'Ligue 1',
#   'age': 35},
#  {'player': 'Idrissa Gana Gueye',
#   'nation': 'SEN',
#   'position': 'MF',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 33},
#  {'player': 'Ignatius Ganago',
#   'nation': 'CMR',
#   'position': 'FWMF',
#   'squad': 'Nantes',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Ignatius Ganago',
#   'nation': 'CMR',
#   'position': 'FW',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': "Silvère Ganvoula M'Boussy",
#   'nation': 'CGO',
#   'position': 'FW',
#   'squad': 'Bochum',
#   'competition': 'Bundesliga',
#   'age': 26},
#  {'player': 'Aleix García',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Girona',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Álvaro García',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Rayo Vallecano',
#   'competition': 'La Liga',
#   'age': 30},
#  {'player': 'Borja García',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Girona',
#   'competition': 'La Liga',
#   'age': 32},
#  {'player': 'Carlos García',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Dani García',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 32},
#  {'player': 'David García',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Eric García',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Francisco Garcia',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Rayo Vallecano',
#   'competition': 'La Liga',
#   'age': 23},
#  {'player': 'Raúl García',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Athletic Club',
#   'competition': 'La Liga',
#   'age': 36},
#  {'player': 'Rubén García',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 29},
#  {'player': 'Unai García',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Alejandro Garnacho',
#   'nation': 'ESP',
#   'position': 'FW',
#   'squad': 'Manchester Utd',
#   'competition': 'Premier League',
#   'age': 18},
#  {'player': 'James Garner',
#   'nation': 'ENG',
#   'position': 'MF',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Felix Garreta',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 18},
#  {'player': 'Sékou Gassama',
#   'nation': 'SEN',
#   'position': 'FW',
#   'squad': 'Valladolid',
#   'competition': 'La Liga',
#   'age': 27},
#  {'player': 'Johan Gastien',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 35},
#  {'player': 'Federico Gatti',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Juventus',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Gavi',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Barcelona',
#   'competition': 'La Liga',
#   'age': 18},
#  {'player': 'Paulo Gazzaniga',
#   'nation': 'ARG',
#   'position': 'GK',
#   'squad': 'Girona',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'David de Gea',
#   'nation': 'ESP',
#   'position': 'GK',
#   'squad': 'Manchester Utd',
#   'competition': 'Premier League',
#   'age': 32},
#  {'player': 'Dennis Geiger',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Hoffenheim',
#   'competition': 'Bundesliga',
#   'age': 24},
#  {'player': 'Joe Gelhardt',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 20},
#  {'player': 'Valentin Gendrey',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Denis Genreau',
#   'nation': 'AUS',
#   'position': 'MFFW',
#   'squad': 'Toulouse',
#   'competition': 'Ligue 1',
#   'age': 23},
#  {'player': 'Yannick Gerhardt',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Wolfsburg',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Valère Germain',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Montpellier',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Gerson',
#   'nation': 'BRA',
#   'position': 'MF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 25},
#  {'player': 'Ismaël Gharbi',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Paris S-G',
#   'competition': 'Ligue 1',
#   'age': 18},
#  {'player': 'Paolo Ghiglione',
#   'nation': 'ITA',
#   'position': 'DF',
#   'squad': 'Cremonese',
#   'competition': 'Serie A',
#   'age': 26},
#  {'player': 'Saman Ghoddos',
#   'nation': 'IRN',
#   'position': 'MFFW',
#   'squad': 'Brentford',
#   'competition': 'Premier League',
#   'age': 29},
#  {'player': 'Faouzi Ghoulam',
#   'nation': 'ALG',
#   'position': 'DF',
#   'squad': 'Angers',
#   'competition': 'Ligue 1',
#   'age': 32},
#  {'player': 'Morgan Gibbs-White',
#   'nation': 'ENG',
#   'position': 'FWMF',
#   'squad': 'Wolves',
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Morgan Gibbs-White',
#   'nation': 'ENG',
#   'position': 'MFFW',
#   'squad': "Nott'ham Forest",
#   'competition': 'Premier League',
#   'age': 23},
#  {'player': 'Niko Gießelmann',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Union Berlin',
#   'competition': 'Bundesliga',
#   'age': 31},
#  {'player': 'Samuel Gigot',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Marseille',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Rafa? Gikiewicz',
#   'nation': 'POL',
#   'position': 'GK',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 35},
#  {'player': 'Óscar Gil',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Mario Gila',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Lazio',
#   'competition': 'Serie A',
#   'age': 22},
#  {'player': 'Billy Gilmour',
#   'nation': 'SCO',
#   'position': 'MF',
#   'squad': 'Brighton',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Álvaro Giménez',
#   'nation': 'ESP',
#   'position': 'FW',
#   'squad': 'Cádiz',
#   'competition': 'La Liga',
#   'age': 31},
#  {'player': 'Gvidas Gineitis',
#   'nation': 'LTU',
#   'position': 'MF',
#   'squad': 'Torino',
#   'competition': 'Serie A',
#   'age': 18},
#  {'player': 'Matthias Ginter',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Freiburg',
#   'competition': 'Bundesliga',
#   'age': 29},
#  {'player': 'Andrei Girotto',
#   'nation': 'BRA',
#   'position': 'DFMF',
#   'squad': 'Nantes',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'Olivier Giroud',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Milan',
#   'competition': 'Serie A',
#   'age': 36},
#  {'player': 'Serge Gnabry',
#   'nation': 'GER',
#   'position': 'FWMF',
#   'squad': 'Bayern Munich',
#   'competition': 'Bundesliga',
#   'age': 27},
#  {'player': 'Degnand Gnonto',
#   'nation': 'ITA',
#   'position': 'FWMF',
#   'squad': 'Leeds United',
#   'competition': 'Premier League',
#   'age': 19},
#  {'player': 'Ben Godfrey',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Pierluigi Gollini',
#   'nation': 'ITA',
#   'position': 'GK',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 27},
#  {'player': 'Aleksandr Golovin',
#   'nation': 'RUS',
#   'position': 'MFFW',
#   'squad': 'Monaco',
#   'competition': 'Ligue 1',
#   'age': 26},
#  {'player': 'André Gomes',
#   'nation': 'POR',
#   'position': 'MF',
#   'squad': 'Lille',
#   'competition': 'Ligue 1',
#   'age': 29},
#  {'player': 'Angel Gomes',
#   'nation': 'ENG',
#   'position': 'MF',
#   'squad': 'Lille',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'João Gomes',
#   'nation': 'BRA',
#   'position': 'MF',
#   'squad': 'Wolves',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Toti Gomes',
#   'nation': 'POR',
#   'position': 'DF',
#   'squad': 'Wolves',
#   'competition': 'Premier League',
#   'age': 24},
#  {'player': 'Dani Gómez',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 24},
#  {'player': 'Joe Gomez',
#   'nation': 'ENG',
#   'position': 'DF',
#   'squad': 'Liverpool',
#   'competition': 'Premier League',
#   'age': 25},
#  {'player': 'Maxi Gómez',
#   'nation': 'URU',
#   'position': 'FW',
#   'squad': 'Valencia',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Moi Gómez',
#   'nation': 'ESP',
#   'position': 'MFFW',
#   'squad': 'Osasuna',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Papu Gómez',
#   'nation': 'ARG',
#   'position': 'MFFW',
#   'squad': 'Sevilla',
#   'competition': 'La Liga',
#   'age': 34},
#  {'player': 'Sergi Gómez',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 30},
#  {'player': 'Sergio Gómez',
#   'nation': 'ESP',
#   'position': 'DFMF',
#   'squad': 'Manchester City',
#   'competition': 'Premier League',
#   'age': 22},
#  {'player': 'Maxime Gonalons',
#   'nation': 'FRA',
#   'position': 'MF',
#   'squad': 'Clermont Foot',
#   'competition': 'Ligue 1',
#   'age': 33},
#  {'player': 'Diego González',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Elche',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Édgar González',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 25},
#  {'player': 'Giovanni González',
#   'nation': 'URU',
#   'position': 'DF',
#   'squad': 'Mallorca',
#   'competition': 'La Liga',
#   'age': 28},
#  {'player': 'Joan Gonzàlez',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Lecce',
#   'competition': 'Serie A',
#   'age': 21},
#  {'player': 'Nicolás González',
#   'nation': 'ARG',
#   'position': 'FWMF',
#   'squad': 'Fiorentina',
#   'competition': 'Serie A',
#   'age': 24},
#  {'player': 'Nicolás González',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Valencia',
#   'competition': 'La Liga',
#   'age': 21},
#  {'player': 'Oumar Gonzalez',
#   'nation': 'CMR',
#   'position': 'DF',
#   'squad': 'Ajaccio',
#   'competition': 'Ligue 1',
#   'age': 24},
#  {'player': 'Roberto González',
#   'nation': 'ESP',
#   'position': 'FWMF',
#   'squad': 'Betis',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Jacek Góralski',
#   'nation': 'POL',
#   'position': 'MF',
#   'squad': 'Bochum',
#   'competition': 'Bundesliga',
#   'age': 30},
#  {'player': 'Anthony Gordon',
#   'nation': 'ENG',
#   'position': 'MFFW',
#   'squad': 'Newcastle Utd',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Anthony Gordon',
#   'nation': 'ENG',
#   'position': 'FW',
#   'squad': 'Everton',
#   'competition': 'Premier League',
#   'age': 21},
#  {'player': 'Leon Goretzka',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Bayern Munich',
#   'competition': 'Bundesliga',
#   'age': 28},
#  {'player': 'Andoni Gorosabel',
#   'nation': 'ESP',
#   'position': 'DF',
#   'squad': 'Real Sociedad',
#   'competition': 'La Liga',
#   'age': 26},
#  {'player': 'Robin Gosens',
#   'nation': 'GER',
#   'position': 'DF',
#   'squad': 'Inter',
#   'competition': 'Serie A',
#   'age': 28},
#  {'player': 'Mario Götze',
#   'nation': 'GER',
#   'position': 'MF',
#   'squad': 'Eint Frankfurt',
#   'competition': 'Bundesliga',
#   'age': 30},
#  {'player': 'Amine Gouiri',
#   'nation': 'FRA',
#   'position': 'FWMF',
#   'squad': 'Nice',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Amine Gouiri',
#   'nation': 'FRA',
#   'position': 'FW',
#   'squad': 'Rennes',
#   'competition': 'Ligue 1',
#   'age': 22},
#  {'player': 'Jeffrey Gouweleeuw',
#   'nation': 'NED',
#   'position': 'DF',
#   'squad': 'Augsburg',
#   'competition': 'Bundesliga',
#   'age': 31},
#  {'player': 'Jonathan Gradit',
#   'nation': 'FRA',
#   'position': 'DF',
#   'squad': 'Lens',
#   'competition': 'Ligue 1',
#   'age': 30},
#  {'player': 'José Gragera',
#   'nation': 'ESP',
#   'position': 'MF',
#   'squad': 'Espanyol',
#   'competition': 'La Liga',
#   'age': 22},
#  {'player': 'Alberto Grassi',
#   'nation': 'ITA',
#   'position': 'MF',
#   'squad': 'Empoli',
#   'competition': 'Serie A',
#   'age': 27},
#  ...]

# %% [markdown]
# ### 8. Create a new variable named players_by_nation that groups players by their respective nations.
#
# The variable should be a dictionary where the keys are the nation names, and the values are lists of players belonging to that nation.
#
# Each player should be represented as a dictionary containing the keys:
#
# - player
# - position
# - squad
# - competition
# - age.
#
# Example of expected output:
#
# <code>
# {'USA': [{'player': 'Brenden Aaronson',
#           'position': 'MFFW',
#           'squad': 'Leeds United',
#           'competition': 'Premier League',
#           'age': 31},
#          {'player': 'Tyler Adams',
#           'position': 'MF',
#           'squad': 'Leeds United',
#           'competition': 'Premier League',
#           'age': 31},
#           ...
#         ],
#         ...
# }
# </code>

# %%
players_by_nation = {}
for player in players:
    nation = player[1]
   
    player_data = {
        'player' : player[0],
        'position' : player[2],
        'squad' : player[3],
        'competition' : player[4],
        'age' : player[5]
    }

    if nation not in players_by_nation:
        players_by_nation[nation] = [player_data]
    else:
        players_by_nation[nation].append(player_data)

players_by_nation
# Out:
# {'USA': [{'player': 'Brenden Aaronson',
#    'position': 'MFFW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Tyler Adams',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'John Brooks',
#    'position': 'DF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Timothy Chandler',
#    'position': 'DF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Sergiño Dest',
#    'position': 'DF',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Luca de la Torre',
#    'position': 'MF',
#    'squad': 'Celta Vigo',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Weston McKennie',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Weston McKennie',
#    'position': 'MFDF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Yunus Musah',
#    'position': 'MF',
#    'squad': 'Valencia',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Erik Palmer-Brown',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Kevin Paredes',
#    'position': 'MFFW',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Jordan Pefok',
#    'position': 'FW',
#    'squad': 'Union Berlin',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Ricardo Pepi',
#    'position': 'FW',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Christian Pulisic',
#    'position': 'FWDF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Tim Ream',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 35},
#   {'player': 'Gio Reyna',
#    'position': 'FWMF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Chris Richards',
#    'position': 'DF',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Antonee Robinson',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Joe Scally',
#    'position': 'DF',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Timothy Weah',
#    'position': 'DFFW',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 22}],
#  'MAR': [{'player': 'Yunis Abdelhamid',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Zakaria Aboukhlal',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Nayef Aguerd',
#    'position': 'DF',
#    'squad': 'West Ham',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Sofyan Amrabat',
#    'position': 'MF',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Anuar',
#    'position': 'MFFW',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Ayman Azhil',
#    'position': 'MF',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Aymen Barkok',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Sofiane Boufal',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Yassine Bounou',
#    'position': 'GK',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Mehdi Bourabia',
#    'position': 'MF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Achraf Dari',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Youssef En-Nesyri',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Abdessamad Ezzalzouli',
#    'position': 'FWMF',
#    'squad': 'Osasuna',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Zouhair Feddal',
#    'position': 'DF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Munir El Haddadi',
#    'position': 'MFFW',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Achraf Hakimi',
#    'position': 'DFMF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Amine Harit',
#    'position': 'MFFW',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Omar El Hilali',
#    'position': 'DFMF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Adam Masina',
#    'position': 'DF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Aïman Maurer',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Noussair Mazraoui',
#    'position': 'DF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Azzedine Ounahi',
#    'position': 'MF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Azzedine Ounahi',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Kays Ruiz',
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Abdelhamid Sabiri',
#    'position': 'MFFW',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Hamza Sakhi',
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Nabil Touaizi',
#    'position': 'MF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Jawad El Yamiq',
#    'position': 'DF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Hakim Ziyech',
#    'position': 'FWMF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 29}],
#  'FRA': [{'player': 'Himad Abdelli',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Laurent Abergel',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Matthis Abline',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Matthis Abline',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Mohamed Achi',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Martin Adeline',
#    'position': 'MFFW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Amine Adli',
#    'position': 'FW',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Yacine Adli',
#    'position': 'MFFW',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Lucien Agoume',
#    'position': 'MF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Ruben Aguilar',
#    'position': 'DF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Naouirou Ahamada',
#    'position': 'MFFW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Naouirou Ahamada',
#    'position': 'MF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Rayan Aït Nouri',
#    'position': 'DF',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Ludovic Ajorque',
#    'position': 'FW',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Ludovic Ajorque',
#    'position': 'FW',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 28},
#   {'player': 'Maghnes Akliouche',
#    'position': 'MFDF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Mohamed Ali Cho',
#    'position': 'FW',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Ibrahim Amadou',
#    'position': 'DFMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Jordan Amavi',
#    'position': 'DF',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Kelvin Amian',
#    'position': 'DF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Benjamin André',
#    'position': 'MF',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Janis Antiste',
#    'position': 'FW',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Houssem Aouar',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Adil Aouchiche',
#    'position': 'MFFW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Dennis Appiah',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Taïryk Arconte',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Alphonse Areola',
#    'position': 'GK',
#    'squad': 'West Ham',
#    'competition': 'Premier League',
#    'age': 29},
#   {'player': 'Mathias Autret',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Loïc Bade',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Loïc Bade',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Benoît Badiashile',
#    'position': 'DF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Benoît Badiashile',
#    'position': 'DF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Dénys Bain',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Thierno Balde',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Jonathan Bamba',
#    'position': 'FW',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Bradley Barcola',
#    'position': 'FWMF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Melvin Bard',
#    'position': 'DF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Mickaël Barreto',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Brian Bayeye',
#    'position': 'DF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Yanis Begraoui',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Alexis Beka Beka',
#    'position': 'MF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Jean-Ricner Bellegarde',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jeanöel Belocian',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Eliesse Ben Seghir',
#    'position': 'FW',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Salim Ben Seghir',
#    'position': 'MF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Wissam Ben Yedder',
#    'position': 'FW',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Karim Benzema',
#    'position': 'FW',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 35},
#   {'player': 'Quentin Bernard',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Paul Bernardoni',
#    'position': 'GK',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Jason Berthomier',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Giulian Biancone',
#    'position': 'DF',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Ludovic Blas',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Alexis Blin',
#    'position': 'MFDF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Antonin Bobichon',
#    'position': 'MF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Quentin Boisgard',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Warren Bondo',
#    'position': 'MF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Franci Bouebari',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Ismaëlben Boura',
#    'position': 'DFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Benjamin Bourigeaud',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Lilian Brassier',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Rémy Cabella',
#    'position': 'MFFW',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Jimmy Cabot',
#    'position': 'DFMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Anthony Caci',
#    'position': 'DF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Mahdi Camara',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Ousmane Camara',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Eduardo Camavinga',
#    'position': 'MFDF',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Axel Camblan',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Pierrick Capelle',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Étienne Capoue',
#    'position': 'MF',
#    'squad': 'Villarreal',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Maxence Caqueret',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Irvin Cardona',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Irvin Cardona',
#    'position': 'MF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Yoann Cathline',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Fabien Centonze',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Florian Chabrolle',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'El Chadaille Bitshiabu',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Fares Chaïbi',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Gaëtan Charbonnier',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Brendan Chardonnet',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Xavier Chavalerin',
#    'position': 'MF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Rayan Cherki',
#    'position': 'MFFW',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Lucas Chevalier',
#    'position': 'GK',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Joris Chotard',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Yanis Cimignani',
#    'position': 'MFDF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Souleymane Cissé',
#    'position': 'DF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Alexis Claude-Maurice',
#    'position': 'FW',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Alexis Claude-Maurice',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jonathan Clauss',
#    'position': 'DF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Marcus Coco',
#    'position': 'DFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Alexandre Coeff',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Kingsley Coman',
#    'position': 'FWMF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Francis Coquelin',
#    'position': 'MF',
#    'squad': 'Villarreal',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Sébastien Corchia',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Benoît Costil',
#    'position': 'GK',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Tanguy Coulibaly',
#    'position': 'DFFW',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Mathieu Coutadeur',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Nicolas Cozza',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Mickaël Cuisance',
#    'position': 'MF',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Damien Da Silva',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Colin Dagba',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Romain Del Castillo',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Thomas Delaine',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Sacha Delaye',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Moussa Dembélé',
#    'position': 'FWMF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Ousmane Dembélé',
#    'position': 'FW',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Rémy Descamps',
#    'position': 'GK',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Moussa Diaby',
#    'position': 'FW',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Bafodé Diakité',
#    'position': 'DF',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Baila Diallo',
#    'position': 'DF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Ibrahima Diallo',
#    'position': 'MF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Stéphane Diarra',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Lucas Digne',
#    'position': 'DF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 29},
#   {'player': 'Junior Dina Ebimbe',
#    'position': 'DFMF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Lois Diony',
#    'position': 'FW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Issa Diop',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Sofiane Diop',
#    'position': 'MFFW',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Sofiane Diop',
#    'position': 'MF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Yehvann Diouf',
#    'position': 'GK',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Axel Disasi',
#    'position': 'DF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Kyliane Dong',
#    'position': 'DFMF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Lohann Doucet',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Désiré Doué',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Guela Doué',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Ismaël Doukouré',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Rémy Dugimont',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Maxime Dupé',
#    'position': 'GK',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Jean-Kevin Duverne',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Odsonne Édouard',
#    'position': 'FWMF',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Hugo Ekitike',
#    'position': 'FW',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Sepe Elye Wahi',
#    'position': 'FW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Maxime Estève',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Romain Faivre',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Romain Faivre',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Khalil Fayad',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Nabil Fekir',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Jordan Ferri',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Alexis Flips',
#    'position': 'DFMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Wesley Fofana',
#    'position': 'DF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Wesley Fofana',
#    'position': 'DF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Yahia Fofana',
#    'position': 'GK',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Youssouf Fofana',
#    'position': 'MF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Dimitri Foulquier',
#    'position': 'DFMF',
#    'squad': 'Valencia',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Angelo Fulgini',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Angelo Fulgini',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Gauthier Gallon',
#    'position': 'GK',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Kévin Gameiro',
#    'position': 'FW',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Johan Gastien',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Valentin Gendrey',
#    'position': 'DF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Valère Germain',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Samuel Gigot',
#    'position': 'DF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Olivier Giroud',
#    'position': 'FW',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 36},
#   {'player': 'Maxime Gonalons',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Amine Gouiri',
#    'position': 'FWMF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Amine Gouiri',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Jonathan Gradit',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Clément Grenier',
#    'position': 'MF',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 32},
#   {'player': 'Antoine Griezmann',
#    'position': 'FWMF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Axel Gueguin',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Mattéo Guendouzi',
#    'position': 'MF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Evann Guessand',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Josuha Guilavogui',
#    'position': 'MFDF',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Frederic Guilbert',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Rafik Guitane',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Malo Gusto',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Jaouen Hadjam',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Mathis Hamdi',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Romain Hamouma',
#    'position': 'FWMF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Gauthier Hein',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Thomas Henry',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Lucas Hernández',
#    'position': 'DF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Theo Hernández',
#    'position': 'DF',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Franck Honorat',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Ilyes Housni',
#    'position': 'FW',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Adrien Hunou',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Mounaim El Idrissy',
#    'position': 'FW',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jonathan Ikone',
#    'position': 'FW',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Paul Joly',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Christopher Jullien',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Abdoul Kader Bamba',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Arnaud Kalimuendo',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Pierre Kalulu',
#    'position': 'DF',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Boubacar Kamara',
#    'position': 'MF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Nordine Kandil',
#    'position': 'MFFW',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': "N'Golo Kanté",
#    'position': 'MF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Yann Karamoh',
#    'position': 'FWMF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Check Keita',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Anthony Khelifa',
#    'position': 'DF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Presnel Kimpembe',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Randal Kolo Muani',
#    'position': 'FW',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Timothée Kolodziejczak',
#    'position': 'DF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Ibrahima Konaté',
#    'position': 'DF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Kouadio Koné',
#    'position': 'MF',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Jules Koundé',
#    'position': 'DF',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Sael Kumbedi',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Layvin Kurzawa',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 30},
#   {'player': 'Grejohn Kyei',
#    'position': 'FW',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Gaëtan Laborde',
#    'position': 'FW',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Gaëtan Laborde',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Alexandre Lacazette',
#    'position': 'FW',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Maxence Lacroix',
#    'position': 'DF',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Alban Lafont',
#    'position': 'GK',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Kenny Lala',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Julien Laporte',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Armand Lauriente',
#    'position': 'FW',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Armand Lauriente',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Théo Le Bris',
#    'position': 'MFDF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Julien Le Cardinal',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Jérémy Le Douaron',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Enzo Le Fée',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Vincent Le Goff',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Maxime Le Marchand',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Robin Le Normand',
#    'position': 'DF',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 26},
#   {'player': 'Benjamin Lecomte',
#    'position': 'GK',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Benjamin Lecomte',
#    'position': 'GK',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Pierre Lees-Melou',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Florian Lejeune',
#    'position': 'DF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Thomas Lemar',
#    'position': 'MF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Clément Lenglet',
#    'position': 'DF',
#    'squad': 'Tottenham',
#    'competition': 'Premier League',
#    'age': 27},
#   {'player': 'Johann Lepenant',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Benjamin Leroy',
#    'position': 'GK',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Léo Leroy',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Dimitri Liénard',
#    'position': 'DFMF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Hugo Lloris',
#    'position': 'GK',
#    'squad': 'Tottenham',
#    'competition': 'Premier League',
#    'age': 36},
#   {'player': 'Banzouzi Locko',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Maxime Lopez',
#    'position': 'MF',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Anthony Losilla',
#    'position': 'MF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 36},
#   {'player': 'Castello Lukeba',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Hugo Magnetti',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Yohann Magnin',
#    'position': 'MFDF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Mike Maignan',
#    'position': 'GK',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Jean-Victor Makengo',
#    'position': 'MF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Jean-Victor Makengo',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Hianga Mananga Mbock',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Steve Mandanda',
#    'position': 'GK',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 37},
#   {'player': 'Thomas Mangani',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Myziane Maolida',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Myziane Maolida',
#    'position': 'FWMF',
#    'squad': 'Hertha BSC',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Faitout Maouassa',
#    'position': 'DFFW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Sekou Mara',
#    'position': 'FWMF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Vincent Marchetti',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Anthony Martial',
#    'position': 'FW',
#    'squad': 'Manchester Utd',
#    'competition': 'Premier League',
#    'age': 27},
#   {'player': 'Jonas Martin',
#    'position': 'MF',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Han-Noah Massengo',
#    'position': 'MFDF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Yanis Massolin',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Jean-Philippe Mateta',
#    'position': 'FW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Chrislain Matsima',
#    'position': 'DFMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Neal Maupay',
#    'position': 'FW',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Christian Mawissa',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Kylian Mbappé',
#    'position': 'FW',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jason Mbock',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Nathanael Mbuku',
#    'position': 'FWMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Soualiho Meïté',
#    'position': 'MF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Houboulang Mendes',
#    'position': 'DF',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Antoine Mendy',
#    'position': 'DF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Batista Mendy',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ferland Mendy',
#    'position': 'DF',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Quentin Merlin',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Illan Meslier',
#    'position': 'GK',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Enzo Millot',
#    'position': 'MF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Anthony Modeste',
#    'position': 'FW',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Florent Mollet',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Florent Mollet',
#    'position': 'MF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Nordi Mukiele',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': "Obite N'Dicka",
#    'position': 'DF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': "Nathan N'Goumou",
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': "Nathan N'Goumou",
#    'position': 'FW',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': "Stanley N'Soki",
#    'position': 'DF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Michel Ndary Adopo',
#    'position': 'MFDF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Tanguy Ndombele',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Moussa Niakhate',
#    'position': 'DF',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Tanguy Nianzou',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Christopher Nkunku',
#    'position': 'FWMF',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Arnaud Nordin',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Riad Nouri',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 37},
#   {'player': 'Randy Ntekja',
#    'position': 'FW',
#    'squad': 'Elche',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Randy Ntekja',
#    'position': 'FWMF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Gerzino Nyamsi',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Wilson Odobert',
#    'position': 'MFFW',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Florent Ogier',
#    'position': 'DF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Michael Olise',
#    'position': 'MFFW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Warmed Omari',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Remi Oudin',
#    'position': 'FWMF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Zinédine Ould Khaled',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Nicolas Pallois',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Benjamin Pavard',
#    'position': 'DF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Dimitri Payet',
#    'position': 'MFFW',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Timothee Pembele',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Brayann Pereira',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Romain Perraud',
#    'position': 'DF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Gaëtan Perrin',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Lucas Perrin',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Ronaël Pierre-Gabriel',
#    'position': 'DF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Ronaël Pierre-Gabriel',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Alassane Pléa',
#    'position': 'FW',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Julien Ponceau',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Mehdi Puch Herrantz',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Ghjuvanni Quilichini',
#    'position': 'GK',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Adrien Rabiot',
#    'position': 'MF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Adil Rami',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 37},
#   {'player': 'Lilian Raolisoa',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Jeff Reine-Adélaïde',
#    'position': 'MF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Jeff Reine-Adélaïde',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Franck Ribéry',
#    'position': 'MF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 39},
#   {'player': 'Rémy Riou',
#    'position': 'GK',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Renaud Ripart',
#    'position': 'FWMF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Valentin Rongier',
#    'position': 'MF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Anthony Rouault',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Jérôme Roussillon',
#    'position': 'MFDF',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Jérôme Roussillon',
#    'position': 'DF',
#    'squad': 'Union Berlin',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Georginio Rutter',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Georginio Rutter',
#    'position': 'FW',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Wesley Saïd',
#    'position': 'FWMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Allan Saint-Maximin',
#    'position': 'FW',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Théo Sainte-Luce',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Mamadou Sakho',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Amine Salama',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'William Saliba',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Junior Sambia',
#    'position': 'DFMF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Morgan Sanson',
#    'position': 'MF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 28},
#   {'player': 'Morgan Sanson',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Baptiste Santamaria',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Malang Sarr',
#    'position': 'DF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Téji Savanier',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Kiliann Sildillia',
#    'position': 'DFMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Mohamed Simakan',
#    'position': 'DF',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Ibrahima Sissoko',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Moussa Sissoko',
#    'position': 'MF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'François-Joseph Sollacaro',
#    'position': 'GK',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Brandon Soppy',
#    'position': 'DF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Brandon Soppy',
#    'position': 'DF',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Florian Sotoca',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Moussa Soumano',
#    'position': 'MFFW',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Adama Soumaoro',
#    'position': 'DF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Boubakary Soumaré',
#    'position': 'MF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Arnaud Souquet',
#    'position': 'DFFW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Waniss Taibi',
#    'position': 'MF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Flavien Tait',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Florian Tardieu',
#    'position': 'MF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Aurélien Tchouaméni',
#    'position': 'MF',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Mathys Tel',
#    'position': 'FW',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Martin Terrier',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Florian Thauvin',
#    'position': 'MFDF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Adrien Thomasson',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Adrien Thomasson',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Marcus Thuram',
#    'position': 'FW',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 25},
# ...
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'César Montes',
#    'position': 'DF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Guillermo Ochoa',
#    'position': 'GK',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 37},
#   {'player': 'Johan Vásquez',
#    'position': 'DF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 24}],
#  'ISR': [{'player': 'Moanes Dabbur',
#    'position': 'FW',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Manor Solomon',
#    'position': 'FW',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Shon Weissman',
#    'position': 'FW',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 26}],
#  'CAN': [{'player': 'Jonathan David',
#    'position': 'FW',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Alphonso Davies',
#    'position': 'DF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Luca Koleosho',
#    'position': 'FWDF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Cyle Larin',
#    'position': 'FW',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Ike Ugbo',
#    'position': 'FWMF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 24}],
#  'MTQ': [{'player': 'Grégoire Defrel',
#    'position': 'FW',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Christophe Hérelle',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Mickael Malsa',
#    'position': 'MF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 27}],
#  'BEN': [{'player': 'Jodel Dossou',
#    'position': 'MFDF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Cédric Hountondji',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Steve Mounié',
#    'position': 'FW',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 28}],
#  'COM': [{'player': 'Ckene Doucouré',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': "Youssouf M'Changama",
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Mohamed Youssouf',
#    'position': 'DF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 34}],
#  'SVK': [{'player': 'Ondrej Duda',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Ondrej Duda',
#    'position': 'MF',
#    'squad': 'Köln',
#    'competition': 'Bundesliga',
#    'age': 28},
#   {'player': 'Norbert Gyömbér',
#    'position': 'DF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Stanislav Lobotka',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Peter Pekarík',
#    'position': 'DF',
#    'squad': 'Hertha BSC',
#    'competition': 'Bundesliga',
#    'age': 36},
#   {'player': 'Marek Rodák',
#    'position': 'GK',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Milan \x8akriniar',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Dávid Strelec',
#    'position': 'FW',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Martin Valjent',
#    'position': 'DF',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 27}],
#  'HON': [{'player': 'Alberth Elis',
#    'position': 'MFFW',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Anthony Lozano',
#    'position': 'FW',
#    'squad': 'Cádiz',
#    'competition': 'La Liga',
#    'age': 29}],
#  'ISL': [{'player': 'Mikael Ellertsson',
#    'position': 'MFDF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': '?órir Jóhann Helgason',
#    'position': 'MF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 22}],
#  'EGY': [{'player': 'Mohamed Elneny',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 30},
#   {'player': 'Omar Marmoush',
#    'position': 'FW',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Mostafa Mohamed',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Mohamed Salah',
#    'position': 'FW',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 30}],
#  'NIR': [{'player': 'Jonny Evans',
#    'position': 'DF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 35},
#   {'player': 'Jamal Lewis',
#    'position': 'DF',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Isaac Price',
#    'position': 'MF',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 19}],
#  'AUS': [{'player': 'Tyrese Francois',
#    'position': 'FW',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Denis Genreau',
#    'position': 'MFFW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ajdin Hrustic',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Alou Kuol',
#    'position': 'FW',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Awer Mabil',
#    'position': 'MFFW',
#    'squad': 'Cádiz',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Harry Souttar',
#    'position': 'DF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 24}],
#  'CRC': [{'player': 'Cristian Gamboa',
#    'position': 'DF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 33},
#   {'player': 'Keylor Navas',
#    'position': 'GK',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 36}],
#  'CGO': [{'player': "Silvère Ganvoula M'Boussy",
#    'position': 'FW',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Béni Makouana',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Fernand Mayembo',
#    'position': 'DF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Bevic Moussiti-Oko',
#    'position': 'FW',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Brice Samba',
#    'position': 'GK',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 28}],
#  'LTU': [{'player': 'Gvidas Gineitis',
#    'position': 'MF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 18}],
#  'RUS': [{'player': 'Aleksandr Golovin',
#    'position': 'MFFW',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Andrey Lunyov',
#    'position': 'GK',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Aleksei Miranchuk',
#    'position': 'MF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 27}],
#  'HUN': [{'player': 'Péter Gulácsi',
#    'position': 'GK',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Willi Orban',
#    'position': 'DF',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Roland Sallai',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'András Schäfer',
#    'position': 'MF',
#    'squad': 'Union Berlin',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Dominik Szoboszlai',
#    'position': 'MFFW',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 22}],
#  'KOR': [{'player': 'Hwang Hee-chan',
#    'position': 'FW',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 27},
#   {'player': 'Son Heung-min',
#    'position': 'MFFW',
#    'squad': 'Tottenham',
#    'competition': 'Premier League',
#    'age': 30},
#   {'player': 'Lee Jae-sung',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Lee Kangin',
#    'position': 'MFFW',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Kim Min-jae',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Jeong Woo-yeong',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 23}],
#  'EQG': [{'player': 'Aridane Hernández',
#    'position': 'DF',
#    'squad': 'Osasuna',
#    'competition': 'La Liga',
#    'age': 33},
#   {'player': 'Pedro Obiang',
#    'position': 'MF',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Pepín',
#    'position': 'MF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 26}],
#  'VEN': [{'player': 'Yangel Herrera',
#    'position': 'MFFW',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Darwin Machís',
#    'position': 'FW',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Tomás Rincón',
#    'position': 'MF',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 35},
#   {'player': 'Salomón Rondón',
#    'position': 'FW',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 33}],
#  'PHI': [{'player': 'Gerrit Holtmann',
#    'position': 'FW',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 27}],
#  'FIN': [{'player': 'Luká\x9a Hrádeck?',
#    'position': 'GK',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 33},
#   {'player': 'Fredrik Jensen',
#    'position': 'FWMF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Joel Pohjanpalo',
#    'position': 'FWMF',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 28},
#   {'player': 'Niklas Pyyhtiä',
#    'position': 'MF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Naatan Skyttä',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Jere Uronen',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Jere Uronen',
#    'position': 'DF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 28}],
#  'HAI': [{'player': 'Dany Jean',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 20}],
#  'MNE': [{'player': 'Stevan Joveti?',
#    'position': 'FWMF',
#    'squad': 'Hertha BSC',
#    'competition': 'Bundesliga',
#    'age': 33},
#   {'player': 'Adam Maru\x9ai?',
#    'position': 'DF',
#    'squad': 'Lazio',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Esteban Saveljich',
#    'position': 'FW',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Stefan Savi?',
#    'position': 'DF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 32}],
#  'ZIM': [{'player': 'Tino Kadewere',
#    'position': 'MFFW',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 27},
#   {'player': 'Marshall Munetsi',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Jordan Zemura',
#    'position': 'DF',
#    'squad': 'Bournemouth',
#    'competition': 'Premier League',
#    'age': 23}],
#  'SLE': [{'player': 'Yayah Kallon',
#    'position': 'MFFW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 21}],
#  'GRE': [{'player': 'Thomas Kastanaras',
#    'position': 'FWDF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Giorgos Kyriakopoulos',
#    'position': 'FW',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Giorgos Kyriakopoulos',
#    'position': 'FWDF',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Vassilis Lambropoulos',
#    'position': 'DF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Charalambos Lykogiannis',
#    'position': 'DF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Konstantinos Mavropanos',
#    'position': 'DF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Dimitris Nikolaou',
#    'position': 'DF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Panagiotis Retsos',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Kostas Stafylidis',
#    'position': 'MFDF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Kostas Tsimikas',
#    'position': 'DF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Theocharis Tsingaras',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22}],
#  'CYP': [{'player': 'Grigoris Kastanos',
#    'position': 'MFDF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 25}],
#  'CTA': [{'player': 'Geoffrey Kondogbia',
#    'position': 'MF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 29}],
#  'UKR': [{'player': 'Viktor Kovalenko',
#    'position': 'MF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Andriy Lunin',
#    'position': 'GK',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Ruslan Malinovskyi',
#    'position': 'MFFW',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Ruslan Malinovskyi',
#    'position': 'MFFW',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Mykhailo Mudryk',
#    'position': 'FW',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Vitaliy Mykolenko',
#    'position': 'DFMF',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Ivan Ordets',
#    'position': 'DF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Eduard Sobol',
#    'position': 'DFMF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Viktor Tsyhankov',
#    'position': 'MF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Oleksandr Zinchenko',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 26}],
#  'LVA': [{'player': 'Raimonds Krollis',
#    'position': 'FW',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 21}],
#  'GEO': [{'player': 'Khvicha Kvaratskhelia',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Luka Lochoshvili',
#    'position': 'DF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Giorgi Mamardashvili',
#    'position': 'GK',
#    'squad': 'Valencia',
#    'competition': 'La Liga',
#    'age': 22}],
#  'MOZ': [{'player': 'Reinildo Mandava',
#    'position': 'DF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 29}],
#  'DOM': [{'player': 'Mariano',
#    'position': 'FW',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 29}],
#  'RSA': [{'player': 'Lebo Mothiba',
#    'position': 'FWMF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 27}],
#  'BDI': [{'player': 'Youssouf Ndayishimiye',
#    'position': 'MFDF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 24}],
#  nan: [{'player': 'David Ozoh',
#    'position': 'FW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 17}],
#  'GUF': [{'player': 'Yoann Salmier',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 30}],
#  'UZB': [{'player': 'Eldor Shomurodov',
#    'position': 'FW',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Eldor Shomurodov',
#    'position': 'FW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 27}]}

# %% [markdown]
# ### 9. Create a new variable named players_by_squad that groups players by their respective squads.
#
# The variable should be a dictionary where the keys are the squad names, and the values are lists of players belonging to that squad.
#
# Each player should be represented as a dictionary containing the keys:
#
# - player
# - position
# - squad
# - competition
# - age.
#
# Example of expected output:
# <code>
# {'Leeds United': [{'player': 'Brenden Aaronson',
#                     'position': 'MFFW',
#                     'squad': 'Leeds United',
#                     'competition': 'Premier League',
#                     'age': 22},
#                   {'player': 'Tyler Adams',
#                    'position': 'MF',
#                    'squad': 'Leeds United',
#                    'competition': 'Premier League',
#                    'age': 23},
#                     ...
#                 ],
#                 ...
# }
# </code>

# %%
players_by_squad = {}

for player in players:
    squad = player[3]
    player_data = {
        'player': player[0],
        'position': player[2],
        'squad': player[3],
        'competition': player[4],
        'age': player[5]
    }

    if squad in players_by_squad:
        players_by_squad[squad].append(player_data)
    else:
        players_by_squad[squad] = [player_data]

players_by_squad
# Out:
# {'Leeds United': [{'player': 'Brenden Aaronson',
#    'position': 'MFFW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Tyler Adams',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Luke Ayling',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Patrick Bamford',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 29},
#   {'player': 'Liam Cooper',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Cody Drameh',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Mateo Fernández',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Junior Firpo',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Adam Forshaw',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Joe Gelhardt',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Degnand Gnonto',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Sam Greenwood',
#    'position': 'MFFW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Darko Gyabi',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Jack Harrison',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Daniel James',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Mateusz Klich',
#    'position': 'MFFW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 32},
#   {'player': 'Robin Koch',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Diego Llorente',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 29},
#   {'player': 'Weston McKennie',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Illan Meslier',
#    'position': 'GK',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Rasmus Nissen',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Marc Roca',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Rodrigo',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Georginio Rutter',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Luis Sinisterra',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Pascal Struijk',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Crysencio Summerville',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Maximilian Wöber',
#    'position': 'DF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 25}],
#  'Reims': [{'player': 'Yunis Abdelhamid',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Martin Adeline',
#    'position': 'MFFW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Emmanuel Agbadou',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Folarin Balogun',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Mitchell van Bergen',
#    'position': 'FWDF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'El Bilal Touré',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Maxime Busi',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Jens Cajuste',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Thibault De Smet',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Ibrahim Diakité',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Yehvann Diouf',
#    'position': 'GK',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Kamory Doumbia',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Wout Faes',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Alexis Flips',
#    'position': 'DFMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Thomas Foket',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Andrew Gravillon',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Rafik Guitane',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Noah Holm',
#    'position': 'FWMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Junya Ito',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Check Keita',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Banzouzi Locko',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Dion Lopy',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Myziane Maolida',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Azor Matusiwa',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Nathanael Mbuku',
#    'position': 'FWMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Marshall Munetsi',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Patrick Pentz',
#    'position': 'GK',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Kaj Sierhuis',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Arber Zeneli',
#    'position': 'FWMF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 27}],
#  'Angers': [{'player': 'Himad Abdelli',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ibrahim Amadou',
#    'position': 'DFMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Abdoulaye Bamba',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Nabil Bentaleb',
#    'position': 'MF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Paul Bernardoni',
#    'position': 'GK',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Miha Bla?i?',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Antonin Bobichon',
#    'position': 'MF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Sofiane Boufal',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Ousmane Camara',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Pierrick Capelle',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Ilyes Cheti',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Lois Diony',
#    'position': 'FW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Souleyman Doumbia',
#    'position': 'DFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Yahia Fofana',
#    'position': 'GK',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Faouzi Ghoulam',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Cédric Hountondji',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Adrien Hunou',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Marin Jakoli\x9a',
#    'position': 'FW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Jason Mbock',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Farid El Melali',
#    'position': 'FWDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Batista Mendy',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ibrahima Niane',
#    'position': 'FW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Zinédine Ould Khaled',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Azzedine Ounahi',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Lilian Raolisoa',
#    'position': 'MFDF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Halid \x8aabanovi?',
#    'position': 'DFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Amine Salama',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Abdallah Sima',
#    'position': 'FW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Waniss Taibi',
#    'position': 'MF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Sada Thioub',
#    'position': 'FWMF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Yan Valery',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23}],
#  'Lens': [{'player': 'Salis Abdul Samed',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Patrick Berg',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Ismaëlben Boura',
#    'position': 'DFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Adam Buksa',
#    'position': 'FWMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Jimmy Cabot',
#    'position': 'DFMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Alexis Claude-Maurice',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'David Pereira da Costa',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Kevin Danso',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Seko Fofana',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Steven Fortes',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Przemys?aw Frankowski',
#    'position': 'DFMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Angelo Fulgini',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Ignatius Ganago',
#    'position': 'FW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Jonathan Gradit',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Massadio Haïdara',
#    'position': 'DFMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Gaël Kakuta',
#    'position': 'FW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Rémy Labeau Lascary',
#    'position': 'FWMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Julien Le Cardinal',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Deiver Machado',
#    'position': 'DFMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Facundo Medina',
#    'position': 'DF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Jean Onana',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Loïs Openda',
#    'position': 'FW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': '?ukasz Por?ba',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Wesley Saïd',
#    'position': 'FWMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Brice Samba',
#    'position': 'GK',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Florian Sotoca',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Adrien Thomasson',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Christopher Wooh',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 21}],
#  'Lorient': [{'player': 'Laurent Abergel',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Adil Aouchiche',
#    'position': 'MFFW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Quentin Boisgard',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Igor Carioca',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Yoann Cathline',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Stéphane Diarra',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Bamba Dieng',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Ckene Doucouré',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Romain Faivre',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Adrian Grbi?',
#    'position': 'MFFW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Bonke Innocent',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Gedeon Kalulu',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Ibrahima Koné',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Julien Laporte',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Armand Lauriente',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Théo Le Bris',
#    'position': 'MFDF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Enzo Le Fée',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Vincent Le Goff',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Jean-Victor Makengo',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Vito Mannone',
#    'position': 'GK',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Chrislain Matsima',
#    'position': 'DFMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Bamo Meïté',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Terem Moffi',
#    'position': 'FW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Yvon Mvogo',
#    'position': 'GK',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Dango Ouattara',
#    'position': 'FWMF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Julien Ponceau',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Montassar Talbi',
#    'position': 'DF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Darlin Yongwa',
#    'position': 'FWDF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 22}],
#  'Hellas Verona': [{'player': 'Oliver Abildgaard',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Bruno Amione',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Antonín Barák',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Jayden Braaf',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Juan Cabal',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Federico Ceccherini',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Diego Coppola',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Alessandro Cortinovis',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Pawe? Dawidowicz',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Fabio Depaoli',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Josh Doig',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Ondrej Duda',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Davide Faraoni',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Adolfo Gaich',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Koray Günter',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Thomas Henry',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Isak Hien',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Martin Hongla',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Ajdin Hrustic',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Ivan Ili?',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Yayah Kallon',
#    'position': 'MFFW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Kevin Lasagna',
#    'position': 'FWMF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Darko Lazovi?',
#    'position': 'DFMF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Giangiacomo Magnani',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Lorenzo Montipò',
#    'position': 'GK',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Cyril Ngonge',
#    'position': 'FWMF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Roberto Piccoli',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Panagiotis Retsos',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Ibrahim Sulemana',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Adrien Tameze',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Filippo Terracciano',
#    'position': 'DFMF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Miguel Veloso',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 36},
#   {'player': 'Simone Verdi',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Milan ?uri?',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 32}],
#  'Auxerre': [{'player': 'Matthis Abline',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Mathias Autret',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Dénys Bain',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Quentin Bernard',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Kenji-Van Boto',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Ousmane Camara',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Gaëtan Charbonnier',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Alexandre Coeff',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Nuno da Costa',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Benoît Costil',
#    'position': 'GK',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Siriki Dembélé',
#    'position': 'FW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Rémy Dugimont',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Gauthier Hein',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Julian Jeanvier',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Paul Joly',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Jubal',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': "Youssouf M'Changama",
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Han-Noah Massengo',
#    'position': 'MFDF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Gideon Mensah',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': "M'Baye Niang",
#    'position': 'FW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Brayann Pereira',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Gaëtan Perrin',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Ionu? Radu',
#    'position': 'GK',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Rayan Raveloson',
#    'position': 'MFDF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Kays Ruiz',
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Hamza Sakhi',
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Lassine Sinayoko',
#    'position': 'MFFW',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Birama Touré',
#    'position': 'MF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Souleymane Touré',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Akim Zedadka',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 27}],
#  'Rennes': [{'player': 'Matthis Abline',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Doðan Alemdar',
#    'position': 'GK',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Lorenz Assignon',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Loïc Bade',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Jeanöel Belocian',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Benjamin Bourigeaud',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Alan Do Marcolino',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Jeremy Doku',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Désiré Doué',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Guela Doué',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Amine Gouiri',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Sehrou Guirassy',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Arnaud Kalimuendo',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Gaëtan Laborde',
#    'position': 'FW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Lovro Majer',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Steve Mandanda',
#    'position': 'GK',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 37},
#   {'player': 'Birger Meling',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Warmed Omari',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Joe Rodon',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Ibrahim Salah',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Baptiste Santamaria',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Djed Spence',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Kamaldeen Sulemana',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Flavien Tait',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Martin Terrier',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Arthur Theate',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Karl Toko Ekambi',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Hamari Traoré',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Adrien Truffert',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Chimuanya Ugochukwu',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Christopher Wooh',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Xeka',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 28}],
#  'Betis': [{'player': 'Abner',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Paul Akouokou',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Claudio Bravo',
#    'position': 'GK',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 39},
#   {'player': 'Sergio Canales',
#    'position': 'FWMF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'William Carvalho',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Juan Cruz',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Fran Delgado',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Nabil Fekir',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Luiz Felipe',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Felix Garreta',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Édgar González',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Roberto González',
#    'position': 'FWMF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Andrés Guardado',
#    'position': 'MFFW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 36},
#   {'player': 'Luiz Henrique',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Borja Iglesias',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Joaquín',
#    'position': 'MFFW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 41},
#   {'player': 'Willian José',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Juanmi',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Juan Miranda',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Martín Montoya',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Álex Moreno',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Loren Morón',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Ayoze Pérez',
#    'position': 'FW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Germán Pezzella',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Rodrigo',
#    'position': 'FWMF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Guido Rodríguez',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Aitor Ruibal',
#    'position': 'DFFW',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 26},
#   {'player': 'Víctor Ruiz',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Youssouf Sabaly',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29},
#   {'player': 'Rui Silva',
#    'position': 'GK',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 29}],
#  'Toulouse': [{'player': 'Zakaria Aboukhlal',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Yanis Begraoui',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Veljko Birman?evi?',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Fares Chaïbi',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Logan Costa',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Thijs Dallinga',
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Brecht Dejaegere',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Branco van den Boomen',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Mikkel Desler',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Moussa Diarra',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Maxime Dupé',
#    'position': 'GK',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Denis Genreau',
#    'position': 'MFFW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Rhys Healey',
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Waren Kamanzi',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Kévin Keben Biakolo',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Christian Mawissa',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': "Nathan N'Goumou",
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Rasmus Nicolaisen',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Ado Onaiwu',
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Rafael Ratão',
#    'position': 'FW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Anthony Rouault',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Vincent Sierro',
#    'position': 'MFFW',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Naatan Skyttä',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Stijn Spierings',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Gabriel Suazo',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Issiaga Sylla',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Theocharis Tsingaras',
#    'position': 'MF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Oliver Zandén',
#    'position': 'DFMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21}],
#  'Roma': [{'player': 'Tammy Abraham',
#    'position': 'FW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Andrea Belotti',
#    'position': 'FW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Edoardo Bove',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Mohamed Camara',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Zeki Çelik',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Bryan Cristante',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Paulo Dybala',
#    'position': 'MFFW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Roger Ibanez',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Rick Karsdorp',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Marash Kumbulla',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Diego Llorente',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Gianluca Mancini',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Nemanja Mati?',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'Rui Patrício',
#    'position': 'GK',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'Lorenzo Pellegrini',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Stephan El Shaarawy',
#    'position': 'DFMF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Eldor Shomurodov',
#    'position': 'FW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Chris Smalling',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 33},
#   {'player': 'Ola Solbakken',
#    'position': 'MFFW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Leonardo Spinazzola',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Benjamin Tahirovic',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Matías Viña',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Cristian Volpato',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Georginio Wijnaldum',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Nicola Zalewski',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Nicolò Zaniolo',
#    'position': 'MFFW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 23}],
#  'Inter': [{'player': 'Francesco Acerbi',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 35},
#   {'player': 'Kristjan Asllani',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Nicolò Barella',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Alessandro Bastoni',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Raoul Bellanova',
#    'position': 'DFMF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Marcelo Brozovi?',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 30},
#   {'player': 'Hakan Çalhanoðlu',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Valentin Carboni',
#    'position': 'MFFW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 17},
#   {'player': 'Joaquín Correa',
#    'position': 'FW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': "Danilo D'Ambrosio",
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'Matteo Darmian',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 33},
#   {'player': 'Federico Dimarco',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Denzel Dumfries',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Edin D?eko',
#    'position': 'FW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 36},
#   {'player': 'Roberto Gagliardini',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Robin Gosens',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Samir Handanovi?',
#    'position': 'GK',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 38},
#   {'player': 'Romelu Lukaku',
#    'position': 'FW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Lautaro Martínez',
#    'position': 'FW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Henrikh Mkhitaryan',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'André Onana',
#    'position': 'GK',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Milan \x8akriniar',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Stefan de Vrij',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 31}],
#  'Nantes': [{'player': 'Mohamed Achi',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Dennis Appiah',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Ludovic Blas',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Jean-Charles Castelletto',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Fabien Centonze',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Pedro Chirivella',
#    'position': 'MF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Marcus Coco',
#    'position': 'DFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Sébastien Corchia',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Andy Delort',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Rémy Descamps',
#    'position': 'GK',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Lohann Doucet',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Fábio',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Ignatius Ganago',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Andrei Girotto',
#    'position': 'DFMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Evann Guessand',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Jaouen Hadjam',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Abdoul Kader Bamba',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 28},
#   {'player': 'Alban Lafont',
#    'position': 'GK',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Quentin Merlin',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Mostafa Mohamed',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Florent Mollet',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Samuel Moutoussamy',
#    'position': 'MF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Nicolas Pallois',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Moses Simon',
#    'position': 'FWMF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Moussa Sissoko',
#    'position': 'MF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': 'Charles Traore',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'João Victor',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Nathan Zeze',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 17}],
#  'Sevilla': [{'player': 'Marcos Acuña',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Carlos Álvarez',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Loïc Bade',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Yassine Bounou',
#    'position': 'GK',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Bryan',
#    'position': 'DFMF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Carmona',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Jesús Corona',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Thomas Delaney',
#    'position': 'MF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Marko Dmitrovi?',
#    'position': 'GK',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Kasper Dolberg',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Youssef En-Nesyri',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Fernando',
#    'position': 'MFDF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 35},
#   {'player': 'Papu Gómez',
#    'position': 'MFFW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Nemanja Gudelj',
#    'position': 'DFMF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Pape Gueye',
#    'position': 'MF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Isco',
#    'position': 'MFFW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Adnan Januzaj',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Joan Jordán',
#    'position': 'MF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Érik Lamela',
#    'position': 'FWMF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 30},
#   {'player': 'Marcão',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 26},
#   {'player': 'Rafa Mir',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Gonzalo Montiel',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 26},
#   {'player': 'Jesús Navas',
#    'position': 'DFFW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 37},
#   {'player': 'Tanguy Nianzou',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Lucas Ocampos',
#    'position': 'FWMF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 28},
#   {'player': 'Pedro Ortiz',
#    'position': 'MF',
# ...
#   {'player': 'Oscar Ureña',
#    'position': 'MF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Valery',
#    'position': 'MFDF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Manu Vallejo',
#    'position': 'FWMF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Toni Villa',
#    'position': 'MFFW',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 28}],
#  'Brighton': [{'player': 'Facundo Buonanotte',
#    'position': 'MFFW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Moisés Caicedo',
#    'position': 'MF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Julio César Enciso',
#    'position': 'FWMF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Levi Colwill',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Lewis Dunk',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Pervis Estupiñán',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Evan Ferguson',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Billy Gilmour',
#    'position': 'MF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Pascal Groß',
#    'position': 'MFDF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Jan Paul van Hecke',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Adam Lallana',
#    'position': 'MFFW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 34},
#   {'player': 'Tariq Lamptey',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Alexis Mac Allister',
#    'position': 'MF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Solly March',
#    'position': 'FWDF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 28},
#   {'player': 'Kaoru Mitoma',
#    'position': 'FWDF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Andrew Moran',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Enock Mwepu',
#    'position': 'FWMF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Robert Sánchez',
#    'position': 'GK',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Jeremy Sarmiento',
#    'position': 'MF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Leandro Trossard',
#    'position': 'FWMF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 28},
#   {'player': 'Deniz Undav',
#    'position': 'FWMF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Joël Veltman',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Adam Webster',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 28},
#   {'player': 'Danny Welbeck',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 32}],
#  'Montpellier': [{'player': 'Matis Carvalho',
#    'position': 'GK',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Joris Chotard',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Nicolas Cozza',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Sacha Delaye',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Sepe Elye Wahi',
#    'position': 'FW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Maxime Estève',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Khalil Fayad',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Cheikh Faye',
#    'position': 'FW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jordan Ferri',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 30},
#   {'player': 'Valère Germain',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Axel Gueguin',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Christopher Jullien',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Bingourou Kamara',
#    'position': 'GK',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 26},
#   {'player': 'Wahbi Khazri',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Boubakar Kouyaté',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Benjamin Lecomte',
#    'position': 'GK',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Léo Leroy',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Béni Makouana',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Faitout Maouassa',
#    'position': 'DFFW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Stephy Mavididi',
#    'position': 'FW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Arnaud Nordin',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Jonas Omlin',
#    'position': 'GK',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Falaye Sacko',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 27},
#   {'player': 'Théo Sainte-Luce',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Mamadou Sakho',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Téji Savanier',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Arnaud Souquet',
#    'position': 'DFFW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Issiaga Sylla',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 29},
#   {'player': 'Enzo Tchato',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 20}],
#  'Napoli': [{'player': 'Diego Demme',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Giovanni Di Lorenzo',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Elif Elmas',
#    'position': 'FWMF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Gianluca Gaetano',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Juan Jesus',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Khvicha Kvaratskhelia',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Stanislav Lobotka',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Hirving Lozano',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Alex Meret',
#    'position': 'GK',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Kim Min-jae',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Tanguy Ndombele',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Mathías Olivera',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Victor Osimhen',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Adam Ounas',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 26},
#   {'player': 'Matteo Politano',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 29},
#   {'player': 'Giacomo Raspadori',
#    'position': 'FWMF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Amir Rrahmani',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 28},
#   {'player': 'Mário Rui',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Giovanni Simeone',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Leo Skiri Østigård',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Andre-Frank Zambo Anguissa',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 27},
#   {'player': 'Alessandro Zanoli',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Alessio Zerbin',
#    'position': 'FW',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Piotr Zieli?ski',
#    'position': 'MF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 28}],
#  'Freiburg': [{'player': 'Ritsu Doan',
#    'position': 'FWMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Maximilian Eggestein',
#    'position': 'MF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Mark Flekken',
#    'position': 'GK',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Matthias Ginter',
#    'position': 'DF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Michael Gregoritsch',
#    'position': 'FW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 28},
#   {'player': 'Vincenzo Grifo',
#    'position': 'FWMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Manuel Gulde',
#    'position': 'DFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Christian Günter',
#    'position': 'DFMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 29},
#   {'player': 'Nicolas Höfler',
#    'position': 'MF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Lucas Höler',
#    'position': 'FWMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 28},
#   {'player': 'Yannik Keitel',
#    'position': 'MF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Lukas Kübler',
#    'position': 'DF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 30},
#   {'player': 'Daniel Kyereh',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Philipp Lienhart',
#    'position': 'DF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 26},
#   {'player': 'Nils Petersen',
#    'position': 'FW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Roland Sallai',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Kevin Schade',
#    'position': 'FWMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Keven Schlotterbeck',
#    'position': 'DF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Kiliann Sildillia',
#    'position': 'DFMF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Hugo Siquet',
#    'position': 'DF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Robert Wagner',
#    'position': 'MF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Noah Weißhaupt',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Jeong Woo-yeong',
#    'position': 'MFFW',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 23}],
#  'Arsenal': [{'player': 'Gabriel Dos Santos',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Mohamed Elneny',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 30},
#   {'player': 'Rob Holding',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 27},
#   {'player': 'Gabriel Jesus',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Jorginho',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Marquinhos',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Martinelli',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Reiss Nelson',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Eddie Nketiah',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Ethan Nwaneri',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 15},
#   {'player': 'Thomas Partey',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 29},
#   {'player': 'Aaron Ramsdale',
#    'position': 'GK',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Bukayo Saka',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'William Saliba',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Albert Sambi Lokonga',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Emile Smith Rowe',
#    'position': 'MFFW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Cédric Soares',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Kieran Tierney',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Takehiro Tomiyasu',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Leandro Trossard',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 28},
#   {'player': 'Fabio Vieira',
#    'position': 'MFFW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Ben White',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Granit Xhaka',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 30},
#   {'player': 'Oleksandr Zinchenko',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 26},
#   {'player': 'Martin Ødegaard',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 24}]}

# %% [markdown]
# ### 10. Calculate the average age of players for each competition.
#
# Create a new variable named average_age_by_competition that contains the average age for each competition. The competitions should be the keys, and the values should be the average ages rounded to one decimal place.
#
# Example of expected output:
#
# <code>
# {
#     'Premier League': 27.5,
#     'La Liga': 26.8,
#     'Bundesliga': 25.9,
#     ...
# }
# </code>
#
# * Note that, the value for age is rounded to the nearest 1 decimal point

# %%
from numpy import mean


average_age_by_competition = {}

for player in players:
    competition = player[4]
    age = player[5]

    if competition in average_age_by_competition:
        average_age_by_competition[competition].append(age)
    else:
        average_age_by_competition[competition] = [age]

for competition, ages in average_age_by_competition.items():
    average_age_by_competition[competition] = round(mean(ages), 1)

average_age_by_competition
# Out:
# {'Premier League': 26.0,
#  'Ligue 1': 25.3,
#  'Serie A': 26.0,
#  'La Liga': 26.9,
#  'Bundesliga': 25.8}

# %% [markdown]
# ### 11. Transform the players data to dict-of-dict.
#
# Transform the dataset to create a new variable named average_stats_by_position. This variable should contain the average values of goals, assists, and shots on target (SoT) for each position across all players. The positions should be the keys, and the values should be dictionaries with the keys goals, assists, and sot, representing the average values for each statistic.
#
# Example of expected output:
#
# <code>
# {
#     'FW': {'goals': 12.5, 'assists': 5.3, 'sot': 8.1},
#     'MF': {'goals': 6.2, 'assists': 8.7, 'sot': 3.9},
#     'DF': {'goals': 2.8, 'assists': 3.1, 'sot': 1.6},
#     ...
# }
# </code>
#
# * Note that, the values for goals, assists, sot are rounded to the nearest 1 decimal point

# %%
position_stats = {}

for player in players:
    name, nation, pos, squad, comp, *rest, goals, shots, sot, assists = player
    goals = float(goals) 
    assists = float(assists)
    shots = float(shots)
    sot = float(sot)

    # Check if the position is already in the 'position_stats' dictionary
    if pos in position_stats:
        position_stats[pos]['goals'] += goals
        position_stats[pos]['assists'] += assists
        position_stats[pos]['shots'] += shots
        position_stats[pos]['sot'] += sot
        position_stats[pos]['count'] += 1
    else:
        # If the position is not in the 'position_stats' dictionary, add it
        position_stats[pos] = {
            'goals': goals,
            'assists': assists,
            'shots': shots,
            'sot': sot,
            'count': 1
        }


# Calculate the average stats for each position
average_stats_by_position = {}
for pos, stats in position_stats.items():
    average_stats_by_position[pos] = {
        'goals': round(stats['goals'] / stats['count'], 1),
        'assists': round(stats['assists'] / stats['count'], 1),
        'sot': round(stats['sot'] / stats['count'], 1)
    }


average_stats_by_position
# Out:
# {'MFFW': {'goals': 1.5, 'assists': 0.1, 'sot': 0.6},
#  'DF': {'goals': 0.4, 'assists': 0.0, 'sot': 0.1},
#  'MF': {'goals': 0.8, 'assists': 0.1, 'sot': 0.4},
#  'FWMF': {'goals': 2.0, 'assists': 0.1, 'sot': 0.8},
#  'FW': {'goals': 2.6, 'assists': 0.1, 'sot': 0.8},
#  'DFFW': {'goals': 0.4, 'assists': 0.1, 'sot': 0.3},
#  'MFDF': {'goals': 0.5, 'assists': 0.0, 'sot': 0.3},
#  'GK': {'goals': 0.0, 'assists': 0.0, 'sot': 0.0},
#  'DFMF': {'goals': 0.6, 'assists': 0.1, 'sot': 0.3},
#  'FWDF': {'goals': 1.2, 'assists': 0.1, 'sot': 0.7}}

# %% [markdown]
# ## Transformations/ Aggregations

# %% [markdown]
# ### 12. Calculate total goals per Competition
#
# Create a dictionary containing each competition as key, and the sum of all the goals scored as a value. Store the result in the variable goals_per_comp. It should look something like:
#
# <code>
#     {
#         'Premier League': ...,
#         'Serie A': ...,
#         ...
#         'Bundesliga': ...
#     }
# </code>

# %%
goals_per_comp = {}
for player in players:
    name, nation, pos, squad, comp, *rest, goals, shots, sot, assists = player
    goals = int(goals)
    goals_per_comp.setdefault(comp, 0)
    goals_per_comp[comp] += goals
goals_per_comp
# Out:
# {'Premier League': 564,
#  'Ligue 1': 618,
#  'Serie A': 538,
#  'La Liga': 480,
#  'Bundesliga': 563}

# %% [markdown]
# ### 13. Calculate the total number of minutes played by each squad across all competitions.
#
# Create a dictionary named total_minutes_by_squad where the keys are the squad names, and the values are the total minutes played by that squad.
#
# Example of expected output:
#
# <code>
# {
#     'Manchester United': 4578,
#     'Real Madrid': 5123,
#     'Bayern Munich': 3984,
#     ...
# }
#
# </code>

# %%
total_minuets_by_squad = {}
for player in players:
    name, nation, pos, squad, *rest = player
    minutes = player[-5]
    total_minuets_by_squad.setdefault(squad, 0)
    total_minuets_by_squad[squad] += minutes
total_minuets_by_squad
# Out:
# {'Leeds United': 20743,
#  'Reims': 21502,
#  'Angers': 21611,
#  'Lens': 21755,
#  'Lorient': 21751,
#  'Hellas Verona': 20671,
#  'Auxerre': 21603,
#  'Rennes': 21754,
#  'Betis': 20524,
#  'Toulouse': 21731,
#  'Roma': 21780,
#  'Inter': 20739,
#  'Nantes': 21675,
#  'Sevilla': 20604,
#  'Southampton': 21780,
#  'Köln': 18690,
#  'Fulham': 22687,
#  'Dortmund': 19800,
#  'Leverkusen': 19764,
#  'Milan': 21735,
#  'Bologna': 20731,
#  'Cremonese': 20743,
#  'Troyes': 21704,
#  'Werder Bremen': 19723,
#  'Valladolid': 19791,
#  'Spezia': 21720,
#  'West Ham': 21780,
#  'Monaco': 22554,
#  'Crystal Palace': 21689,
#  'Stuttgart': 19719,
#  'Strasbourg': 21595,
#  'Celta Vigo': 19708,
#  'Torino': 21780,
#  'Wolves': 21611,
#  'Brentford': 21780,
#  'Mainz 05': 19750,
#  'Manchester City': 20725,
#  'Almería': 20782,
#  'Empoli': 21653,
#  'Hoffenheim': 19724,
#  'Real Madrid': 19799,
#  'Cádiz': 20690,
#  'Eint Frankfurt': 18787,
#  'Barcelona': 19725,
#  'Lazio': 21695,
#  'Villarreal': 19765,
#  'Leicester City': 21780,
#  'Liverpool': 19766,
#  'Getafe': 19782,
#  'Elche': 19520,
#  'Real Sociedad': 19726,
#  'Clermont Foot': 22726,
#  'Everton': 20790,
#  'Valencia': 20723,
#  'Newcastle Utd': 21780,
#  'Ajaccio': 22626,
#  'Schalke 04': 19744,
#  'Sassuolo': 20736,
#  'Athletic Club': 20724,
#  'Mallorca': 20784,
#  'Sampdoria': 20738,
#  'Fiorentina': 20722,
#  'Lille': 21763,
#  'Bournemouth': 21780,
#  'Manchester Utd': 21759,
#  'Monza': 20789,
#  'Bochum': 19800,
#  'Lyon': 21699,
#  'Aston Villa': 20761,
#  'Brest': 21739,
#  'Wolfsburg': 19800,
#  'Chelsea': 21677,
#  'Udinese': 20744,
#  'Lecce': 21711,
#  'Nice': 22660,
#  "Nott'ham Forest": 21780,
#  'Osasuna': 19670,
#  'RB Leipzig': 19754,
#  'Marseille': 22732,
#  'Rayo Vallecano': 19721,
#  'Espanyol': 19617,
#  'Atlético Madrid': 19757,
#  'Augsburg': 19753,
#  'Union Berlin': 19728,
#  "M'Gladbach": 18772,
#  'Tottenham': 22737,
#  'Paris S-G': 22659,
#  'Bayern Munich': 19762,
#  'Hertha BSC': 18788,
#  'Atalanta': 21717,
#  'Salernitana': 20771,
#  'Juventus': 20736,
#  'Girona': 20777,
#  'Brighton': 20790,
#  'Montpellier': 21555,
#  'Napoli': 20790,
#  'Freiburg': 19726,
#  'Arsenal': 20790}

# %% [markdown]
# ### 14. Determine the average number of starts for players in each competition.
#
# Create a dictionary named average_starts_per_comp where the keys are the competition names, and the values are the average number of starts rounded to the nearest whole number.
#
# Example of expected output:
#
# <code>
# {
#     'Premier League': 23,
#     'La Liga': 19,
#     'Bundesliga': 21,
#     ...
# }
# </code>

# %%
starts_by_comp = {}
for player in players:
    name, nation, pos, squad, comp, age, born, mp, starts, *rest = player
    starts_by_comp.setdefault(comp, []).append(int(starts))

average_starts_per_comp = {}
for comp, starts_list in starts_by_comp.items():
    average_starts = round(sum(starts_list) / len(starts_list))
    average_starts_per_comp[comp] = average_starts

average_starts_per_comp
# Out:
# {'Premier League': 9,
#  'Ligue 1': 9,
#  'Serie A': 9,
#  'La Liga': 8,
#  'Bundesliga': 8}

# %% [markdown]
# ### 15. Calculate the max scorers per competition.
#
# Find the top scorers of each competition (maximum number of goals scored). Store your results in the variable top_scorers_per_comp. Attention! There might be more than one top scorer in the league, so your result should be a list of dictionaries containing each player and their goals as a tuple.
#
# Example:
#
# <code>
# {
#     "Ligue 1": [
#         ("Lionel Messi", 14),
#         ("Kylian Mbappe", 14),
#     ],
#     'La Liga': [
#         ('Robert Lewandowski', 18)
#     ]
# }
# </code>

# %%
top_scorers_per_comp = {}
for player in players:
    name,  nation, pos, squad, comp, *rest = player
    goals = player[-4]
    if comp not in top_scorers_per_comp:
        top_scorers_per_comp[comp] = [(name, goals)]
        continue
    current_scorers = top_scorers_per_comp[comp]
    current_top_goals = current_scorers[0][1]
    if goals > current_top_goals:
        top_scorers_per_comp[comp] = [(name, goals)]
    elif goals == current_top_goals:
        top_scorers_per_comp[comp].append((name, goals))
top_scorers_per_comp
# Out:
# {'Premier League': [('Erling Haaland', 25)],
#  'Ligue 1': [('Folarin Balogun', 14), ('Wissam Ben Yedder', 14)],
#  'Serie A': [('Victor Osimhen', 16)],
#  'La Liga': [('Robert Lewandowski', 14)],
#  'Bundesliga': [('Niclas Füllkrug', 13)]}

# %% [markdown]
# ### 16. Convert the dataset into a new format - List of Dictionaries.
#
# Create a list named goals_and_assists_by_player which is a list of dictionaries. Each dictionary should contain the keys player, competition, goals, and assists.
#
# Example of expected output:
#
# <code>
# [
#     {'player': 'Harry Kane', 'competition': 'Premier League', 'goals': 25, 'assists': 12},
#     {'player': 'Lionel Messi', 'competition': 'La Liga', 'goals': 30, 'assists': 18},
#     {'player': 'Cristiano Ronaldo', 'competition': 'Serie A', 'goals': 27, 'assists': 10},
#     ...
# ]
# </code>

# %%
goals_and_assists_by_player = []

for player in players:
    name, nation, pos, squad, comp, age, born, mp, starts, mins, goals, shots, sot, assists = player
    goals_and_assists_by_player.append({
        'player': name,
        'competition': comp,
        'goals': goals,
        'assists': assists
    })

goals_and_assists_by_player
# Out:
# [{'player': 'Brenden Aaronson',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.11},
#  {'player': 'Yunis Abdelhamid',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Himad Abdelli',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Salis Abdul Samed',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Laurent Abergel',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.08},
#  {'player': 'Oliver Abildgaard',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Matthis Abline',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Matthis Abline',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Abner', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Zakaria Aboukhlal',
#   'competition': 'Ligue 1',
#   'goals': 5,
#   'assists': 0.24},
#  {'player': 'Tammy Abraham',
#   'competition': 'Serie A',
#   'goals': 6,
#   'assists': 0.17},
#  {'player': 'Francesco Acerbi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.08},
#  {'player': 'Mohamed Achi',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marcos Acuña',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.09},
#  {'player': 'Che Adams',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.11},
#  {'player': 'Tyler Adams',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sargis Adamyan',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.19},
#  {'player': 'Tosin Adarabioyo',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Martin Adeline',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Karim Adeyemi',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.12},
#  {'player': 'Amine Adli',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.28},
#  {'player': 'Yacine Adli',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Michel Aebischer',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Felix Afena-Gyan',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Emmanuel Agbadou',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.11},
#  {'player': 'Lucien Agoume',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Felix Agu',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Álvaro Aguado',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.16},
#  {'player': 'Kevin Agudelo',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Nayef Aguerd',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ruben Aguilar',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Naouirou Ahamada',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Naouirou Ahamada',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.13},
#  {'player': 'Amar Ahmed',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jean-Eudes Aholou',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Joseph Aidoo',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Ola Aina', 'competition': 'Serie A', 'goals': 1, 'assists': 0.13},
#  {'player': 'Rayan Aït Nouri',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Emanuel Aiwum',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kristoffer Ajer',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ludovic Ajorque',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Ludovic Ajorque',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.38},
#  {'player': 'Manuel Akanji',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Nathan Aké',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergio Akieme',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Maghnes Akliouche',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Paul Akouokou',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jean-Daniel Akpa-Akpro',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kevin Akpoguma',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'David Alaba',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.2},
#  {'player': 'Tomás Alarcón',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Lucas Alario',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Jordi Alba',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.29},
#  {'player': 'Luis Alberto',
#   'competition': 'Serie A',
#   'goals': 4,
#   'assists': 0.26},
#  {'player': 'Raúl Albiol',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marc Albrighton',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Thiago Alcántara',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carlos Alcaraz',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Rubén Alcaraz',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Omar Alderete',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Iván Alejo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.12},
#  {'player': 'Doðan Alemdar',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carles Aleñá',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.12},
#  {'player': 'Trent Alexander-Arnold',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.06},
#  {'player': 'Alejandro Alfaro',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ángel Algobia',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mohamed Ali Cho',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.57},
#  {'player': 'Faride Alidou',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alisson',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Jim Allevinah',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Dele Alli',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Domingos André Ribeiro Almeida',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.22},
#  {'player': 'Miguel Almirón',
#   'competition': 'Premier League',
#   'goals': 10,
#   'assists': 0.05},
#  {'player': 'Marcos Alonso',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mickaël Alphonse',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Éder Álvarez Balanta',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carlos Álvarez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gastón Álvarez',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Julián Álvarez',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.0},
#  {'player': 'Agustín Álvarez Martínez',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.3},
#  {'player': 'Yeray Álvarez',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.06},
#  {'player': 'Ibrahim Amadou',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Daniel Amartey',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Amath', 'competition': 'La Liga', 'goals': 1, 'assists': 0.0},
#  {'player': 'Jordan Amavi',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kelvin Amian',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.09},
#  {'player': 'Bruno Amione',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Bruno Amione',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.11},
#  {'player': 'Nadiem Amiri',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.14},
#  {'player': 'Ethan Ampadu',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Sofyan Amrabat',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Joachim Andersen',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Elliot Anderson',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Felipe Anderson',
#   'competition': 'Serie A',
#   'goals': 6,
#   'assists': 0.11},
#  {'player': 'Benjamin André',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.05},
#  {'player': 'Komnen Andri?',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.14},
#  {'player': 'Robert Andrich',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.13},
#  {'player': 'Angeliño',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.28},
#  {'player': 'Fabrizio Angileri',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jaidon Anthony',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Janis Antiste',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Waldemar Anton',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Marcos Antônio',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Michail Antonio',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.17},
#  {'player': 'Antony',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Valentin Antov',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Christopher Antwi-Adjei',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.68},
#  {'player': 'Anuar', 'competition': 'La Liga', 'goals': 1, 'assists': 0.0},
#  {'player': 'Houssem Aouar',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.22},
#  {'player': 'Adil Aouchiche',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dennis Appiah',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mauro Arambarri',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.15},
#  {'player': 'Charles Aránguiz',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Ronald Araújo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.11},
#  {'player': 'Cameron Archer',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Taïryk Arconte',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alphonse Areola',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Joe Aribo',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Adam Armstrong',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.09},
#  {'player': 'Stuart Armstrong',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Marko Arnautovi?',
#   'competition': 'Serie A',
#   'goals': 8,
#   'assists': 0.0},
#  {'player': 'Maximilian Arnold',
#   'competition': 'Bundesliga',
#   'goals': 4,
#   'assists': 0.1},
#  {'player': 'Kepa Arrizabalaga',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Roberto Arroyo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Tolgay Arslan',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Arthur', 'competition': 'Serie A', 'goals': 3, 'assists': 0.14},
#  {'player': 'Santiago Arzamendia',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Takuma Asano',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Santiago Ascacíbar',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergio Asenjo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marco Asensio',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.54},
#  {'player': 'Kristoffer Askildsen',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fisnik Asllani',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kristjan Asllani',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Iago Aspas',
#   'competition': 'La Liga',
#   'goals': 9,
#   'assists': 0.16},
#  {'player': 'Lorenz Assignon',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.45},
#  {'player': 'Youcef Atal',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Pierre-Emerick Aubameyang',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Pierre-Emerick Aubameyang',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Emil Audero',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Tommaso Augello',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.11},
#  {'player': 'Ludwig Augustinsson',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ludwig Augustinsson',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Serge Aurier',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mathias Autret',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.15},
#  {'player': 'Ezequiel Ávila',
#   'competition': 'La Liga',
#   'goals': 7,
#   'assists': 0.16},
#  {'player': 'Cédric Avinel',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Taiwo Awoniyi',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.0},
#  {'player': 'Mehmet-Can Aydin',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'André Ayew',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jordan Ayew',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.06},
#  {'player': 'Kaan Ayhan',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Luke Ayling',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.13},
#  {'player': 'Ayman Azhil',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sardar Azmoun',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'César Azpilicueta',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sanoussy Ba',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Iddrisu Baba',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sr?an Babi?',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Loïc Bade', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Loïc Bade', 'competition': 'Ligue 1', 'goals': 0, 'assists': 1.0},
#  {'player': 'Édgar Badía',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Benoît Badiashile',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Benoît Badiashile',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Alex Baena',
#   'competition': 'La Liga',
#   'goals': 4,
#   'assists': 0.09},
#  {'player': 'Jaime Báez',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Leon Bailey',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.14},
#  {'player': 'Eric Bailly',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dénys Bain',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Brandon Baiye',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Stefan Bajcetic',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Nedim Bajrami',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.1},
#  {'player': 'Nedim Bajrami',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Cédric Bakambu',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 1.43},
#  {'player': 'Mitchel Bakker',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.09},
#  {'player': 'Ridle Baku',
#   'competition': 'Bundesliga',
#   'goals': 5,
#   'assists': 0.05},
#  {'player': 'Tommaso Baldanzi',
#   'competition': 'Serie A',
#   'goals': 4,
#   'assists': 0.0},
#  {'player': 'Alejandro Balde',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.3},
#  {'player': 'Thierno Balde',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carlos Baleba',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mikel Balenziaga',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Leonardo Balerdi',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Iván Balliu',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fodé Ballo-Touré',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Folarin Balogun',
#   'competition': 'Ligue 1',
#   'goals': 14,
#   'assists': 0.06},
#  {'player': 'Abdoulaye Bamba',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jonathan Bamba',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.19},
#  {'player': 'Patrick Bamford',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.3},
#  {'player': 'Lameck Banda',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.09},
#  {'player': 'Filippo Bandinelli',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Léo Baptistão',
#   'competition': 'La Liga',
#   'goals': 3,
#   'assists': 0.1},
#  {'player': 'Shandon Baptiste',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Antonín Barák',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Antonín Barák',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Andrea Barberis',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.29},
#  {'player': 'Bradley Barcola',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.27},
#  {'player': 'Melvin Bard',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Keidi Bare',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Nicolò Barella',
#   'competition': 'Serie A',
#   'goals': 5,
#   'assists': 0.28},
#  {'player': 'Kike Barja',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.23},
#  {'player': 'Ross Barkley',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.15},
#  {'player': 'Aymen Barkok',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.29},
#  {'player': 'Harvey Barnes',
#   'competition': 'Premier League',
#   'goals': 8,
#   'assists': 0.05},
#  {'player': 'Leandro Barreiro Martins',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.17},
#  {'player': 'Ander Barrenetxea',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mickaël Barreto',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.26},
#  {'player': 'Pablo Barrios',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Musa Barrow',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.12},
#  {'player': 'Federico Baschirotto',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Toma Ba\x9ai?',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gil Bastião Dias',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alessandro Bastoni',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Simone Bastoni',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.19},
#  {'player': 'Rodrigo Battaglia',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Maximilian Bauer',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Oliver Baumann',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Timo Baumgartl',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Julian Baumgartlinger',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Christoph Baumgartner',
#   'competition': 'Bundesliga',
#   'goals': 5,
#   'assists': 0.17},
#  {'player': 'Cyrille Bayala',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.07},
#  {'player': 'Brian Bayeye',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Noah Joel Sarenren Bazee',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gavin Bazunu',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Bebé', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Ihlas Bebou',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Rodrigo Becão',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.07},
#  {'player': 'Mads Bech Sørensen',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Julius Beck',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sheraldo Becker',
#   'competition': 'Bundesliga',
#   'goals': 7,
#   'assists': 0.25},
#  {'player': 'Jan Bednarek',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jan Bednarek',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Donny van de Beek',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Asmir Begovi?',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yanis Begraoui',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kevin Behrens',
#   'competition': 'Bundesliga',
#   'goals': 4,
#   'assists': 0.12},
#  {'player': 'Alexis Beka Beka',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jérémie Bela',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.14},
#  {'player': 'Youcef Belaïli',
#   'competition': 'Ligue 1',
#   'goals': 5,
#   'assists': 0.34},
#  {'player': 'Youcef Belaïli',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.5},
#  {'player': 'Haris Belkebla',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Stefan Bell',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Armel Bella Kotchap',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.09},
#  {'player': 'Raoul Bellanova',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Karim Bellarabi',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jean-Ricner Bellegarde',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.28},
#  {'player': 'Héctor Bellerín',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jude Bellingham',
#   'competition': 'Bundesliga',
#   'goals': 4,
#   'assists': 0.21},
#  {'player': 'Jeanöel Belocian',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Andrea Belotti',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fran Beltrán',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.06},
#  {'player': 'Eliesse Ben Seghir',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.19},
#  {'player': 'Salim Ben Seghir',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Wissam Ben Yedder',
#   'competition': 'Ligue 1',
#   'goals': 14,
#   'assists': 0.24},
#  {'player': 'Marco Benassi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marco Benassi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ismaël Bennacer',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.06},
#  {'player': 'Saïd Benrahma',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.08},
#  {'player': 'Ramy Bensebaini',
#   'competition': 'Bundesliga',
#   'goals': 5,
#   'assists': 0.0},
#  {'player': 'Nabil Bentaleb',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.18},
#  {'player': 'Rodrigo Bentancur',
#   'competition': 'Premier League',
#   'goals': 5,
#   'assists': 0.12},
#  {'player': 'Karim Benzema',
#   'competition': 'La Liga',
#   'goals': 9,
#   'assists': 0.26},
#  {'player': 'Domenico Berardi',
#   'competition': 'Serie A',
#   'goals': 4,
#   'assists': 0.29},
#  {'player': 'Yuri Berchiche',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Álex Berenguer',
#   'competition': 'La Liga',
#   'goals': 3,
#   'assists': 0.07},
#  {'player': 'Bartosz Bereszy?ski',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Patrick Berg',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mitchell van Bergen',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Mergim Berisha',
#   'competition': 'Bundesliga',
#   'goals': 6,
#   'assists': 0.31},
#  {'player': 'Quentin Bernard',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Paul Bernardoni',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Juan Bernat',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.18},
#  {'player': 'Victor Bernth Kristiansen',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jason Berthomier',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Beto', 'competition': 'Serie A', 'goals': 7, 'assists': 0.07},
#  {'player': 'Owen Bevan',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Matteo Bianchetti',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Alessandro Bianco',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Giulian Biancone',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ermin Bi?ak?i?',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Pedro Bigas',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jaka Bijol',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'El Bilal Touré',
#   'competition': 'La Liga',
#   'goals': 4,
#   'assists': 0.19},
#  {'player': 'El Bilal Touré',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Philip Billing',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.06},
#  {'player': 'Jean-Claude Billong',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Cristiano Biraghi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.11},
#  {'player': 'Samuele Birindelli',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Veljko Birman?evi?',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Tom Bischof',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yves Bissouma',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kristijan Bistrovi?',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Leonardo Bittencourt',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Marco Bizot',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Blanco', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Lautaro Blanco',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.38},
#  {'player': 'Rubén Blanco',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ludovic Blas',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.05},
#  {'player': 'Janis Blaswich',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Miha Bla?i?',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Joaquín Blázquez',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alexis Blin',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Daley Blind',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Myron Boadu',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Jérôme Boateng',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kevin-Prince Boateng',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Antonin Bobichon',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jean-Paul Boëtius',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jeremie Boga',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 1.14},
#  {'player': 'Emil Bohinen',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Quentin Boisgard',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Willy Boly',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.15},
#  {'player': 'Giacomo Bonaventura',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Federico Bonazzoli',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.1},
#  {'player': 'Warren Bondo',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Theo Bongonda',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.22},
#  {'player': 'Kevin Bonifazi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Leonardo Bonucci',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Neto Borges',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Yvandro Borges Sanches',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sebastiaan Bornauw',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Rafael Borré',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.36},
#  {'player': 'Erik Botheim',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.27},
#  {'player': 'Sven Botman',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kenji-Van Boto',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kouamé Botué',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Badredine Bouanani',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 1.5},
#  {'player': 'Hicham Boudaoui',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.12},
#  {'player': 'Franci Bouebari',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sofiane Boufal',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.32},
#  {'player': 'Wassim Boullif',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yassine Bounou',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ismaëlben Boura',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mehdi Bourabia',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.11},
#  {'player': 'Benjamin Bourigeaud',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.26},
#  {'player': 'Edoardo Bove',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jarrod Bowen',
#   'competition': 'Premier League',
#   'goals': 4,
#   'assists': 0.05},
#  {'player': 'Lucas Boyé',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.15},
#  {'player': 'Jayden Braaf',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Domagoj Bradari?',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.09},
#  {'player': 'Bilal Brahimi',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.4},
#  {'player': 'Martin Braithwaite',
#   'competition': 'La Liga',
#   'goals': 5,
#   'assists': 0.08},
#  {'player': 'Juan Brandáriz',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Julian Brandt',
#   'competition': 'Bundesliga',
#   'goals': 6,
#   'assists': 0.24},
#  {'player': 'Darko Bra\x9aanac',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.12},
#  {'player': 'Lilian Brassier',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Claudio Bravo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fabian Bredlow',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'James Bree',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Josip Brekalo',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Josip Brekalo',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.33},
#  {'player': 'Gleison Bremer',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Armando Broja',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Dylan Bronn',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'John Brooks',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Moritz Broschinski',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Marcelo Brozovi?',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Cédric Brunner',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Lewis Brunt',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jacob Bruun Larsen',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Andreas Bruus',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.18},
#  {'player': 'Bryan',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.63},
#  {'player': 'Bryan', 'competition': 'La Liga', 'goals': 1, 'assists': 0.0},
#  {'player': 'Joe Bryan', 'competition': 'Ligue 1', 'goals': 0, 'assists': 0.0},
#  {'player': 'Lee Buchanan',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Ante Budimir',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Emi Buendía',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Hugo Bueno',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Santiago Bueno',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Adam Buksa',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marius Bülter',
#   'competition': 'Bundesliga',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Cristian Buonaiuto',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Facundo Buonanotte',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alessandro Buongiorno',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Delano Burgzorg',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.43},
#  {'player': 'Jonathan Burkardt',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.34},
#  {'player': 'Oliver Burke',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Dan Burn',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Maxime Busi',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.15},
#  {'player': 'Sergio Busquets',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Aurélio Buta',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Marcin Bu?ka',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jamie Bynoe-Gittens',
#   'competition': 'Bundesliga',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Juan Cabal',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Rémy Cabella',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.45},
#  {'player': 'Jimmy Cabot',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.18},
#  {'player': 'Leandro Cabrera',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Liberato Cacace',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Anthony Caci',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.08},
#  {'player': 'Cafú',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Moisés Caicedo',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.05},
#  {'player': 'Tom Cairney',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jens Cajuste',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.11},
#  {'player': 'Cala', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Davide Calabria',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.18},
#  {'player': 'Mattia Caldara',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Luca Caldirola',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fernando Calero',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Duje ?aleta-Car',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Duje ?aleta-Car',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Hakan Çalhanoðlu',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.29},
#  {'player': 'Kerim Calhanoglu',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Daniel Caligiuri',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Alexander Callens',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dominic Calvert-Lewin',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mahdi Camara',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mohamed Camara',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mohamed Camara',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.13},
#  {'player': 'Ousmane Camara',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ousmane Camara',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Eduardo Camavinga',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Nicolò Cambiaghi',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.17},
#  {'player': 'Andrea Cambiaso',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.16},
#  {'player': 'Axel Camblan',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergio Camello',
#   'competition': 'La Liga',
#   'goals': 5,
#   'assists': 0.19},
#  {'player': 'Chem Campbell',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Emre Can',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergio Canales',
#   'competition': 'La Liga',
#   'goals': 3,
#   'assists': 0.06},
#  {'player': 'Matteo Cancellieri',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'João Cancelo',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.07},
#  {'player': 'João Cancelo',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.67},
#  {'player': 'Antonio Candreva',
#   'competition': 'Serie A',
#   'goals': 2,
#   'assists': 0.06},
#  {'player': 'Thomas Cannon',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergi Canós',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ander Capa',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Pierrick Capelle',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.22},
#  {'player': 'Étienne Capoue',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gianluca Caprari',
#   'competition': 'Serie A',
#   'goals': 4,
#   'assists': 0.07},
#  {'player': 'Francesco Caputo',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Francesco Caputo',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.31},
#  {'player': 'Maxence Caqueret',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.18},
#  {'player': 'Andrea Carboni',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Valentin Carboni',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Isaac Carcelen',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Irvin Cardona',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Irvin Cardona',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Igor Carioca',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carlos', 'competition': 'Serie A', 'goals': 4, 'assists': 0.15},
#  {'player': 'Diego Carlos',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Juan Carlos',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'José Carlos Lazo',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'José Carlos Lazo',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Carmona', 'competition': 'La Liga', 'goals': 1, 'assists': 0.0},
#  {'player': 'Carmona', 'competition': 'La Liga', 'goals': 2, 'assists': 0.17},
#  {'player': 'Marco Carnesecchi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yannick Carrasco',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Dani Carvajal',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.08},
#  {'player': 'Fabio Carvalho',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Matis Carvalho',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'William Carvalho',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.07},
#  {'player': 'Nicolò Casale',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.07},
#  {'player': 'Casemiro',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.22},
#  {'player': 'Casemiro', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Matty Cash',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Timothy Castagne',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.1},
#  {'player': 'Michele Castagnetti',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Koen Casteels',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Valentín Castellanos',
#   'competition': 'La Liga',
#   'goals': 4,
#   'assists': 0.0},
#  {'player': 'Jean-Charles Castelletto',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Samu Castillejo',
#   'competition': 'La Liga',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Jonny Castro',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gaetano Castrovilli',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Danilo Cataldi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.06},
#  {'player': 'Catena', 'competition': 'La Liga', 'goals': 1, 'assists': 0.05},
#  {'player': 'Yoann Cathline',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.16},
#  {'player': 'Maximiliano Caufriez',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Edinson Cavani',
#   'competition': 'La Liga',
#   'goals': 5,
#   'assists': 0.1},
#  {'player': 'Dani Ceballos',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.16},
#  {'player': 'Federico Ceccherini',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Assan Ceesay',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Emil Ceide',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Zeki Çelik',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fabien Centonze',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Franco Cervi',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Julio César Enciso',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Leonardo César Jardim',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Julian Chabot',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.19},
#  {'player': 'Florian Chabrolle',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'El Chadaille Bitshiabu',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fares Chaïbi',
#   'competition': 'Ligue 1',
#   'goals': 4,
#   'assists': 0.26},
#  {'player': 'Nathaniel Chalobah',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Trevoh Chalobah',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Calum Chambers',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Timothy Chandler',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gaëtan Charbonnier',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Brendan Chardonnet',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Xavier Chavalerin',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.13},
#  {'player': 'Pep Chavarría',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Rayan Cherki',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.39},
#  {'player': 'Ilyes Cheti',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Lucas Chevalier',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fabio Chiarodia',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Federico Chiesa',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.74},
#  {'player': 'Ben Chilwell',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.2},
#  {'player': 'Vlad Chiriche?',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Pedro Chirivella',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.06},
#  {'player': 'Joris Chotard',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Andreas Christensen',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.13},
#  {'player': 'Oliver Christensen',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Ryan Christie',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Carney Chukwuemeka',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Samuel Chukwueze',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.18},
#  {'player': 'Darko Churlinov',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Víctor Chust',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Tolga Ciðerci',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yanis Cimignani',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Daniel Ciofani',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Tio Cipot', 'competition': 'Serie A', 'goals': 0, 'assists': 0.0},
#  {'player': 'Pathé Ciss',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Souleymane Cissé',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Patrick Ciurria',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.29},
#  {'player': 'Bobby Clark',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alexis Claude-Maurice',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alexis Claude-Maurice',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.4},
#  {'player': 'Jonathan Clauss',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.5},
#  {'player': 'Carlos Clerc',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.08},
#  {'player': 'Nathaniel Clyne',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Conor Coady',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.05},
# ...
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Zouhair Feddal',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Nabil Fekir',
#   'competition': 'La Liga',
#   'goals': 2,
#   'assists': 0.23},
#  {'player': 'Felipe',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Felipe', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Luiz Felipe',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'João Félix',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'João Félix',
#   'competition': 'La Liga',
#   'goals': 4,
#   'assists': 0.42},
#  {'player': 'Ohis Felix Uduokhai',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Kiko Femenía',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Evan Ferguson',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.77},
#  {'player': 'Lewis Ferguson',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Bruno Fernandes',
#   'competition': 'Premier League',
#   'goals': 5,
#   'assists': 0.19},
#  {'player': 'Edimilson Fernandes',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Aitor Fernández',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Álex Fernández',
#   'competition': 'La Liga',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Álvaro Fernández',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Carlos Fernández',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Enzo Fernández',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.5},
#  {'player': 'Federico Fernández',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Joaquín Fernández',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mateo Fernández',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fernando', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Fernando', 'competition': 'La Liga', 'goals': 0, 'assists': 0.0},
#  {'player': 'Alex Ferrari',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alex Ferrari',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Salvador Ferrer',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jordan Ferri',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.12},
#  {'player': 'Fidel', 'competition': 'La Liga', 'goals': 0, 'assists': 0.22},
#  {'player': 'Karol Fila',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Roberto Firmino',
#   'competition': 'Premier League',
#   'goals': 7,
#   'assists': 0.29},
#  {'player': 'Junior Firpo',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kilian Fischer',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Mark Flekken',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Florian Flick',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alexis Flips',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.27},
#  {'player': 'Alessandro Florenzi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Phil Foden',
#   'competition': 'Premier League',
#   'goals': 7,
#   'assists': 0.34},
#  {'player': 'Datro Fofana',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Seko Fofana',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.15},
#  {'player': 'Wesley Fofana',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Wesley Fofana',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yahia Fofana',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Youssouf Fofana',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.05},
#  {'player': 'Thomas Foket',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'José Fonte',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Pablo Fornals',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Emil Forsberg',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.24},
#  {'player': 'Adam Forshaw',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Fraser Forster',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Philipp Förster',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.52},
#  {'player': 'Steven Fortes',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Timothy Fosu-Mensah',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dimitri Foulquier',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Juan Foyth',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Raphael Framberger',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Tyrese Francois',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Bartol Franji?',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.4},
#  {'player': 'Przemys?aw Frankowski',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.11},
#  {'player': 'Ryan Fraser',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Davide Frattesi',
#   'competition': 'Serie A',
#   'goals': 5,
#   'assists': 0.0},
#  {'player': 'Fred',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Ryan Fredericks',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Iván Fresneda',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Remo Freuler',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Michael Frey',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.38},
#  {'player': 'Marco Friedl',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Marvin Friedrich',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Jeremie Frimpong',
#   'competition': 'Bundesliga',
#   'goals': 5,
#   'assists': 0.22},
#  {'player': 'Chris Führich',
#   'competition': 'Bundesliga',
#   'goals': 4,
#   'assists': 0.0},
#  {'player': 'Angelo Fulgini',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Angelo Fulgini',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.17},
#  {'player': 'Niclas Füllkrug',
#   'competition': 'Bundesliga',
#   'goals': 13,
#   'assists': 0.16},
#  {'player': 'Matteo Gabbia',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Manolo Gabbiadini',
#   'competition': 'Serie A',
#   'goals': 4,
#   'assists': 0.08},
#  {'player': 'Gianluca Gaetano',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 2.5},
#  {'player': 'Roberto Gagliardini',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Adolfo Gaich',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Cody Gakpo',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Javi Galán',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.05},
#  {'player': 'Iñigo Ruiz de Galarreta',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Pablo Galdames Millán',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Conor Gallagher',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.11},
#  {'player': 'Antonino Gallo',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Gauthier Gallon',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Cristian Gamboa',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Kévin Gameiro',
#   'competition': 'Ligue 1',
#   'goals': 7,
#   'assists': 0.0},
#  {'player': 'Idrissa Gana Gueye',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Ignatius Ganago',
#   'competition': 'Ligue 1',
#   'goals': 3,
#   'assists': 0.33},
#  {'player': 'Ignatius Ganago',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': "Silvère Ganvoula M'Boussy",
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Aleix García',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.2},
#  {'player': 'Álvaro García',
#   'competition': 'La Liga',
#   'goals': 4,
#   'assists': 0.12},
#  {'player': 'Borja García',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Carlos García',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 3.33},
#  {'player': 'Dani García',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.15},
#  {'player': 'David García',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Eric García',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Francisco Garcia',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.1},
#  {'player': 'Raúl García',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.32},
#  {'player': 'Rubén García',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.29},
#  {'player': 'Unai García',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Alejandro Garnacho',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.56},
#  {'player': 'James Garner',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Felix Garreta',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sékou Gassama',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Johan Gastien',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.11},
#  {'player': 'Federico Gatti',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gavi', 'competition': 'La Liga', 'goals': 1, 'assists': 0.14},
#  {'player': 'Paulo Gazzaniga',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'David de Gea',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dennis Geiger',
#   'competition': 'Bundesliga',
#   'goals': 1,
#   'assists': 0.15},
#  {'player': 'Joe Gelhardt',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.83},
#  {'player': 'Valentin Gendrey',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Denis Genreau',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Yannick Gerhardt',
#   'competition': 'Bundesliga',
#   'goals': 4,
#   'assists': 0.09},
#  {'player': 'Valère Germain',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.0},
#  {'player': 'Gerson', 'competition': 'Ligue 1', 'goals': 2, 'assists': 0.0},
#  {'player': 'Ismaël Gharbi',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Paolo Ghiglione',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.19},
#  {'player': 'Saman Ghoddos',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Faouzi Ghoulam',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Morgan Gibbs-White',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Morgan Gibbs-White',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.23},
#  {'player': 'Niko Gießelmann',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.19},
#  {'player': 'Samuel Gigot',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.14},
#  {'player': 'Rafa? Gikiewicz',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Óscar Gil',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.07},
#  {'player': 'Mario Gila',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Billy Gilmour',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Álvaro Giménez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Gvidas Gineitis',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Matthias Ginter',
#   'competition': 'Bundesliga',
#   'goals': 3,
#   'assists': 0.05},
#  {'player': 'Andrei Girotto',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.05},
#  {'player': 'Olivier Giroud',
#   'competition': 'Serie A',
#   'goals': 7,
#   'assists': 0.27},
#  {'player': 'Serge Gnabry',
#   'competition': 'Bundesliga',
#   'goals': 9,
#   'assists': 0.33},
#  {'player': 'Degnand Gnonto',
#   'competition': 'Premier League',
#   'goals': 2,
#   'assists': 0.13},
#  {'player': 'Ben Godfrey',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Pierluigi Gollini',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Aleksandr Golovin',
#   'competition': 'Ligue 1',
#   'goals': 5,
#   'assists': 0.34},
#  {'player': 'André Gomes',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Angel Gomes',
#   'competition': 'Ligue 1',
#   'goals': 2,
#   'assists': 0.16},
#  {'player': 'João Gomes',
#   'competition': 'Premier League',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Toti Gomes',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Dani Gómez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Joe Gomez',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Maxi Gómez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Moi Gómez',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.11},
#  {'player': 'Papu Gómez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.14},
#  {'player': 'Sergi Gómez',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Sergio Gómez',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.83},
#  {'player': 'Maxime Gonalons',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Diego González',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Édgar González',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Giovanni González',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.34},
#  {'player': 'Joan Gonzàlez',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.17},
#  {'player': 'Nicolás González',
#   'competition': 'Serie A',
#   'goals': 3,
#   'assists': 0.2},
#  {'player': 'Nicolás González',
#   'competition': 'La Liga',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Oumar Gonzalez',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Roberto González',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jacek Góralski',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Anthony Gordon',
#   'competition': 'Premier League',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Anthony Gordon',
#   'competition': 'Premier League',
#   'goals': 3,
#   'assists': 0.0},
#  {'player': 'Leon Goretzka',
#   'competition': 'Bundesliga',
#   'goals': 3,
#   'assists': 0.09},
#  {'player': 'Andoni Gorosabel',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Robin Gosens',
#   'competition': 'Serie A',
#   'goals': 1,
#   'assists': 0.0},
#  {'player': 'Mario Götze',
#   'competition': 'Bundesliga',
#   'goals': 2,
#   'assists': 0.06},
#  {'player': 'Amine Gouiri',
#   'competition': 'Ligue 1',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Amine Gouiri',
#   'competition': 'Ligue 1',
#   'goals': 9,
#   'assists': 0.07},
#  {'player': 'Jeffrey Gouweleeuw',
#   'competition': 'Bundesliga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Jonathan Gradit',
#   'competition': 'Ligue 1',
#   'goals': 1,
#   'assists': 0.13},
#  {'player': 'José Gragera',
#   'competition': 'La Liga',
#   'goals': 0,
#   'assists': 0.0},
#  {'player': 'Alberto Grassi',
#   'competition': 'Serie A',
#   'goals': 0,
#   'assists': 0.0},
#  ...]

# %% [markdown]
# ### 17. Calculate the total number of goals and assists for each player in the dataset
#
# Expected Output is a dictionary with the player name as the key and the value is a dictionary with keys goals and assists and their respective values.
#
# Example of expected output:
#
# <code>
# {
#     'Harry Kane': {'goals': 25, 'assists': 12},
#     'Lionel Messi': {'goals': 30, 'assists': 18},
#     'Cristiano Ronaldo': {'goals': 27, 'assists': 10},
#     ...
# }
# </code>

# %%
goals_and_assists_per_player = {}

for player in players:
    name, nation, pos, squad, comp, age, born, mp, starts, mins, goals, shots, sot, assists = player
    goals = float(goals)
    assists = float(assists)
    if name not in goals_and_assists_per_player:
        goals_and_assists_per_player[name] = {'goals': goals, 'assists': assists}
    else:
        goals_and_assists_per_player[name]['goals'] += goals
        goals_and_assists_per_player[name]['assists'] += assists


goals_and_assists_per_player
# Out:
# {'Brenden Aaronson': {'goals': 1.0, 'assists': 0.11},
#  'Yunis Abdelhamid': {'goals': 0.0, 'assists': 0.05},
#  'Himad Abdelli': {'goals': 0.0, 'assists': 0.0},
#  'Salis Abdul Samed': {'goals': 1.0, 'assists': 0.0},
#  'Laurent Abergel': {'goals': 0.0, 'assists': 0.08},
#  'Oliver Abildgaard': {'goals': 0.0, 'assists': 0.0},
#  'Matthis Abline': {'goals': 2.0, 'assists': 0.0},
#  'Abner': {'goals': 0.0, 'assists': 0.0},
#  'Zakaria Aboukhlal': {'goals': 5.0, 'assists': 0.24},
#  'Tammy Abraham': {'goals': 6.0, 'assists': 0.17},
#  'Francesco Acerbi': {'goals': 0.0, 'assists': 0.08},
#  'Mohamed Achi': {'goals': 0.0, 'assists': 0.0},
#  'Marcos Acuña': {'goals': 2.0, 'assists': 0.09},
#  'Che Adams': {'goals': 4.0, 'assists': 0.11},
#  'Tyler Adams': {'goals': 0.0, 'assists': 0.0},
#  'Sargis Adamyan': {'goals': 1.0, 'assists': 0.19},
#  'Tosin Adarabioyo': {'goals': 1.0, 'assists': 0.0},
#  'Martin Adeline': {'goals': 0.0, 'assists': 0.0},
#  'Karim Adeyemi': {'goals': 2.0, 'assists': 0.12},
#  'Amine Adli': {'goals': 1.0, 'assists': 0.28},
#  'Yacine Adli': {'goals': 0.0, 'assists': 0.0},
#  'Michel Aebischer': {'goals': 1.0, 'assists': 0.0},
#  'Felix Afena-Gyan': {'goals': 0.0, 'assists': 0.0},
#  'Emmanuel Agbadou': {'goals': 0.0, 'assists': 0.11},
#  'Lucien Agoume': {'goals': 0.0, 'assists': 0.0},
#  'Felix Agu': {'goals': 0.0, 'assists': 0.0},
#  'Álvaro Aguado': {'goals': 0.0, 'assists': 0.16},
#  'Kevin Agudelo': {'goals': 0.0, 'assists': 0.0},
#  'Nayef Aguerd': {'goals': 0.0, 'assists': 0.0},
#  'Ruben Aguilar': {'goals': 0.0, 'assists': 0.0},
#  'Naouirou Ahamada': {'goals': 2.0, 'assists': 0.13},
#  'Amar Ahmed': {'goals': 0.0, 'assists': 0.0},
#  'Jean-Eudes Aholou': {'goals': 1.0, 'assists': 0.0},
#  'Joseph Aidoo': {'goals': 2.0, 'assists': 0.0},
#  'Ola Aina': {'goals': 1.0, 'assists': 0.13},
#  'Rayan Aït Nouri': {'goals': 1.0, 'assists': 0.0},
#  'Emanuel Aiwum': {'goals': 0.0, 'assists': 0.0},
#  'Kristoffer Ajer': {'goals': 0.0, 'assists': 0.0},
#  'Ludovic Ajorque': {'goals': 1.0, 'assists': 0.38},
#  'Manuel Akanji': {'goals': 0.0, 'assists': 0.07},
#  'Nathan Aké': {'goals': 0.0, 'assists': 0.0},
#  'Sergio Akieme': {'goals': 0.0, 'assists': 0.0},
#  'Maghnes Akliouche': {'goals': 0.0, 'assists': 0.0},
#  'Paul Akouokou': {'goals': 0.0, 'assists': 0.0},
#  'Jean-Daniel Akpa-Akpro': {'goals': 0.0, 'assists': 0.0},
#  'Kevin Akpoguma': {'goals': 0.0, 'assists': 0.0},
#  'David Alaba': {'goals': 1.0, 'assists': 0.2},
#  'Tomás Alarcón': {'goals': 0.0, 'assists': 0.0},
#  'Lucas Alario': {'goals': 1.0, 'assists': 0.0},
#  'Jordi Alba': {'goals': 1.0, 'assists': 0.29},
#  'Luis Alberto': {'goals': 4.0, 'assists': 0.26},
#  'Raúl Albiol': {'goals': 0.0, 'assists': 0.0},
#  'Marc Albrighton': {'goals': 1.0, 'assists': 0.0},
#  'Thiago Alcántara': {'goals': 0.0, 'assists': 0.0},
#  'Carlos Alcaraz': {'goals': 1.0, 'assists': 0.0},
#  'Rubén Alcaraz': {'goals': 1.0, 'assists': 0.0},
#  'Omar Alderete': {'goals': 0.0, 'assists': 0.0},
#  'Iván Alejo': {'goals': 0.0, 'assists': 0.12},
#  'Doðan Alemdar': {'goals': 0.0, 'assists': 0.0},
#  'Carles Aleñá': {'goals': 2.0, 'assists': 0.12},
#  'Trent Alexander-Arnold': {'goals': 1.0, 'assists': 0.06},
#  'Alejandro Alfaro': {'goals': 0.0, 'assists': 0.0},
#  'Ángel Algobia': {'goals': 0.0, 'assists': 0.0},
#  'Mohamed Ali Cho': {'goals': 0.0, 'assists': 0.57},
#  'Faride Alidou': {'goals': 0.0, 'assists': 0.0},
#  'Alisson': {'goals': 0.0, 'assists': 0.05},
#  'Jim Allevinah': {'goals': 1.0, 'assists': 0.0},
#  'Dele Alli': {'goals': 0.0, 'assists': 0.0},
#  'Domingos André Ribeiro Almeida': {'goals': 2.0, 'assists': 0.22},
#  'Miguel Almirón': {'goals': 10.0, 'assists': 0.05},
#  'Marcos Alonso': {'goals': 1.0, 'assists': 0.0},
#  'Mickaël Alphonse': {'goals': 0.0, 'assists': 0.0},
#  'Éder Álvarez Balanta': {'goals': 0.0, 'assists': 0.0},
#  'Carlos Álvarez': {'goals': 0.0, 'assists': 0.0},
#  'Gastón Álvarez': {'goals': 2.0, 'assists': 0.0},
#  'Julián Álvarez': {'goals': 4.0, 'assists': 0.0},
#  'Agustín Álvarez Martínez': {'goals': 1.0, 'assists': 0.3},
#  'Yeray Álvarez': {'goals': 1.0, 'assists': 0.06},
#  'Ibrahim Amadou': {'goals': 0.0, 'assists': 0.0},
#  'Daniel Amartey': {'goals': 0.0, 'assists': 0.0},
#  'Amath': {'goals': 1.0, 'assists': 0.0},
#  'Jordan Amavi': {'goals': 0.0, 'assists': 0.0},
#  'Kelvin Amian': {'goals': 0.0, 'assists': 0.09},
#  'Bruno Amione': {'goals': 0.0, 'assists': 0.11},
#  'Nadiem Amiri': {'goals': 2.0, 'assists': 0.14},
#  'Ethan Ampadu': {'goals': 0.0, 'assists': 0.07},
#  'Sofyan Amrabat': {'goals': 0.0, 'assists': 0.0},
#  'Joachim Andersen': {'goals': 1.0, 'assists': 0.0},
#  'Elliot Anderson': {'goals': 0.0, 'assists': 0.0},
#  'Felipe Anderson': {'goals': 6.0, 'assists': 0.11},
#  'Benjamin André': {'goals': 1.0, 'assists': 0.05},
#  'Komnen Andri?': {'goals': 4.0, 'assists': 0.14},
#  'Robert Andrich': {'goals': 2.0, 'assists': 0.13},
#  'Angeliño': {'goals': 0.0, 'assists': 0.28},
#  'Fabrizio Angileri': {'goals': 0.0, 'assists': 0.0},
#  'Jaidon Anthony': {'goals': 3.0, 'assists': 0.0},
#  'Janis Antiste': {'goals': 1.0, 'assists': 0.0},
#  'Waldemar Anton': {'goals': 1.0, 'assists': 0.0},
#  'Marcos Antônio': {'goals': 0.0, 'assists': 0.0},
#  'Michail Antonio': {'goals': 2.0, 'assists': 0.17},
#  'Antony': {'goals': 3.0, 'assists': 0.0},
#  'Valentin Antov': {'goals': 0.0, 'assists': 0.0},
#  'Christopher Antwi-Adjei': {'goals': 2.0, 'assists': 0.68},
#  'Anuar': {'goals': 1.0, 'assists': 0.0},
#  'Houssem Aouar': {'goals': 1.0, 'assists': 0.22},
#  'Adil Aouchiche': {'goals': 0.0, 'assists': 0.0},
#  'Dennis Appiah': {'goals': 0.0, 'assists': 0.0},
#  'Mauro Arambarri': {'goals': 0.0, 'assists': 0.15},
#  'Charles Aránguiz': {'goals': 1.0, 'assists': 0.0},
#  'Ronald Araújo': {'goals': 0.0, 'assists': 0.11},
#  'Cameron Archer': {'goals': 0.0, 'assists': 0.0},
#  'Taïryk Arconte': {'goals': 0.0, 'assists': 0.0},
#  'Alphonse Areola': {'goals': 0.0, 'assists': 0.0},
#  'Joe Aribo': {'goals': 2.0, 'assists': 0.0},
#  'Adam Armstrong': {'goals': 1.0, 'assists': 0.09},
#  'Stuart Armstrong': {'goals': 1.0, 'assists': 0.0},
#  'Marko Arnautovi?': {'goals': 8.0, 'assists': 0.0},
#  'Maximilian Arnold': {'goals': 4.0, 'assists': 0.1},
#  'Kepa Arrizabalaga': {'goals': 0.0, 'assists': 0.0},
#  'Roberto Arroyo': {'goals': 0.0, 'assists': 0.0},
#  'Tolgay Arslan': {'goals': 1.0, 'assists': 0.0},
#  'Arthur': {'goals': 3.0, 'assists': 0.14},
#  'Santiago Arzamendia': {'goals': 0.0, 'assists': 0.0},
#  'Takuma Asano': {'goals': 1.0, 'assists': 0.0},
#  'Santiago Ascacíbar': {'goals': 0.0, 'assists': 0.0},
#  'Sergio Asenjo': {'goals': 0.0, 'assists': 0.0},
#  'Marco Asensio': {'goals': 2.0, 'assists': 0.54},
#  'Kristoffer Askildsen': {'goals': 0.0, 'assists': 0.0},
#  'Fisnik Asllani': {'goals': 0.0, 'assists': 0.0},
#  'Kristjan Asllani': {'goals': 0.0, 'assists': 0.0},
#  'Iago Aspas': {'goals': 9.0, 'assists': 0.16},
#  'Lorenz Assignon': {'goals': 0.0, 'assists': 0.45},
#  'Youcef Atal': {'goals': 1.0, 'assists': 0.0},
#  'Pierre-Emerick Aubameyang': {'goals': 1.0, 'assists': 0.0},
#  'Emil Audero': {'goals': 0.0, 'assists': 0.0},
#  'Tommaso Augello': {'goals': 1.0, 'assists': 0.11},
#  'Ludwig Augustinsson': {'goals': 0.0, 'assists': 0.0},
#  'Serge Aurier': {'goals': 1.0, 'assists': 0.0},
#  'Mathias Autret': {'goals': 2.0, 'assists': 0.15},
#  'Ezequiel Ávila': {'goals': 7.0, 'assists': 0.16},
#  'Cédric Avinel': {'goals': 1.0, 'assists': 0.0},
#  'Taiwo Awoniyi': {'goals': 4.0, 'assists': 0.0},
#  'Mehmet-Can Aydin': {'goals': 0.0, 'assists': 0.0},
#  'André Ayew': {'goals': 0.0, 'assists': 0.0},
#  'Jordan Ayew': {'goals': 1.0, 'assists': 0.06},
#  'Kaan Ayhan': {'goals': 0.0, 'assists': 0.0},
#  'Luke Ayling': {'goals': 0.0, 'assists': 0.13},
#  'Ayman Azhil': {'goals': 0.0, 'assists': 0.0},
#  'Sardar Azmoun': {'goals': 0.0, 'assists': 0.0},
#  'César Azpilicueta': {'goals': 0.0, 'assists': 0.0},
#  'Sanoussy Ba': {'goals': 0.0, 'assists': 0.0},
#  'Iddrisu Baba': {'goals': 0.0, 'assists': 0.0},
#  'Sr?an Babi?': {'goals': 1.0, 'assists': 0.0},
#  'Loïc Bade': {'goals': 0.0, 'assists': 1.0},
#  'Édgar Badía': {'goals': 0.0, 'assists': 0.0},
#  'Benoît Badiashile': {'goals': 2.0, 'assists': 0.0},
#  'Alex Baena': {'goals': 4.0, 'assists': 0.09},
#  'Jaime Báez': {'goals': 0.0, 'assists': 0.0},
#  'Leon Bailey': {'goals': 4.0, 'assists': 0.14},
#  'Eric Bailly': {'goals': 0.0, 'assists': 0.0},
#  'Dénys Bain': {'goals': 0.0, 'assists': 0.0},
#  'Brandon Baiye': {'goals': 0.0, 'assists': 0.0},
#  'Stefan Bajcetic': {'goals': 1.0, 'assists': 0.0},
#  'Nedim Bajrami': {'goals': 1.0, 'assists': 0.1},
#  'Cédric Bakambu': {'goals': 0.0, 'assists': 1.43},
#  'Mitchel Bakker': {'goals': 2.0, 'assists': 0.09},
#  'Ridle Baku': {'goals': 5.0, 'assists': 0.05},
#  'Tommaso Baldanzi': {'goals': 4.0, 'assists': 0.0},
#  'Alejandro Balde': {'goals': 0.0, 'assists': 0.3},
#  'Thierno Balde': {'goals': 0.0, 'assists': 0.0},
#  'Carlos Baleba': {'goals': 0.0, 'assists': 0.0},
#  'Mikel Balenziaga': {'goals': 0.0, 'assists': 0.0},
#  'Leonardo Balerdi': {'goals': 0.0, 'assists': 0.05},
#  'Iván Balliu': {'goals': 0.0, 'assists': 0.0},
#  'Fodé Ballo-Touré': {'goals': 1.0, 'assists': 0.0},
#  'Folarin Balogun': {'goals': 14.0, 'assists': 0.06},
#  'Abdoulaye Bamba': {'goals': 0.0, 'assists': 0.0},
#  'Jonathan Bamba': {'goals': 4.0, 'assists': 0.19},
#  'Patrick Bamford': {'goals': 1.0, 'assists': 0.3},
#  'Lameck Banda': {'goals': 1.0, 'assists': 0.09},
#  'Filippo Bandinelli': {'goals': 2.0, 'assists': 0.0},
#  'Léo Baptistão': {'goals': 3.0, 'assists': 0.1},
#  'Shandon Baptiste': {'goals': 0.0, 'assists': 0.0},
#  'Antonín Barák': {'goals': 1.0, 'assists': 0.0},
#  'Andrea Barberis': {'goals': 0.0, 'assists': 0.29},
#  'Bradley Barcola': {'goals': 1.0, 'assists': 0.27},
#  'Melvin Bard': {'goals': 0.0, 'assists': 0.0},
#  'Keidi Bare': {'goals': 0.0, 'assists': 0.0},
#  'Nicolò Barella': {'goals': 5.0, 'assists': 0.28},
#  'Kike Barja': {'goals': 1.0, 'assists': 0.23},
#  'Ross Barkley': {'goals': 3.0, 'assists': 0.15},
#  'Aymen Barkok': {'goals': 0.0, 'assists': 0.29},
#  'Harvey Barnes': {'goals': 8.0, 'assists': 0.05},
#  'Leandro Barreiro Martins': {'goals': 0.0, 'assists': 0.17},
#  'Ander Barrenetxea': {'goals': 1.0, 'assists': 0.0},
#  'Mickaël Barreto': {'goals': 0.0, 'assists': 0.26},
#  'Pablo Barrios': {'goals': 0.0, 'assists': 0.0},
#  'Musa Barrow': {'goals': 2.0, 'assists': 0.12},
#  'Federico Baschirotto': {'goals': 3.0, 'assists': 0.0},
#  'Toma Ba\x9ai?': {'goals': 0.0, 'assists': 0.0},
#  'Gil Bastião Dias': {'goals': 0.0, 'assists': 0.0},
#  'Alessandro Bastoni': {'goals': 0.0, 'assists': 0.14},
#  'Simone Bastoni': {'goals': 2.0, 'assists': 0.19},
#  'Rodrigo Battaglia': {'goals': 0.0, 'assists': 0.0},
#  'Maximilian Bauer': {'goals': 0.0, 'assists': 0.0},
#  'Oliver Baumann': {'goals': 0.0, 'assists': 0.0},
#  'Timo Baumgartl': {'goals': 0.0, 'assists': 0.0},
#  'Julian Baumgartlinger': {'goals': 0.0, 'assists': 0.0},
#  'Christoph Baumgartner': {'goals': 5.0, 'assists': 0.17},
#  'Cyrille Bayala': {'goals': 1.0, 'assists': 0.07},
#  'Brian Bayeye': {'goals': 0.0, 'assists': 0.0},
#  'Noah Joel Sarenren Bazee': {'goals': 0.0, 'assists': 0.0},
#  'Gavin Bazunu': {'goals': 0.0, 'assists': 0.0},
#  'Bebé': {'goals': 0.0, 'assists': 0.0},
#  'Ihlas Bebou': {'goals': 2.0, 'assists': 0.0},
#  'Rodrigo Becão': {'goals': 1.0, 'assists': 0.07},
#  'Mads Bech Sørensen': {'goals': 0.0, 'assists': 0.0},
#  'Julius Beck': {'goals': 0.0, 'assists': 0.0},
#  'Sheraldo Becker': {'goals': 7.0, 'assists': 0.25},
#  'Jan Bednarek': {'goals': 0.0, 'assists': 0.0},
#  'Donny van de Beek': {'goals': 0.0, 'assists': 0.0},
#  'Asmir Begovi?': {'goals': 0.0, 'assists': 0.0},
#  'Yanis Begraoui': {'goals': 0.0, 'assists': 0.0},
#  'Kevin Behrens': {'goals': 4.0, 'assists': 0.12},
#  'Alexis Beka Beka': {'goals': 0.0, 'assists': 0.0},
#  'Jérémie Bela': {'goals': 1.0, 'assists': 0.14},
#  'Youcef Belaïli': {'goals': 5.0, 'assists': 0.8400000000000001},
#  'Haris Belkebla': {'goals': 1.0, 'assists': 0.0},
#  'Stefan Bell': {'goals': 0.0, 'assists': 0.0},
#  'Armel Bella Kotchap': {'goals': 0.0, 'assists': 0.09},
#  'Raoul Bellanova': {'goals': 0.0, 'assists': 0.0},
#  'Karim Bellarabi': {'goals': 0.0, 'assists': 0.0},
#  'Jean-Ricner Bellegarde': {'goals': 1.0, 'assists': 0.28},
#  'Héctor Bellerín': {'goals': 0.0, 'assists': 0.0},
#  'Jude Bellingham': {'goals': 4.0, 'assists': 0.21},
#  'Jeanöel Belocian': {'goals': 0.0, 'assists': 0.0},
#  'Andrea Belotti': {'goals': 0.0, 'assists': 0.0},
#  'Fran Beltrán': {'goals': 0.0, 'assists': 0.06},
#  'Eliesse Ben Seghir': {'goals': 3.0, 'assists': 0.19},
#  'Salim Ben Seghir': {'goals': 0.0, 'assists': 0.0},
#  'Wissam Ben Yedder': {'goals': 14.0, 'assists': 0.24},
#  'Marco Benassi': {'goals': 0.0, 'assists': 0.0},
#  'Ismaël Bennacer': {'goals': 1.0, 'assists': 0.06},
#  'Saïd Benrahma': {'goals': 3.0, 'assists': 0.08},
#  'Ramy Bensebaini': {'goals': 5.0, 'assists': 0.0},
#  'Nabil Bentaleb': {'goals': 2.0, 'assists': 0.18},
#  'Rodrigo Bentancur': {'goals': 5.0, 'assists': 0.12},
#  'Karim Benzema': {'goals': 9.0, 'assists': 0.26},
#  'Domenico Berardi': {'goals': 4.0, 'assists': 0.29},
#  'Yuri Berchiche': {'goals': 0.0, 'assists': 0.1},
#  'Álex Berenguer': {'goals': 3.0, 'assists': 0.07},
#  'Bartosz Bereszy?ski': {'goals': 0.0, 'assists': 0.0},
#  'Patrick Berg': {'goals': 0.0, 'assists': 0.0},
#  'Mitchell van Bergen': {'goals': 0.0, 'assists': 0.14},
#  'Mergim Berisha': {'goals': 6.0, 'assists': 0.31},
#  'Quentin Bernard': {'goals': 0.0, 'assists': 0.14},
#  'Paul Bernardoni': {'goals': 0.0, 'assists': 0.0},
#  'Juan Bernat': {'goals': 1.0, 'assists': 0.18},
#  'Victor Bernth Kristiansen': {'goals': 0.0, 'assists': 0.0},
#  'Jason Berthomier': {'goals': 0.0, 'assists': 0.0},
#  'Beto': {'goals': 7.0, 'assists': 0.07},
#  'Owen Bevan': {'goals': 0.0, 'assists': 0.0},
#  'Matteo Bianchetti': {'goals': 1.0, 'assists': 0.0},
#  'Alessandro Bianco': {'goals': 0.0, 'assists': 0.0},
#  'Giulian Biancone': {'goals': 0.0, 'assists': 0.0},
#  'Ermin Bi?ak?i?': {'goals': 0.0, 'assists': 0.0},
#  'Pedro Bigas': {'goals': 0.0, 'assists': 0.0},
#  'Jaka Bijol': {'goals': 2.0, 'assists': 0.0},
#  'El Bilal Touré': {'goals': 4.0, 'assists': 0.19},
#  'Philip Billing': {'goals': 4.0, 'assists': 0.06},
#  'Jean-Claude Billong': {'goals': 0.0, 'assists': 0.0},
#  'Cristiano Biraghi': {'goals': 0.0, 'assists': 0.11},
#  'Samuele Birindelli': {'goals': 0.0, 'assists': 0.1},
#  'Veljko Birman?evi?': {'goals': 0.0, 'assists': 0.0},
#  'Tom Bischof': {'goals': 0.0, 'assists': 0.0},
#  'Yves Bissouma': {'goals': 0.0, 'assists': 0.0},
#  'Kristijan Bistrovi?': {'goals': 0.0, 'assists': 0.0},
#  'Leonardo Bittencourt': {'goals': 2.0, 'assists': 0.0},
#  'Marco Bizot': {'goals': 0.0, 'assists': 0.0},
#  'Blanco': {'goals': 0.0, 'assists': 0.0},
#  'Lautaro Blanco': {'goals': 0.0, 'assists': 0.38},
#  'Rubén Blanco': {'goals': 0.0, 'assists': 0.0},
#  'Ludovic Blas': {'goals': 4.0, 'assists': 0.05},
#  'Janis Blaswich': {'goals': 0.0, 'assists': 0.0},
#  'Miha Bla?i?': {'goals': 2.0, 'assists': 0.0},
#  'Joaquín Blázquez': {'goals': 0.0, 'assists': 0.0},
#  'Alexis Blin': {'goals': 0.0, 'assists': 0.0},
#  'Daley Blind': {'goals': 0.0, 'assists': 0.0},
#  'Myron Boadu': {'goals': 1.0, 'assists': 0.0},
#  'Jérôme Boateng': {'goals': 0.0, 'assists': 0.0},
#  'Kevin-Prince Boateng': {'goals': 0.0, 'assists': 0.0},
#  'Antonin Bobichon': {'goals': 0.0, 'assists': 0.0},
#  'Jean-Paul Boëtius': {'goals': 0.0, 'assists': 0.0},
#  'Jeremie Boga': {'goals': 1.0, 'assists': 1.14},
#  'Emil Bohinen': {'goals': 0.0, 'assists': 0.0},
#  'Quentin Boisgard': {'goals': 1.0, 'assists': 0.0},
#  'Willy Boly': {'goals': 0.0, 'assists': 0.15},
#  'Giacomo Bonaventura': {'goals': 3.0, 'assists': 0.0},
#  'Federico Bonazzoli': {'goals': 2.0, 'assists': 0.1},
#  'Warren Bondo': {'goals': 0.0, 'assists': 0.0},
#  'Theo Bongonda': {'goals': 2.0, 'assists': 0.22},
#  'Kevin Bonifazi': {'goals': 0.0, 'assists': 0.0},
#  'Leonardo Bonucci': {'goals': 1.0, 'assists': 0.0},
#  'Neto Borges': {'goals': 2.0, 'assists': 0.0},
#  'Yvandro Borges Sanches': {'goals': 0.0, 'assists': 0.0},
#  'Sebastiaan Bornauw': {'goals': 0.0, 'assists': 0.0},
#  'Rafael Borré': {'goals': 2.0, 'assists': 0.36},
#  'Erik Botheim': {'goals': 1.0, 'assists': 0.27},
#  'Sven Botman': {'goals': 0.0, 'assists': 0.0},
#  'Kenji-Van Boto': {'goals': 0.0, 'assists': 0.0},
#  'Kouamé Botué': {'goals': 0.0, 'assists': 0.0},
#  'Badredine Bouanani': {'goals': 0.0, 'assists': 1.5},
#  'Hicham Boudaoui': {'goals': 0.0, 'assists': 0.12},
#  'Franci Bouebari': {'goals': 0.0, 'assists': 0.0},
#  'Sofiane Boufal': {'goals': 4.0, 'assists': 0.32},
#  'Wassim Boullif': {'goals': 0.0, 'assists': 0.0},
#  'Yassine Bounou': {'goals': 0.0, 'assists': 0.0},
#  'Ismaëlben Boura': {'goals': 0.0, 'assists': 0.0},
#  'Mehdi Bourabia': {'goals': 0.0, 'assists': 0.11},
#  'Benjamin Bourigeaud': {'goals': 3.0, 'assists': 0.26},
#  'Edoardo Bove': {'goals': 0.0, 'assists': 0.0},
#  'Jarrod Bowen': {'goals': 4.0, 'assists': 0.05},
#  'Lucas Boyé': {'goals': 1.0, 'assists': 0.15},
#  'Jayden Braaf': {'goals': 0.0, 'assists': 0.0},
#  'Domagoj Bradari?': {'goals': 0.0, 'assists': 0.09},
#  'Bilal Brahimi': {'goals': 3.0, 'assists': 0.4},
#  'Martin Braithwaite': {'goals': 5.0, 'assists': 0.08},
#  'Juan Brandáriz': {'goals': 1.0, 'assists': 0.0},
#  'Julian Brandt': {'goals': 6.0, 'assists': 0.24},
#  'Darko Bra\x9aanac': {'goals': 1.0, 'assists': 0.12},
#  'Lilian Brassier': {'goals': 0.0, 'assists': 0.0},
#  'Claudio Bravo': {'goals': 0.0, 'assists': 0.0},
#  'Fabian Bredlow': {'goals': 0.0, 'assists': 0.0},
#  'James Bree': {'goals': 0.0, 'assists': 0.0},
#  'Josip Brekalo': {'goals': 0.0, 'assists': 0.33},
#  'Gleison Bremer': {'goals': 1.0, 'assists': 0.0},
#  'Armando Broja': {'goals': 1.0, 'assists': 0.0},
#  'Dylan Bronn': {'goals': 0.0, 'assists': 0.0},
#  'John Brooks': {'goals': 0.0, 'assists': 0.0},
#  'Moritz Broschinski': {'goals': 1.0, 'assists': 0.0},
#  'Marcelo Brozovi?': {'goals': 2.0, 'assists': 0.0},
#  'Cédric Brunner': {'goals': 0.0, 'assists': 0.0},
#  'Lewis Brunt': {'goals': 0.0, 'assists': 0.0},
#  'Jacob Bruun Larsen': {'goals': 1.0, 'assists': 0.0},
#  'Andreas Bruus': {'goals': 0.0, 'assists': 0.18},
#  'Bryan': {'goals': 1.0, 'assists': 0.63},
#  'Joe Bryan': {'goals': 0.0, 'assists': 0.0},
#  'Lee Buchanan': {'goals': 1.0, 'assists': 0.0},
#  'Ante Budimir': {'goals': 2.0, 'assists': 0.0},
#  'Emi Buendía': {'goals': 3.0, 'assists': 0.0},
#  'Hugo Bueno': {'goals': 0.0, 'assists': 0.1},
#  'Santiago Bueno': {'goals': 0.0, 'assists': 0.05},
#  'Adam Buksa': {'goals': 0.0, 'assists': 0.0},
#  'Marius Bülter': {'goals': 3.0, 'assists': 0.0},
#  'Cristian Buonaiuto': {'goals': 0.0, 'assists': 0.0},
#  'Facundo Buonanotte': {'goals': 0.0, 'assists': 0.0},
#  'Alessandro Buongiorno': {'goals': 0.0, 'assists': 0.0},
#  'Delano Burgzorg': {'goals': 0.0, 'assists': 0.43},
#  'Jonathan Burkardt': {'goals': 1.0, 'assists': 0.34},
#  'Oliver Burke': {'goals': 2.0, 'assists': 0.0},
#  'Dan Burn': {'goals': 0.0, 'assists': 0.0},
#  'Maxime Busi': {'goals': 0.0, 'assists': 0.15},
#  'Sergio Busquets': {'goals': 0.0, 'assists': 0.07},
#  'Aurélio Buta': {'goals': 2.0, 'assists': 0.0},
#  'Marcin Bu?ka': {'goals': 0.0, 'assists': 0.0},
#  'Jamie Bynoe-Gittens': {'goals': 3.0, 'assists': 0.0},
#  'Juan Cabal': {'goals': 0.0, 'assists': 0.0},
#  'Rémy Cabella': {'goals': 4.0, 'assists': 0.45},
#  'Jimmy Cabot': {'goals': 0.0, 'assists': 0.18},
#  'Leandro Cabrera': {'goals': 0.0, 'assists': 0.0},
#  'Liberato Cacace': {'goals': 0.0, 'assists': 0.0},
#  'Anthony Caci': {'goals': 1.0, 'assists': 0.08},
#  'Cafú': {'goals': 0.0, 'assists': 0.0},
#  'Moisés Caicedo': {'goals': 1.0, 'assists': 0.05},
#  'Tom Cairney': {'goals': 0.0, 'assists': 0.0},
#  'Jens Cajuste': {'goals': 1.0, 'assists': 0.11},
#  'Cala': {'goals': 0.0, 'assists': 0.0},
#  'Davide Calabria': {'goals': 1.0, 'assists': 0.18},
#  'Mattia Caldara': {'goals': 0.0, 'assists': 0.0},
#  'Luca Caldirola': {'goals': 0.0, 'assists': 0.0},
#  'Fernando Calero': {'goals': 0.0, 'assists': 0.0},
#  'Duje ?aleta-Car': {'goals': 0.0, 'assists': 0.0},
#  'Hakan Çalhanoðlu': {'goals': 2.0, 'assists': 0.29},
#  'Kerim Calhanoglu': {'goals': 0.0, 'assists': 0.0},
#  'Daniel Caligiuri': {'goals': 1.0, 'assists': 0.0},
#  'Alexander Callens': {'goals': 0.0, 'assists': 0.0},
#  'Dominic Calvert-Lewin': {'goals': 1.0, 'assists': 0.0},
#  'Mahdi Camara': {'goals': 0.0, 'assists': 0.0},
#  'Mohamed Camara': {'goals': 0.0, 'assists': 0.13},
#  'Ousmane Camara': {'goals': 0.0, 'assists': 0.0},
#  'Eduardo Camavinga': {'goals': 0.0, 'assists': 0.1},
#  'Nicolò Cambiaghi': {'goals': 2.0, 'assists': 0.17},
#  'Andrea Cambiaso': {'goals': 0.0, 'assists': 0.16},
#  'Axel Camblan': {'goals': 0.0, 'assists': 0.0},
#  'Sergio Camello': {'goals': 5.0, 'assists': 0.19},
#  'Chem Campbell': {'goals': 0.0, 'assists': 0.0},
#  'Emre Can': {'goals': 0.0, 'assists': 0.0},
#  'Sergio Canales': {'goals': 3.0, 'assists': 0.06},
#  'Matteo Cancellieri': {'goals': 0.0, 'assists': 0.0},
#  'João Cancelo': {'goals': 2.0, 'assists': 0.74},
#  'Antonio Candreva': {'goals': 2.0, 'assists': 0.06},
#  'Thomas Cannon': {'goals': 0.0, 'assists': 0.0},
#  'Sergi Canós': {'goals': 0.0, 'assists': 0.0},
#  'Ander Capa': {'goals': 0.0, 'assists': 0.0},
#  'Pierrick Capelle': {'goals': 0.0, 'assists': 0.22},
#  'Étienne Capoue': {'goals': 0.0, 'assists': 0.0},
#  'Gianluca Caprari': {'goals': 4.0, 'assists': 0.07},
#  'Francesco Caputo': {'goals': 2.0, 'assists': 0.31},
#  'Maxence Caqueret': {'goals': 1.0, 'assists': 0.18},
#  'Andrea Carboni': {'goals': 0.0, 'assists': 0.0},
#  'Valentin Carboni': {'goals': 0.0, 'assists': 0.0},
#  'Isaac Carcelen': {'goals': 0.0, 'assists': 0.0},
#  'Irvin Cardona': {'goals': 0.0, 'assists': 0.0},
#  'Igor Carioca': {'goals': 0.0, 'assists': 0.0},
#  'Carlos': {'goals': 4.0, 'assists': 0.15},
#  'Diego Carlos': {'goals': 0.0, 'assists': 0.0},
#  'Juan Carlos': {'goals': 0.0, 'assists': 0.0},
#  'José Carlos Lazo': {'goals': 1.0, 'assists': 0.0},
#  'Carmona': {'goals': 3.0, 'assists': 0.17},
#  'Marco Carnesecchi': {'goals': 0.0, 'assists': 0.0},
#  'Yannick Carrasco': {'goals': 1.0, 'assists': 0.0},
#  'Dani Carvajal': {'goals': 0.0, 'assists': 0.08},
#  'Fabio Carvalho': {'goals': 2.0, 'assists': 0.0},
#  'Matis Carvalho': {'goals': 0.0, 'assists': 0.0},
#  'William Carvalho': {'goals': 2.0, 'assists': 0.07},
#  'Nicolò Casale': {'goals': 1.0, 'assists': 0.07},
#  'Casemiro': {'goals': 2.0, 'assists': 0.22},
#  'Matty Cash': {'goals': 0.0, 'assists': 0.0},
#  'Timothy Castagne': {'goals': 1.0, 'assists': 0.1},
#  'Michele Castagnetti': {'goals': 0.0, 'assists': 0.0},
#  'Koen Casteels': {'goals': 0.0, 'assists': 0.05},
#  'Valentín Castellanos': {'goals': 4.0, 'assists': 0.0},
#  'Jean-Charles Castelletto': {'goals': 0.0, 'assists': 0.0},
#  'Samu Castillejo': {'goals': 3.0, 'assists': 0.0},
#  'Jonny Castro': {'goals': 0.0, 'assists': 0.0},
#  'Gaetano Castrovilli': {'goals': 0.0, 'assists': 0.0},
#  'Danilo Cataldi': {'goals': 0.0, 'assists': 0.06},
#  'Catena': {'goals': 1.0, 'assists': 0.05},
#  'Yoann Cathline': {'goals': 1.0, 'assists': 0.16},
#  'Maximiliano Caufriez': {'goals': 0.0, 'assists': 0.0},
#  'Edinson Cavani': {'goals': 5.0, 'assists': 0.1},
#  'Dani Ceballos': {'goals': 0.0, 'assists': 0.16},
#  'Federico Ceccherini': {'goals': 1.0, 'assists': 0.0},
#  'Assan Ceesay': {'goals': 3.0, 'assists': 0.0},
#  'Emil Ceide': {'goals': 0.0, 'assists': 0.0},
#  'Zeki Çelik': {'goals': 0.0, 'assists': 0.0},
#  'Fabien Centonze': {'goals': 0.0, 'assists': 0.0},
#  'Franco Cervi': {'goals': 0.0, 'assists': 0.14},
#  'Julio César Enciso': {'goals': 0.0, 'assists': 0.0},
#  'Leonardo César Jardim': {'goals': 0.0, 'assists': 0.0},
#  'Julian Chabot': {'goals': 0.0, 'assists': 0.19},
#  'Florian Chabrolle': {'goals': 0.0, 'assists': 0.0},
#  'El Chadaille Bitshiabu': {'goals': 0.0, 'assists': 0.0},
#  'Fares Chaïbi': {'goals': 4.0, 'assists': 0.26},
#  'Nathaniel Chalobah': {'goals': 0.0, 'assists': 0.0},
#  'Trevoh Chalobah': {'goals': 0.0, 'assists': 0.0},
#  'Calum Chambers': {'goals': 0.0, 'assists': 0.0},
#  'Timothy Chandler': {'goals': 0.0, 'assists': 0.0},
#  'Gaëtan Charbonnier': {'goals': 1.0, 'assists': 0.0},
#  'Brendan Chardonnet': {'goals': 0.0, 'assists': 0.0},
#  'Xavier Chavalerin': {'goals': 2.0, 'assists': 0.13},
#  'Pep Chavarría': {'goals': 0.0, 'assists': 0.0},
#  'Rayan Cherki': {'goals': 2.0, 'assists': 0.39},
#  'Ilyes Cheti': {'goals': 0.0, 'assists': 0.0},
#  'Lucas Chevalier': {'goals': 0.0, 'assists': 0.0},
#  'Fabio Chiarodia': {'goals': 0.0, 'assists': 0.0},
#  'Federico Chiesa': {'goals': 0.0, 'assists': 0.74},
#  'Ben Chilwell': {'goals': 1.0, 'assists': 0.2},
#  'Vlad Chiriche?': {'goals': 0.0, 'assists': 0.0},
#  'Pedro Chirivella': {'goals': 0.0, 'assists': 0.06},
#  'Joris Chotard': {'goals': 0.0, 'assists': 0.07},
#  'Andreas Christensen': {'goals': 0.0, 'assists': 0.13},
#  'Oliver Christensen': {'goals': 0.0, 'assists': 0.0},
#  'Ryan Christie': {'goals': 1.0, 'assists': 0.0},
#  'Carney Chukwuemeka': {'goals': 0.0, 'assists': 0.0},
#  'Samuel Chukwueze': {'goals': 1.0, 'assists': 0.18},
#  'Darko Churlinov': {'goals': 0.0, 'assists': 0.0},
#  'Víctor Chust': {'goals': 1.0, 'assists': 0.0},
#  'Tolga Ciðerci': {'goals': 0.0, 'assists': 0.0},
#  'Yanis Cimignani': {'goals': 0.0, 'assists': 0.0},
#  'Daniel Ciofani': {'goals': 3.0, 'assists': 0.0},
#  'Tio Cipot': {'goals': 0.0, 'assists': 0.0},
#  'Pathé Ciss': {'goals': 1.0, 'assists': 0.0},
#  'Souleymane Cissé': {'goals': 0.0, 'assists': 0.0},
#  'Patrick Ciurria': {'goals': 3.0, 'assists': 0.29},
#  'Bobby Clark': {'goals': 0.0, 'assists': 0.0},
#  'Alexis Claude-Maurice': {'goals': 2.0, 'assists': 0.4},
#  'Jonathan Clauss': {'goals': 1.0, 'assists': 0.5},
#  'Carlos Clerc': {'goals': 0.0, 'assists': 0.08},
#  'Nathaniel Clyne': {'goals': 0.0, 'assists': 0.0},
#  'Conor Coady': {'goals': 1.0, 'assists': 0.05},
#  'Marcus Coco': {'goals': 1.0, 'assists': 0.0},
#  'Alexandre Coeff': {'goals': 0.0, 'assists': 0.15},
#  'Jack Colback': {'goals': 0.0, 'assists': 0.0},
#  'Séamus Coleman': {'goals': 0.0, 'assists': 0.0},
#  'David ?olina': {'goals': 1.0, 'assists': 0.0},
#  'Álex Collado': {'goals': 1.0, 'assists': 0.17},
#  'Diego Collado': {'goals': 0.0, 'assists': 0.0},
#  'Omar Colley': {'goals': 1.0, 'assists': 0.0},
#  'Nathan Collins': {'goals': 0.0, 'assists': 0.0},
#  'Lorenzo Colombo': {'goals': 4.0, 'assists': 0.18},
#  'Andrea Colpani': {'goals': 2.0, 'assists': 0.0},
#  'Levi Colwill': {'goals': 0.0, 'assists': 0.0},
#  'Kingsley Coman': {'goals': 4.0, 'assists': 0.36},
#  'Eray Cömert': {'goals': 1.0, 'assists': 0.0},
#  'Santi Comesaña': {'goals': 1.0, 'assists': 0.0},
#  'Andrea Consigli': {'goals': 0.0, 'assists': 0.0},
#  'Abdu Conté': {'goals': 1.0, 'assists': 0.11},
#  'Andrea Conti': {'goals': 0.0, 'assists': 0.0},
#  'Lewis Cook': {'goals': 0.0, 'assists': 0.12},
#  'Steve Cook': {'goals': 0.0, 'assists': 0.0},
#  'Liam Cooper': {'goals': 1.0, 'assists': 0.0},
#  'Copete': {'goals': 0.0, 'assists': 0.0},
#  'Diego Coppola': {'goals': 0.0, 'assists': 0.0},
#  'Francis Coquelin': {'goals': 1.0, 'assists': 0.0},
#  'Sébastien Corchia': {'goals': 0.0, 'assists': 0.17},
#  'Maxwel Cornet': {'goals': 0.0, 'assists': 0.0},
#  'Jesús Corona': {'goals': 0.0, 'assists': 0.0},
#  'Ángel Correa': {'goals': 5.0, 'assists': 0.0},
#  'Joaquín Correa': {'goals': 3.0, 'assists': 0.21},
#  'Thierry Correia': {'goals': 0.0, 'assists': 0.0},
#  'Alessandro Cortinovis': {'goals': 0.0, 'assists': 0.0},
#  'Danny da Costa': {'goals': 0.0, 'assists': 0.15},
#  'David Pereira da Costa': {'goals': 1.0, 'assists': 0.22},
#  'Diego Costa': {'goals': 0.0, 'assists': 0.0},
#  'Jaume Costa': {'goals': 0.0, 'assists': 0.06},
#  'Logan Costa': {'goals': 0.0, 'assists': 0.0},
#  'Nuno da Costa': {'goals': 3.0, 'assists': 0.08},
#  'Samu Costa': {'goals': 1.0, 'assists': 0.0},
#  'Benoît Costil': {'goals': 0.0, 'assists': 0.0},
#  'Vladimír Coufal': {'goals': 0.0, 'assists': 0.0},
#  'Lassana Coulibaly': {'goals': 1.0, 'assists': 0.11},
#  'Tanguy Coulibaly': {'goals': 0.0, 'assists': 0.0},
#  'Thibaut Courtois': {'goals': 0.0, 'assists': 0.0},
#  'Mathieu Coutadeur': {'goals': 0.0, 'assists': 0.0},
#  'Philippe Coutinho': {'goals': 0.0, 'assists': 0.0},
#  'Yan Couto': {'goals': 0.0, 'assists': 0.13},
#  'Conor Coventry': {'goals': 0.0, 'assists': 0.0},
#  'Nicolas Cozza': {'goals': 2.0, 'assists': 0.07},
#  'Aaron Cresswell': {'goals': 0.0, 'assists': 0.0},
#  'Bryan Cristante': {'goals': 1.0, 'assists': 0.0},
#  'Domen ?rnigoj': {'goals': 0.0, 'assists': 0.0},
#  'Juan Cruz Armada': {'goals': 0.0, 'assists': 0.0},
#  'Juan Cruz': {'goals': 1.0, 'assists': 0.0},
#  'Juan Cuadrado': {'goals': 0.0, 'assists': 0.25},
#  'Marc Cucurella': {'goals': 0.0, 'assists': 0.13},
#  'Jorge Cuenca': {'goals': 0.0, 'assists': 0.0},
#  'Braian Cufré': {'goals': 0.0, 'assists': 0.0},
#  'Mickaël Cuisance': {'goals': 0.0, 'assists': 0.0},
#  'Matheus Cunha': {'goals': 0.0, 'assists': 0.48},
#  'Curro': {'goals': 0.0, 'assists': 0.0},
#  "Marco D'Alessandro": {'goals': 0.0, 'assists': 0.0},
#  "Danilo D'Ambrosio": {'goals': 0.0, 'assists': 0.0},
#  "Luca D'Andrea": {'goals': 0.0, 'assists': 0.29},
#  'Damien Da Silva': {'goals': 0.0, 'assists': 0.0},
#  'Moanes Dabbur': {'goals': 5.0, 'assists': 0.0},
#  'Colin Dagba': {'goals': 0.0, 'assists': 0.0},
#  'Finn Dahmen': {'goals': 0.0, 'assists': 0.0},
#  'Mahmoud Dahoud': {'goals': 0.0, 'assists': 0.0},
#  'Patson Daka': {'goals': 3.0, 'assists': 0.38},
#  'Thijs Dallinga': {'goals': 7.0, 'assists': 0.07},
#  'Diogo Dalot': {'goals': 0.0, 'assists': 0.14},
#  'Muhammed Damar': {'goals': 0.0, 'assists': 0.0},
#  'Mikkel Damsgaard': {'goals': 0.0, 'assists': 0.0},
#  'Flavius Daniliuc': {'goals': 0.0, 'assists': 0.09},
#  'Danilo': {'goals': 2.0, 'assists': 0.1},
#  'Arnaut Danjuma': {'goals': 2.0, 'assists': 0.0},
#  'Kevin Danso': {'goals': 1.0, 'assists': 0.05},
#  'Dante': {'goals': 1.0, 'assists': 0.05},
#  'Márton Dárdai': {'goals': 0.0, 'assists': 0.0},
#  'Sergi Darder': {'goals': 2.0, 'assists': 0.05},
#  'Achraf Dari': {'goals': 1.0, 'assists': 0.0},
#  'Vladimír Darida': {'goals': 0.0, 'assists': 0.0},
#  'Matteo Darmian': {'goals': 1.0, 'assists': 0.18},
#  'Josh Dasilva': {'goals': 3.0, 'assists': 0.18},
#  'Jonathan David': {'goals': 12.0, 'assists': 0.21},
#  'Alphonso Davies': {'goals': 0.0, 'assists': 0.13},
#  'Ben Davies': {'goals': 2.0, 'assists': 0.06},
#  'Tom Davies': {'goals': 0.0, 'assists': 0.0},
#  'Pawe? Dawidowicz': {'goals': 1.0, 'assists': 0.0},
#  'Craig Dawson': {'goals': 1.0, 'assists': 0.0},
#  'Kevin De Bruyne': {'goals': 3.0, 'assists': 0.62},
#  'Charles De Ketelaere': {'goals': 0.0, 'assists': 0.13},
#  'Manuel De Luca': {'goals': 0.0, 'assists': 0.0},
#  'Rodrigo De Paul': {'goals': 1.0, 'assists': 0.21},
#  'Mattia De Sciglio': {'goals': 0.0, 'assists': 0.0},
#  'Lorenzo De Silvestri': {'goals': 0.0, 'assists': 0.0},
#  'Thibault De Smet': {'goals': 0.0, 'assists': 0.13},
#  'Koni De Winter': {'goals': 0.0, 'assists': 0.0},
#  'Grégoire Defrel': {'goals': 1.0, 'assists': 0.0},
#  'Duccio Degli Innocenti': {'goals': 0.0, 'assists': 0.0},
#  'Brecht Dejaegere': {'goals': 4.0, 'assists': 0.08},
#  'Romain Del Castillo': {'goals': 4.0, 'assists': 0.44},
#  'Alberto Del Moral': {'goals': 0.0, 'assists': 0.0},
#  'Thomas Delaine': {'goals': 0.0, 'assists': 0.13},
#  'Thomas Delaney': {'goals': 0.0, 'assists': 0.0},
#  'Sacha Delaye': {'goals': 1.0, 'assists': 0.0},
#  'Fran Delgado': {'goals': 0.0, 'assists': 0.0},
#  'Andy Delort': {'goals': 6.0, 'assists': 0.11},
#  'Karamoko Dembele': {'goals': 0.0, 'assists': 0.0},
#  'Moussa Dembélé': {'goals': 2.0, 'assists': 0.0},
#  'Ousmane Dembélé': {'goals': 5.0, 'assists': 0.41},
#  'Siriki Dembélé': {'goals': 0.0, 'assists': 0.0},
#  'Merih Demiral': {'goals': 1.0, 'assists': 0.0},
#  'Kerem Demirbay': {'goals': 3.0, 'assists': 0.3},
#  'Ermedin Demirovi?': {'goals': 7.0, 'assists': 0.12},
#  'Diego Demme': {'goals': 0.0, 'assists': 0.0},
#  'Sepp van den Berg': {'goals': 0.0, 'assists': 0.0},
#  'Branco van den Boomen': {'goals': 5.0, 'assists': 0.33},
#  'Leander Dendoncker': {'goals': 0.0, 'assists': 0.0},
#  'Emmanuel Dennis': {'goals': 1.0, 'assists': 0.22},
#  'Fabio Depaoli': {'goals': 2.0, 'assists': 0.15},
#  'Kastriot Dermaku': {'goals': 0.0, 'assists': 0.0},
#  'Halil Derviþoðlu': {'goals': 0.0, 'assists': 0.0},
#  'Rémy Descamps': {'goals': 0.0, 'assists': 0.0},
#  'Mikkel Desler': {'goals': 0.0, 'assists': 0.07},
#  'Cyriel Dessers': {'goals': 3.0, 'assists': 0.0},
#  'Sergiño Dest': {'goals': 0.0, 'assists': 0.0},
#  'Mattia Destro': {'goals': 1.0, 'assists': 0.0},
#  'Gerard Deulofeu': {'goals': 2.0, 'assists': 0.44},
#  'Kiernan Dewsbury-Hall': {'goals': 2.0, 'assists': 0.12},
#  'Samuel Di Carmine': {'goals': 0.0, 'assists': 0.0},
#  'Federico Di Francesco': {'goals': 1.0, 'assists': 0.16},
#  'Michele Di Gregorio': {'goals': 0.0, 'assists': 0.0},
#  'Giovanni Di Lorenzo': {'goals': 1.0, 'assists': 0.14},
#  'Ángel Di María': {'goals': 3.0, 'assists': 0.29},
#  'Boulaye Dia': {'goals': 8.0, 'assists': 0.25},
#  'Moussa Diaby': {'goals': 7.0, 'assists': 0.16},
#  'Mouctar Diakhaby': {'goals': 2.0, 'assists': 0.0},
#  'Bafodé Diakité': {'goals': 0.0, 'assists': 0.0},
#  'Ibrahim Diakité': {'goals': 0.0, 'assists': 0.0},
#  'Abdou Diallo': {'goals': 1.0, 'assists': 0.0},
#  'Baila Diallo': {'goals': 0.0, 'assists': 0.0},
#  'Habib Diallo': {'goals': 10.0, 'assists': 0.0},
#  'Ibrahima Diallo': {'goals': 0.0, 'assists': 0.0},
#  'Ismael Diallo': {'goals': 0.0, 'assists': 0.0},
#  'Mamady Diarra': {'goals': 0.0, 'assists': 0.0},
#  'Mouhamadou Diarra': {'goals': 0.0, 'assists': 0.0},
#  'Moussa Diarra': {'goals': 0.0, 'assists': 0.09},
#  'Stéphane Diarra': {'goals': 1.0, 'assists': 0.0},
#  'Youba Diarra': {'goals': 0.0, 'assists': 0.0},
#  'Rúben Dias': {'goals': 0.0, 'assists': 0.0},
#  'Krépin Diatta': {'goals': 2.0, 'assists': 0.13},
#  'Mory Diaw': {'goals': 0.0, 'assists': 0.0},
#  'Brahim Díaz': {'goals': 4.0, 'assists': 0.26},
#  'Luis Díaz': {'goals': 3.0, 'assists': 0.29},
#  'Justin Diehl': {'goals': 0.0, 'assists': 0.0},
#  'Bamba Dieng': {'goals': 1.0, 'assists': 0.0},
#  'Eric Dier': {'goals': 2.0, 'assists': 0.0},
#  'Florian Dietz': {'goals': 1.0, 'assists': 0.0},
#  'Lucas Digne': {'goals': 1.0, 'assists': 0.0},
#  'Federico Dimarco': {'goals': 3.0, 'assists': 0.06},
#  'Stole Dimitrievski': {'goals': 0.0, 'assists': 0.0},
#  'Junior Dina Ebimbe': {'goals': 2.0, 'assists': 0.11},
#  'Tristan Dingomé': {'goals': 0.0, 'assists': 0.0},
#  'Eren Dinkçi': {'goals': 0.0, 'assists': 0.0},
#  'Sinaly Diomande': {'goals': 0.0, 'assists': 0.0},
#  'Lois Diony': {'goals': 1.0, 'assists': 0.0},
#  'Issa Diop': {'goals': 1.0, 'assists': 0.0},
#  'Sofiane Diop': {'goals': 2.0, 'assists': 0.4},
#  'Yehvann Diouf': {'goals': 0.0, 'assists': 0.0},
#  'Axel Disasi': {'goals': 2.0, 'assists': 0.14},
#  'Malcom Abdulai Ares Djalo': {'goals': 0.0, 'assists': 0.0},
#  'Tiago Djaló': {'goals': 2.0, 'assists': 0.0},
#  'Djené': {'goals': 0.0, 'assists': 0.0},
#  'Moussa Djenepo': {'goals': 0.0, 'assists': 0.16},
#  'Koffi Djidji': {'goals': 1.0, 'assists': 0.0},
#  'Alexander Djiku': {'goals': 1.0, 'assists': 0.1},
#  'Berat Djimsiti': {'goals': 0.0, 'assists': 0.0},
#  'Moussa Djitte': {'goals': 0.0, 'assists': 0.0},
#  'Marko Dmitrovi?': {'goals': 0.0, 'assists': 0.0},
#  'Alan Do Marcolino': {'goals': 0.0, 'assists': 0.0},
#  'Ben Doak': {'goals': 0.0, 'assists': 0.0},
#  'Ritsu Doan': {'goals': 2.0, 'assists': 0.18},
#  'Dodô': {'goals': 0.0, 'assists': 0.08},
#  'Danilho Doekhi': {'goals': 4.0, 'assists': 0.09},
#  'Matt Doherty': {'goals': 1.0, 'assists': 0.0},
#  'Josh Doig': {'goals': 2.0, 'assists': 0.29},
#  'Jeremy Doku': {'goals': 0.0, 'assists': 0.0},
#  'Kasper Dolberg': {'goals': 0.0, 'assists': 0.45},
#  'Carlos Dominguez': {'goals': 0.0, 'assists': 0.0},
#  'Nicolás Domínguez': {'goals': 1.0, 'assists': 0.14},
#  'John Donald': {'goals': 0.0, 'assists': 0.0},
#  'Giulio Donati': {'goals': 0.0, 'assists': 0.0},
#  'Kyliane Dong': {'goals': 0.0, 'assists': 0.0},
#  'Gianluigi Donnarumma': {'goals': 0.0, 'assists': 0.0},
#  'Niklas Dorsch': {'goals': 0.0, 'assists': 0.0},
#  'Gabriel Dos Santos': {'goals': 2.0, 'assists': 0.0},
#  'Jodel Dossou': {'goals': 1.0, 'assists': 0.0},
#  'Lohann Doucet': {'goals': 0.0, 'assists': 0.0},
#  'Abdoulaye Doucouré': {'goals': 0.0, 'assists': 0.0},
#  'Cheick Doucouré': {'goals': 0.0, 'assists': 0.11},
#  'Ckene Doucouré': {'goals': 0.0, 'assists': 1.67},
#  'Désiré Doué': {'goals': 3.0, 'assists': 0.13},
#  'Guela Doué': {'goals': 0.0, 'assists': 0.0},
#  'Ismaël Doukouré': {'goals': 1.0, 'assists': 0.0},
#  'Kamory Doumbia': {'goals': 2.0, 'assists': 0.2},
#  'Souleyman Doumbia': {'goals': 0.0, 'assists': 0.0},
#  'Flynn Downes': {'goals': 0.0, 'assists': 0.0},
#  'Bart?omiej Dr?gowski': {'goals': 0.0, 'assists': 0.0},
#  'Cody Drameh': {'goals': 0.0, 'assists': 0.0},
#  'Dion Drena Beljo': {'goals': 0.0, 'assists': 0.0},
#  'Dominick Drexler': {'goals': 2.0, 'assists': 0.32},
#  'Domingos Duarte': {'goals': 0.0, 'assists': 0.11},
#  'Marvin Ducksch': {'goals': 4.0, 'assists': 0.27},
#  'Ondrej Duda': {'goals': 0.0, 'assists': 0.0},
#  'Shane Duffy': {'goals': 0.0, 'assists': 0.0},
#  'Rémy Dugimont': {'goals': 0.0, 'assists': 0.83},
#  'Denzel Dumfries': {'goals': 1.0, 'assists': 0.15},
#  'Alfred Duncan': {'goals': 0.0, 'assists': 0.0},
#  'Lewis Dunk': {'goals': 0.0, 'assists': 0.0},
#  'Maxime Dupé': {'goals': 0.0, 'assists': 0.0},
#  'Jhon Durán': {'goals': 0.0, 'assists': 0.0},
#  'Pablo Durán': {'goals': 0.0, 'assists': 0.0},
#  'Hugo Duro': {'goals': 1.0, 'assists': 0.0},
#  'Jean-Kevin Duverne': {'goals': 0.0, 'assists': 0.0},
#  'Paulo Dybala': {'goals': 8.0, 'assists': 0.46},
#  'Edin D?eko': {'goals': 7.0, 'assists': 0.21},
#  'Malcolm Ebiowei': {'goals': 0.0, 'assists': 0.0},
#  'Festy Ebosele': {'goals': 0.0, 'assists': 0.0},
#  'Enzo Ebosse': {'goals': 0.0, 'assists': 0.0},
#  'Tyronne Ebuehi': {'goals': 1.0, 'assists': 0.11},
#  'Ederson': {'goals': 0.0, 'assists': 0.05},
#  'Éderson': {'goals': 1.0, 'assists': 0.0},
#  'Odsonne Édouard': {'goals': 3.0, 'assists': 0.17},
#  'Samuel Edozie': {'goals': 0.0, 'assists': 0.0},
#  'Maximilian Eggestein': {'goals': 0.0, 'assists': 0.13},
#  'Lilian Egloff': {'goals': 0.0, 'assists': 0.0},
#  'Íñigo Eguaras': {'goals': 1.0, 'assists': 0.14},
#  'Kingsley Ehizibue': {'goals': 1.0, 'assists': 0.0},
#  'Chidera Ejuke': {'goals': 0.0, 'assists': 0.34},
#  'Albin Ekdal': {'goals': 0.0, 'assists': 0.15},
#  'Hugo Ekitike': {'goals': 3.0, 'assists': 0.37},
#  'Emmanuel Ekong': {'goals': 0.0, 'assists': 0.0},
#  'Anthony Elanga': {'goals': 0.0, 'assists': 0.23},
#  'Alberth Elis': {'goals': 0.0, 'assists': 0.0},
#  'Mikael Ellertsson': {'goals': 0.0, 'assists': 0.0},
#  'Harvey Elliott': {'goals': 1.0, 'assists': 0.08},
#  'Elif Elmas': {'goals': 5.0, 'assists': 0.11},
#  'Mohamed Elneny': {'goals': 0.0, 'assists': 0.0},
#  'Aritz Elustondo': {'goals': 0.0, 'assists': 0.09},
#  'Nico Elvedi': {'goals': 2.0, 'assists': 0.0},
#  'Rodrigo Ely': {'goals': 0.0, 'assists': 0.0},
#  'Sepe Elye Wahi': {'goals': 7.0, 'assists': 0.06},
#  'Mohamed Elyounoussi': {'goals': 0.0, 'assists': 0.06},
#  'Adri Embarba': {'goals': 1.0, 'assists': 0.34},
#  'Breel Embolo': {'goals': 12.0, 'assists': 0.12},
#  'Emerson': {'goals': 1.0, 'assists': 0.08},
#  'Youssef En-Nesyri': {'goals': 3.0, 'assists': 0.0},
#  'Wataru Endo': {'goals': 3.0, 'assists': 0.05},
#  'Arne Engels': {'goals': 0.0, 'assists': 0.43},
#  'Christian Eriksen': {'goals': 1.0, 'assists': 0.42},
#  'Martin Erlic': {'goals': 0.0, 'assists': 0.0},
#  'Gonzalo Escalante': {'goals': 2.0, 'assists': 0.16},
#  'Sergio Escudero': {'goals': 0.0, 'assists': 0.0},
#  'Alfonso Espino': {'goals': 0.0, 'assists': 0.15},
#  'Bernardo Espinosa': {'goals': 0.0, 'assists': 0.11},
#  'Salvatore Esposito': {'goals': 0.0, 'assists': 0.0},
#  'Maxime Estève': {'goals': 0.0, 'assists': 0.0},
#  'Pervis Estupiñán': {'goals': 0.0, 'assists': 0.21},
#  'Jonny Evans': {'goals': 0.0, 'assists': 0.0},
#  'Edu Expósito': {'goals': 2.0, 'assists': 0.19},
#  'Eberechi Eze': {'goals': 3.0, 'assists': 0.17},
#  'Nicolás Ezequiel Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Abdessamad Ezzalzouli': {'goals': 0.0, 'assists': 0.31},
#  '?ukasz Fabia?ski': {'goals': 0.0, 'assists': 0.0},
#  'Fabinho': {'goals': 0.0, 'assists': 0.0},
#  'Fábio': {'goals': 0.0, 'assists': 0.0},
#  'Noah Fadiga': {'goals': 1.0, 'assists': 0.0},
#  'Wout Faes': {'goals': 0.0, 'assists': 0.0},
#  'Nicolò Fagioli': {'goals': 2.0, 'assists': 0.32},
#  'Ralf Fährmann': {'goals': 0.0, 'assists': 0.0},
#  'Romain Faivre': {'goals': 0.0, 'assists': 0.3},
#  'Radamel Falcao': {'goals': 2.0, 'assists': 0.0},
#  'Wladimiro Falcone': {'goals': 0.0, 'assists': 0.0},
#  'Fali': {'goals': 0.0, 'assists': 0.0},
#  'Mamadou Fall': {'goals': 0.0, 'assists': 0.0},
#  'Davide Faraoni': {'goals': 0.0, 'assists': 0.38},
#  'Ansu Fati': {'goals': 3.0, 'assists': 0.35},
#  'Khalil Fayad': {'goals': 0.0, 'assists': 0.43},
#  'Cheikh Faye': {'goals': 0.0, 'assists': 0.0},
#  'Federico Fazio': {'goals': 1.0, 'assists': 0.0},
#  'Jacopo Fazzini': {'goals': 0.0, 'assists': 0.0},
#  'Zouhair Feddal': {'goals': 0.0, 'assists': 0.0},
#  'Nabil Fekir': {'goals': 2.0, 'assists': 0.23},
#  'Felipe': {'goals': 0.0, 'assists': 0.0},
#  'Luiz Felipe': {'goals': 0.0, 'assists': 0.0},
#  'João Félix': {'goals': 5.0, 'assists': 0.42},
#  'Ohis Felix Uduokhai': {'goals': 0.0, 'assists': 0.1},
#  'Kiko Femenía': {'goals': 0.0, 'assists': 0.0},
#  'Evan Ferguson': {'goals': 3.0, 'assists': 0.77},
#  'Lewis Ferguson': {'goals': 3.0, 'assists': 0.0},
#  'Bruno Fernandes': {'goals': 5.0, 'assists': 0.19},
#  'Edimilson Fernandes': {'goals': 0.0, 'assists': 0.14},
#  'Aitor Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Álex Fernández': {'goals': 3.0, 'assists': 0.0},
#  'Álvaro Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Carlos Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Enzo Fernández': {'goals': 0.0, 'assists': 0.5},
#  'Federico Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Joaquín Fernández': {'goals': 1.0, 'assists': 0.0},
#  'Mateo Fernández': {'goals': 0.0, 'assists': 0.0},
#  'Fernando': {'goals': 0.0, 'assists': 0.0},
#  'Alex Ferrari': {'goals': 0.0, 'assists': 0.0},
#  'Salvador Ferrer': {'goals': 0.0, 'assists': 0.0},
#  'Jordan Ferri': {'goals': 0.0, 'assists': 0.12},
#  'Fidel': {'goals': 0.0, 'assists': 0.22},
#  'Karol Fila': {'goals': 0.0, 'assists': 0.0},
#  'Roberto Firmino': {'goals': 7.0, 'assists': 0.29},
#  'Junior Firpo': {'goals': 0.0, 'assists': 0.0},
#  'Kilian Fischer': {'goals': 0.0, 'assists': 0.0},
#  'Mark Flekken': {'goals': 0.0, 'assists': 0.0},
#  'Florian Flick': {'goals': 0.0, 'assists': 0.0},
#  'Alexis Flips': {'goals': 2.0, 'assists': 0.27},
#  'Alessandro Florenzi': {'goals': 0.0, 'assists': 0.0},
#  'Phil Foden': {'goals': 7.0, 'assists': 0.34},
#  'Datro Fofana': {'goals': 0.0, 'assists': 0.0},
#  'Seko Fofana': {'goals': 3.0, 'assists': 0.15},
#  'Wesley Fofana': {'goals': 0.0, 'assists': 0.0},
#  'Yahia Fofana': {'goals': 0.0, 'assists': 0.0},
#  'Youssouf Fofana': {'goals': 1.0, 'assists': 0.05},
#  'Thomas Foket': {'goals': 0.0, 'assists': 0.0},
#  'José Fonte': {'goals': 1.0, 'assists': 0.0},
#  'Pablo Fornals': {'goals': 1.0, 'assists': 0.0},
#  'Emil Forsberg': {'goals': 2.0, 'assists': 0.24},
#  'Adam Forshaw': {'goals': 0.0, 'assists': 0.0},
#  'Fraser Forster': {'goals': 0.0, 'assists': 0.0},
#  'Philipp Förster': {'goals': 2.0, 'assists': 0.52},
#  'Steven Fortes': {'goals': 0.0, 'assists': 0.0},
#  'Timothy Fosu-Mensah': {'goals': 0.0, 'assists': 0.0},
#  'Dimitri Foulquier': {'goals': 0.0, 'assists': 0.14},
#  'Juan Foyth': {'goals': 1.0, 'assists': 0.0},
#  'Raphael Framberger': {'goals': 0.0, 'assists': 0.0},
#  'Tyrese Francois': {'goals': 0.0, 'assists': 0.0},
#  'Bartol Franji?': {'goals': 0.0, 'assists': 0.4},
#  'Przemys?aw Frankowski': {'goals': 2.0, 'assists': 0.11},
#  'Ryan Fraser': {'goals': 0.0, 'assists': 0.0},
#  'Davide Frattesi': {'goals': 5.0, 'assists': 0.0},
#  'Fred': {'goals': 2.0, 'assists': 0.0},
#  'Ryan Fredericks': {'goals': 0.0, 'assists': 0.0},
#  'Iván Fresneda': {'goals': 0.0, 'assists': 0.0},
#  'Remo Freuler': {'goals': 0.0, 'assists': 0.0},
#  'Michael Frey': {'goals': 0.0, 'assists': 0.38},
#  'Marco Friedl': {'goals': 0.0, 'assists': 0.0},
#  'Marvin Friedrich': {'goals': 1.0, 'assists': 0.0},
#  'Jeremie Frimpong': {'goals': 5.0, 'assists': 0.22},
#  'Chris Führich': {'goals': 4.0, 'assists': 0.0},
#  'Angelo Fulgini': {'goals': 0.0, 'assists': 0.17},
#  'Niclas Füllkrug': {'goals': 13.0, 'assists': 0.16},
#  'Matteo Gabbia': {'goals': 0.0, 'assists': 0.0},
#  'Manolo Gabbiadini': {'goals': 4.0, 'assists': 0.08},
#  'Gianluca Gaetano': {'goals': 0.0, 'assists': 2.5},
#  'Roberto Gagliardini': {'goals': 0.0, 'assists': 0.0},
#  'Adolfo Gaich': {'goals': 0.0, 'assists': 0.0},
#  'Cody Gakpo': {'goals': 0.0, 'assists': 0.0},
#  'Javi Galán': {'goals': 0.0, 'assists': 0.05},
#  'Iñigo Ruiz de Galarreta': {'goals': 0.0, 'assists': 0.0},
#  'Pablo Galdames Millán': {'goals': 0.0, 'assists': 0.0},
#  'Conor Gallagher': {'goals': 1.0, 'assists': 0.11},
#  'Antonino Gallo': {'goals': 0.0, 'assists': 0.07},
#  'Gauthier Gallon': {'goals': 0.0, 'assists': 0.0},
#  'Cristian Gamboa': {'goals': 0.0, 'assists': 0.0},
#  'Kévin Gameiro': {'goals': 7.0, 'assists': 0.0},
#  'Idrissa Gana Gueye': {'goals': 0.0, 'assists': 0.07},
#  'Ignatius Ganago': {'goals': 3.0, 'assists': 0.33},
#  "Silvère Ganvoula M'Boussy": {'goals': 0.0, 'assists': 0.0},
#  'Aleix García': {'goals': 0.0, 'assists': 0.2},
#  'Álvaro García': {'goals': 4.0, 'assists': 0.12},
#  'Borja García': {'goals': 1.0, 'assists': 0.0},
#  'Carlos García': {'goals': 0.0, 'assists': 3.33},
#  'Dani García': {'goals': 0.0, 'assists': 0.15},
#  'David García': {'goals': 1.0, 'assists': 0.0},
#  'Eric García': {'goals': 1.0, 'assists': 0.0},
#  'Francisco Garcia': {'goals': 0.0, 'assists': 0.1},
#  'Raúl García': {'goals': 1.0, 'assists': 0.32},
#  'Rubén García': {'goals': 1.0, 'assists': 0.29},
#  'Unai García': {'goals': 0.0, 'assists': 0.07},
#  'Alejandro Garnacho': {'goals': 1.0, 'assists': 0.56},
#  'James Garner': {'goals': 0.0, 'assists': 0.0},
#  'Felix Garreta': {'goals': 0.0, 'assists': 0.0},
#  'Sékou Gassama': {'goals': 0.0, 'assists': 0.0},
#  'Johan Gastien': {'goals': 2.0, 'assists': 0.11},
#  'Federico Gatti': {'goals': 0.0, 'assists': 0.0},
#  'Gavi': {'goals': 1.0, 'assists': 0.14},
#  'Paulo Gazzaniga': {'goals': 0.0, 'assists': 0.0},
#  'David de Gea': {'goals': 0.0, 'assists': 0.0},
#  'Dennis Geiger': {'goals': 1.0, 'assists': 0.15},
#  'Joe Gelhardt': {'goals': 0.0, 'assists': 0.83},
#  'Valentin Gendrey': {'goals': 0.0, 'assists': 0.0},
#  'Denis Genreau': {'goals': 0.0, 'assists': 0.0},
#  'Yannick Gerhardt': {'goals': 4.0, 'assists': 0.09},
#  'Valère Germain': {'goals': 2.0, 'assists': 0.0},
#  'Gerson': {'goals': 2.0, 'assists': 0.0},
#  'Ismaël Gharbi': {'goals': 0.0, 'assists': 0.0},
#  'Paolo Ghiglione': {'goals': 0.0, 'assists': 0.19},
#  'Saman Ghoddos': {'goals': 0.0, 'assists': 0.0},
#  'Faouzi Ghoulam': {'goals': 0.0, 'assists': 0.0},
#  'Morgan Gibbs-White': {'goals': 2.0, 'assists': 0.23},
#  'Niko Gießelmann': {'goals': 0.0, 'assists': 0.19},
#  'Samuel Gigot': {'goals': 2.0, 'assists': 0.14},
#  'Rafa? Gikiewicz': {'goals': 0.0, 'assists': 0.0},
#  'Óscar Gil': {'goals': 0.0, 'assists': 0.07},
#  'Mario Gila': {'goals': 0.0, 'assists': 0.0},
#  'Billy Gilmour': {'goals': 0.0, 'assists': 0.0},
#  'Álvaro Giménez': {'goals': 0.0, 'assists': 0.0},
#  'Gvidas Gineitis': {'goals': 0.0, 'assists': 0.0},
#  'Matthias Ginter': {'goals': 3.0, 'assists': 0.05},
#  'Andrei Girotto': {'goals': 1.0, 'assists': 0.05},
#  'Olivier Giroud': {'goals': 7.0, 'assists': 0.27},
#  'Serge Gnabry': {'goals': 9.0, 'assists': 0.33},
#  'Degnand Gnonto': {'goals': 2.0, 'assists': 0.13},
#  'Ben Godfrey': {'goals': 0.0, 'assists': 0.0},
#  'Pierluigi Gollini': {'goals': 0.0, 'assists': 0.0},
#  'Aleksandr Golovin': {'goals': 5.0, 'assists': 0.34},
#  'André Gomes': {'goals': 1.0, 'assists': 0.0},
#  'Angel Gomes': {'goals': 2.0, 'assists': 0.16},
#  'João Gomes': {'goals': 1.0, 'assists': 0.0},
#  'Toti Gomes': {'goals': 0.0, 'assists': 0.0},
#  'Dani Gómez': {'goals': 0.0, 'assists': 0.0},
#  'Joe Gomez': {'goals': 0.0, 'assists': 0.0},
#  'Maxi Gómez': {'goals': 0.0, 'assists': 0.0},
#  'Moi Gómez': {'goals': 1.0, 'assists': 0.11},
#  'Papu Gómez': {'goals': 0.0, 'assists': 0.14},
#  'Sergi Gómez': {'goals': 0.0, 'assists': 0.0},
#  'Sergio Gómez': {'goals': 0.0, 'assists': 0.83},
#  'Maxime Gonalons': {'goals': 1.0, 'assists': 0.0},
#  'Diego González': {'goals': 0.0, 'assists': 0.0},
#  'Édgar González': {'goals': 0.0, 'assists': 0.0},
#  'Giovanni González': {'goals': 0.0, 'assists': 0.34},
#  'Joan Gonzàlez': {'goals': 1.0, 'assists': 0.17},
#  'Nicolás González': {'goals': 4.0, 'assists': 0.2},
#  'Oumar Gonzalez': {'goals': 0.0, 'assists': 0.0},
#  'Roberto González': {'goals': 0.0, 'assists': 0.0},
#  'Jacek Góralski': {'goals': 0.0, 'assists': 0.0},
#  'Anthony Gordon': {'goals': 3.0, 'assists': 0.0},
#  'Leon Goretzka': {'goals': 3.0, 'assists': 0.09},
#  'Andoni Gorosabel': {'goals': 0.0, 'assists': 0.0},
#  'Robin Gosens': {'goals': 1.0, 'assists': 0.0},
#  'Mario Götze': {'goals': 2.0, 'assists': 0.06},
#  'Amine Gouiri': {'goals': 9.0, 'assists': 0.07},
#  'Jeffrey Gouweleeuw': {'goals': 0.0, 'assists': 0.0},
#  'Jonathan Gradit': {'goals': 1.0, 'assists': 0.13},
#  'José Gragera': {'goals': 0.0, 'assists': 0.0},
#  'Alberto Grassi': {'goals': 0.0, 'assists': 0.0},
#  'Ryan Gravenberch': {'goals': 0.0, 'assists': 0.0},
#  'Andrew Gravillon': {'goals': 0.0, 'assists': 0.0},
#  'Demarai Gray': {'goals': 3.0, 'assists': 0.05},
#  'Adrian Grbi?': {'goals': 0.0, 'assists': 0.0},
#  'Ivo Grbi?': {'goals': 0.0, 'assists': 0.0},
#  'Jack Grealish': {'goals': 2.0, 'assists': 0.26},
#  'Sam Greenwood': {'goals': 1.0, 'assists': 0.57},
#  'Michael Gregoritsch': {'goals': 7.0, 'assists': 0.19},
#  'Leo Greiml': {'goals': 0.0, 'assists': 0.0},
#  'Clément Grenier': {'goals': 0.0, 'assists': 0.0},
#  'Antoine Griezmann': {'goals': 6.0, 'assists': 0.43},
#  'Vincenzo Grifo': {'goals': 11.0, 'assists': 0.21},
#  'Lennart Grill': {'goals': 0.0, 'assists': 0.0},
#  'Christian Groß': {'goals': 1.0, 'assists': 0.0},
#  'Pascal Groß': {'goals': 6.0, 'assists': 0.15},
#  'Brajan Gruda': {'goals': 0.0, 'assists': 0.0},
#  'Ilia Gruev': {'goals': 0.0, 'assists': 0.0},
#  'Carlos Gruezo': {'goals': 0.0, 'assists': 0.0},
#  'Vicente Guaita': {'goals': 0.0, 'assists': 0.0},
#  'Andrés Guardado': {'goals': 1.0, 'assists': 0.0},
#  'Sergi Guardiola': {'goals': 1.0, 'assists': 0.0},
#  'Nemanja Gudelj': {'goals': 2.0, 'assists': 0.0},
#  'Gabriel Gudmundsson': {'goals': 0.0, 'assists': 0.0},
#  'Gonçalo Guedes': {'goals': 1.0, 'assists': 0.13},
#  'Axel Gueguin': {'goals': 0.0, 'assists': 0.0},
#  'Marc Guéhi': {'goals': 0.0, 'assists': 0.0},
#  'Mattéo Guendouzi': {'goals': 1.0, 'assists': 0.19},
#  'Raphaël Guerreiro': {'goals': 1.0, 'assists': 0.39},
#  'Evann Guessand': {'goals': 2.0, 'assists': 0.19},
#  'Ander Guevara': {'goals': 0.0, 'assists': 0.0},
#  'Pape Gueye': {'goals': 1.0, 'assists': 0.71},
#  'Josuha Guilavogui': {'goals': 1.0, 'assists': 0.0},
#  'Frederic Guilbert': {'goals': 0.0, 'assists': 0.0},
#  'Hugo Guillamón': {'goals': 1.0, 'assists': 0.31},
#  'Bruno Guimarães': {'goals': 3.0, 'assists': 0.19},
#  'Sehrou Guirassy': {'goals': 6.0, 'assists': 0.0},
#  'Rafik Guitane': {'goals': 0.0, 'assists': 0.0},
#  'Péter Gulácsi': {'goals': 0.0, 'assists': 0.0},
#  'Manuel Gulde': {'goals': 0.0, 'assists': 0.0},
#  'Gerard Gumbau': {'goals': 0.0, 'assists': 0.21},
#  'Robert Gumny': {'goals': 1.0, 'assists': 0.07},
#  'Ýlkay Gündoðan': {'goals': 2.0, 'assists': 0.14},
#  'Christian Günter': {'goals': 0.0, 'assists': 0.1},
#  'Koray Günter': {'goals': 1.0, 'assists': 0.0},
#  'Gorka Guruzeta': {'goals': 5.0, 'assists': 0.0},
#  'Malo Gusto': {'goals': 0.0, 'assists': 0.06},
#  'Raúl Guti': {'goals': 0.0, 'assists': 0.0},
#  'Miguel Gutiérrez': {'goals': 0.0, 'assists': 0.12},
#  'Jo\x9ako Gvardiol': {'goals': 0.0, 'assists': 0.0},
#  'Darko Gyabi': {'goals': 0.0, 'assists': 0.0},
#  'Emmanuel Gyasi': {'goals': 1.0, 'assists': 0.0},
#  'Norbert Gyömbér': {'goals': 0.0, 'assists': 0.0},
#  'Christian Gytkjær': {'goals': 1.0, 'assists': 0.0},
#  'Erling Haaland': {'goals': 25.0, 'assists': 0.16},
#  'Nicolas Haas': {'goals': 1.0, 'assists': 0.0},
#  'Janik Haberer': {'goals': 5.0, 'assists': 0.07},
#  ...}

# %% [markdown]
# ### 18. Groups players into different age groups
#
# Create a new variable named players_by_age_group that groups players into different age groups. The variable should be a dictionary where the keys are the age group names (e.g., 'Under 20', '20-25', '26-30', 'Over 30'), and the values are lists of players belonging to that age group. Each player should be represented as a dictionary containing the keys player, nation, position, squad, competition, and age.
#
# The age group is considered as:
#
# Under 20 i.e <20
# 20-25 i.e 20 <= age <= 25
# 26-30 i.e 26 <= age <=30
# Over 30 i.e >30
# Example of expected output:
#
# <code>
# {
#     'Under 20': [
#         {'player': 'Player A', 'nation': 'Country A', 'position': 'Position A', 'squad': 'Squad A', 'competition': 'Competition A', 'age': 19},
#         {'player': 'Player B', 'nation': 'Country B', 'position': 'Position B', 'squad': 'Squad B', 'competition': 'Competition B', 'age': 18},
#         ...
#     ],
#     '20-25': [
#         {'player': 'Player C', 'nation': 'Country C', 'position': 'Position C', 'squad': 'Squad C', 'competition': 'Competition C', 'age': 22},
#         {'player': 'Player D', 'nation': 'Country D', 'position': 'Position D', 'squad': 'Squad D', 'competition': 'Competition D', 'age': 25},
#         ...
#     ],
#     ...
# }
# </code>

# %%
players_by_age_group = {
    'Under 20': [],
    '20-25': [],
    '26-30': [],
    'Over 30': []
}

for player in players:
    name, nation, pos, squad, comp, age, *rest = player
    age = int(age)
    if age < 20:
        age_group = 'Under 20'
    elif 20 <= age <= 25:
        age_group = '20-25'
    elif 26 <= age <= 30:
        age_group = '26-30'
    else:
        age_group = 'Over 30'

    players_by_age_group[age_group].append({
        'player': name,
        'nation': nation,
        'position': pos,
        'squad': squad,
        'competition': comp,
        'age': age
    })


players_by_age_group
# Out:
# {'Under 20': [{'player': 'Matthis Abline',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Matthis Abline',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Martin Adeline',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Amar Ahmed',
#    'nation': 'SWE',
#    'position': 'FW',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Mohamed Ali Cho',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Carlos Álvarez',
#    'nation': 'ESP',
#    'position': 'FW',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Taïryk Arconte',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Roberto Arroyo',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Sanoussy Ba',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'RB Leipzig',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Stefan Bajcetic',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Tommaso Baldanzi',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Alejandro Balde',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Carlos Baleba',
#    'nation': 'CMR',
#    'position': 'MF',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Pablo Barrios',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Julius Beck',
#    'nation': 'DEN',
#    'position': 'MF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 17},
#   {'player': 'Jude Bellingham',
#    'nation': 'ENG',
#    'position': 'MF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Jeanöel Belocian',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Eliesse Ben Seghir',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Salim Ben Seghir',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Owen Bevan',
#    'nation': 'WAL',
#    'position': 'DF',
#    'squad': 'Bournemouth',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Tom Bischof',
#    'nation': 'GER',
#    'position': 'MFFW',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Warren Bondo',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Yvandro Borges Sanches',
#    'nation': 'LUX',
#    'position': 'FWMF',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Badredine Bouanani',
#    'nation': 'ALG',
#    'position': 'FWMF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Franci Bouebari',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Wassim Boullif',
#    'nation': 'ESP',
#    'position': 'DFMF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Facundo Buonanotte',
#    'nation': 'ARG',
#    'position': 'MFFW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Jamie Bynoe-Gittens',
#    'nation': 'ENG',
#    'position': 'FWMF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Ousmane Camara',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Axel Camblan',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Valentin Carboni',
#    'nation': 'ITA',
#    'position': 'MFFW',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 17},
#   {'player': 'Julio César Enciso',
#    'nation': 'PAR',
#    'position': 'FWMF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'El Chadaille Bitshiabu',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Rayan Cherki',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Fabio Chiarodia',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Werder Bremen',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Carney Chukwuemeka',
#    'nation': 'ENG',
#    'position': 'MFFW',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Tio Cipot',
#    'nation': 'SVN',
#    'position': 'DFFW',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Bobby Clark',
#    'nation': 'ENG',
#    'position': 'MF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Levi Colwill',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Diego Coppola',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': "Luca D'Andrea",
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Muhammed Damar',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Duccio Degli Innocenti',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Karamoko Dembele',
#    'nation': 'SCO',
#    'position': 'FWMF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Ibrahim Diakité',
#    'nation': 'GUI',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Mouhamadou Diarra',
#    'nation': 'SEN',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Justin Diehl',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Köln',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Ben Doak',
#    'nation': 'SCO',
#    'position': 'FW',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 17},
#   {'player': 'Kyliane Dong',
#    'nation': 'FRA',
#    'position': 'DFMF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Désiré Doué',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Ismaël Doukouré',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Kamory Doumbia',
#    'nation': 'MLI',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Jhon Durán',
#    'nation': 'COL',
#    'position': 'FW',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Malcolm Ebiowei',
#    'nation': 'ENG',
#    'position': 'MFFW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Harvey Elliott',
#    'nation': 'ENG',
#    'position': 'MFFW',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Arne Engels',
#    'nation': 'BEL',
#    'position': 'MF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Khalil Fayad',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Jacopo Fazzini',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Evan Ferguson',
#    'nation': 'IRL',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Mateo Fernández',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Iván Fresneda',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Alejandro Garnacho',
#    'nation': 'ESP',
#    'position': 'FW',
#    'squad': 'Manchester Utd',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Felix Garreta',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Gavi',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Ismaël Gharbi',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Gvidas Gineitis',
#    'nation': 'LTU',
#    'position': 'MF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Degnand Gnonto',
#    'nation': 'ITA',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Brajan Gruda',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Axel Gueguin',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Malo Gusto',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Darko Gyabi',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Jaouen Hadjam',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Lewis Hall',
#    'nation': 'ENG',
#    'position': 'DFMF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Mathis Hamdi',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Luke Harris',
#    'nation': 'WAL',
#    'position': 'MFFW',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 17},
#   {'player': 'Omar El Hilali',
#    'nation': 'MAR',
#    'position': 'DFMF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Ilyes Housni',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Omari Hutchinson',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Arijon Ibrahimovi?',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Rareþ Ilie',
#    'nation': 'ROU',
#    'position': 'MFFW',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Samuel Iling-Junior',
#    'nation': 'ENG',
#    'position': 'DFMF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Emirhan Ýlkhan',
#    'nation': 'TUR',
#    'position': 'MF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Kaiky',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Kévin Keben Biakolo',
#    'nation': 'CMR',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Check Keita',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Anthony Khelifa',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Luca Koleosho',
#    'nation': 'CAN',
#    'position': 'FWDF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Sael Kumbedi',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Rémy Labeau Lascary',
#    'nation': 'GLP',
#    'position': 'FWMF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Juan Larios',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Roméo Lavia',
#    'nation': 'BEL',
#    'position': 'MF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Marko Lazeti?',
#    'nation': 'SRB',
#    'position': 'FW',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Paolo Lebas',
#    'nation': 'POR',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Félix Lemaréchal',
#    'nation': 'CIV',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Dexter Lembikisa',
#    'nation': 'JAM',
#    'position': 'DF',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Rico Lewis',
#    'nation': 'ENG',
#    'position': 'DFMF',
#    'squad': 'Manchester City',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Soungoutou Magassa',
#    'nation': 'MLI',
#    'position': 'MF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Lorenzo Malagrida',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Pablo Marín',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Marquinhos',
#    'nation': 'BRA',
#    'position': 'MF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Arnau Martinez',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Roger Martínez',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Aïman Maurer',
#    'nation': 'MAR',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Christian Mawissa',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Diego Méndez',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Antoine Mendy',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Marko Milovanovi?',
#    'nation': 'SRB',
#    'position': 'FW',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Fabio Miretti',
#    'nation': 'ITA',
#    'position': 'MFFW',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Daniele Montevago',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Andrew Moran',
#    'nation': 'IRL',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Cristhian Mosquera',
#    'nation': 'COL',
#    'position': 'DF',
#    'squad': 'Valencia',
#    'competition': 'La Liga',
#    'age': 18},
#   {'player': 'Youssoufa Moukoko',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Divin Mubama',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'West Ham',
#    'competition': 'Premier League',
#    'age': 18},
#   {'player': 'Pablo Muñoz',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Jamal Musiala',
#    'nation': 'GER',
#    'position': 'MFFW',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Luca Netz',
#    'nation': 'GER',
#    'position': 'DFFW',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Ethan Nwaneri',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 15},
#   {'player': 'Wilson Odobert',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Tim Oermann',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'David Ozoh',
#    'nation': nan,
#    'position': 'FW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 17},
#   {'player': 'Simone Pafundi',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 16},
#   {'player': 'Kevin Paredes',
#    'nation': 'USA',
#    'position': 'MFFW',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Brayann Pereira',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Isaac Price',
#    'nation': 'NIR',
#    'position': 'MF',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 19},
#   {'player': 'Mehdi Puch Herrantz',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Niklas Pyyhtiä',
#    'nation': 'FIN',
#    'position': 'MF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Joshua Quarshie',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Chadi Riad',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Joel Roca',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 17},
#   {'player': 'Luka Romero',
#    'nation': 'ARG',
#    'position': 'FW',
#    'squad': 'Lazio',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Tom Rothe',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Dikeni Salifou',
#    'nation': 'TOG',
#    'position': 'MF',
#    'squad': 'Werder Bremen',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Sidi Sané',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Giorgio Scalvini',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Vivaldo Semedo',
#    'nation': 'POR',
#    'position': 'FW',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Matìas Soulé',
#    'nation': 'ARG',
#    'position': 'MFDF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Moussa Soumano',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Ibrahim Sulemana',
#    'nation': 'GHA',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Williot Swedberg',
#    'nation': 'SWE',
#    'position': 'MF',
#    'squad': 'Celta Vigo',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Benjamin Tahirovic',
#    'nation': 'SWE',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Mathys Tel',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Alexis Tibidi',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Umut Tohumcu',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Pablo Torre',
#    'nation': 'ESP',
#    'position': 'FW',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'David Torres',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Valladolid',
#    'competition': 'La Liga',
#    'age': 19},
#   {'player': 'Souleymane Touré',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Souleymane Touré',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 19},
#   {'player': 'Chimuanya Ugochukwu',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 18},
#   {'player': 'Lauren Ulrich',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Renato Veiga',
#    'nation': 'POR',
#    'position': 'DF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Gabriel Vidovic',
#    'nation': 'CRO',
#    'position': 'FW',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Samuele Vignato',
#    'nation': 'ITA',
#    'position': 'FWMF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 18},
#   {'player': 'Cristian Volpato',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 19},
#   {'player': 'Robert Wagner',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Freiburg',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Paul Wanner',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Nelson Weiper',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 17},
#   {'player': 'Marcel Wenig',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Florian Wirtz',
#    'nation': 'GER',
#    'position': 'FWMF',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 19},
#   {'player': 'Leny Yoro',
#    'nation': 'FRA',
#    'position': 'DFMF',
#    'squad': 'Lille',
#    'competition': 'Ligue 1',
#    'age': 17},
#   {'player': 'Warren Zaire-Emery',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 16},
#   {'player': 'Aaron Zehnter',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 18},
#   {'player': 'Nathan Zeze',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 17}],
#  '20-25': [{'player': 'Brenden Aaronson',
#    'nation': 'USA',
#    'position': 'MFFW',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Himad Abdelli',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Salis Abdul Samed',
#    'nation': 'GHA',
#    'position': 'MF',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Abner',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Zakaria Aboukhlal',
#    'nation': 'MAR',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Tammy Abraham',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Mohamed Achi',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Tyler Adams',
#    'nation': 'USA',
#    'position': 'MF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Tosin Adarabioyo',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Karim Adeyemi',
#    'nation': 'GER',
#    'position': 'FWMF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Amine Adli',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Yacine Adli',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Felix Afena-Gyan',
#    'nation': 'GHA',
#    'position': 'FWMF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Emmanuel Agbadou',
#    'nation': 'CIV',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Lucien Agoume',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Felix Agu',
#    'nation': 'GER',
#    'position': 'DFFW',
#    'squad': 'Werder Bremen',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Kevin Agudelo',
#    'nation': 'COL',
#    'position': 'MFFW',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Naouirou Ahamada',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Naouirou Ahamada',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Stuttgart',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Rayan Aït Nouri',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Emanuel Aiwum',
#    'nation': 'AUT',
#    'position': 'DF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Kristoffer Ajer',
#    'nation': 'NOR',
#    'position': 'DF',
#    'squad': 'Brentford',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Sergio Akieme',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Maghnes Akliouche',
#    'nation': 'FRA',
#    'position': 'MFDF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Paul Akouokou',
#    'nation': 'CIV',
#    'position': 'MF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Tomás Alarcón',
#    'nation': 'CHI',
#    'position': 'MF',
#    'squad': 'Cádiz',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Carlos Alcaraz',
#    'nation': 'ARG',
#    'position': 'MF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Doðan Alemdar',
#    'nation': 'TUR',
#    'position': 'GK',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Carles Aleñá',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Trent Alexander-Arnold',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Alejandro Alfaro',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Elche',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Ángel Algobia',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Faride Alidou',
#    'nation': 'GER',
#    'position': 'DFMF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Domingos André Ribeiro Almeida',
#    'nation': 'POR',
#    'position': 'MF',
#    'squad': 'Valencia',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Gastón Álvarez',
#    'nation': 'URU',
#    'position': 'DF',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Julián Álvarez',
#    'nation': 'ARG',
#    'position': 'FWMF',
#    'squad': 'Manchester City',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Agustín Álvarez Martínez',
#    'nation': 'URU',
#    'position': 'FWMF',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Kelvin Amian',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Bruno Amione',
#    'nation': 'ARG',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Bruno Amione',
#    'nation': 'ARG',
#    'position': 'DF',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Ethan Ampadu',
#    'nation': 'WAL',
#    'position': 'DFMF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Elliot Anderson',
#    'nation': 'SCO',
#    'position': 'FWMF',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Jaidon Anthony',
#    'nation': 'ENG',
#    'position': 'MFFW',
#    'squad': 'Bournemouth',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Janis Antiste',
#    'nation': 'FRA',
#    'position': 'FW',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Marcos Antônio',
#    'nation': 'BRA',
#    'position': 'MF',
#    'squad': 'Lazio',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Antony',
#    'nation': 'BRA',
#    'position': 'FW',
#    'squad': 'Manchester Utd',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Valentin Antov',
#    'nation': 'BUL',
#    'position': 'DF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Houssem Aouar',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Adil Aouchiche',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Ronald Araújo',
#    'nation': 'URU',
#    'position': 'DF',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Cameron Archer',
#    'nation': 'ENG',
#    'position': 'FWMF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Arthur',
#    'nation': 'BRA',
#    'position': 'FW',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Santiago Arzamendia',
#    'nation': 'PAR',
#    'position': 'MFDF',
#    'squad': 'Cádiz',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Santiago Ascacíbar',
#    'nation': 'ARG',
#    'position': 'MF',
#    'squad': 'Cremonese',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Kristoffer Askildsen',
#    'nation': 'NOR',
#    'position': 'MF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Fisnik Asllani',
#    'nation': 'KVX',
#    'position': 'FWMF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Kristjan Asllani',
#    'nation': 'ALB',
#    'position': 'MF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Lorenz Assignon',
#    'nation': 'TOG',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Taiwo Awoniyi',
#    'nation': 'NGA',
#    'position': 'FW',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Mehmet-Can Aydin',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Ayman Azhil',
#    'nation': 'MAR',
#    'position': 'MF',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Loïc Bade',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Loïc Bade',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Benoît Badiashile',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Benoît Badiashile',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Alex Baena',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Villarreal',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Leon Bailey',
#    'nation': 'JAM',
#    'position': 'FWMF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Brandon Baiye',
#    'nation': 'BEL',
#    'position': 'MF',
#    'squad': 'Clermont Foot',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Nedim Bajrami',
#    'nation': 'ALB',
#    'position': 'MFFW',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Nedim Bajrami',
#    'nation': 'ALB',
#    'position': 'MF',
#    'squad': 'Sassuolo',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Mitchel Bakker',
#    'nation': 'NED',
#    'position': 'MFDF',
#    'squad': 'Leverkusen',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Ridle Baku',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Thierno Balde',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Leonardo Balerdi',
#    'nation': 'ARG',
#    'position': 'DF',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Folarin Balogun',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Lameck Banda',
#    'nation': 'ZAM',
#    'position': 'FWMF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Shandon Baptiste',
#    'nation': 'GRN',
#    'position': 'MF',
#    'squad': 'Brentford',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Bradley Barcola',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Melvin Bard',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Keidi Bare',
#    'nation': 'ALB',
#    'position': 'MF',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Kike Barja',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Osasuna',
#    'competition': 'La Liga',
#    'age': 25},
#   {'player': 'Aymen Barkok',
#    'nation': 'MAR',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Harvey Barnes',
#    'nation': 'ENG',
#    'position': 'MFFW',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Leandro Barreiro Martins',
#    'nation': 'LUX',
#    'position': 'MF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Ander Barrenetxea',
#    'nation': 'ESP',
#    'position': 'FWDF',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'Musa Barrow',
#    'nation': 'GAM',
#    'position': 'FWMF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Alessandro Bastoni',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Maximilian Bauer',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Christoph Baumgartner',
#    'nation': 'AUT',
#    'position': 'MFFW',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Brian Bayeye',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Gavin Bazunu',
#    'nation': 'IRL',
#    'position': 'GK',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Mads Bech Sørensen',
#    'nation': 'DEN',
#    'position': 'DFMF',
#    'squad': 'Brentford',
#    'competition': 'Premier League',
#    'age': 24},
#   {'player': 'Donny van de Beek',
#    'nation': 'NED',
#    'position': 'MF',
#    'squad': 'Manchester Utd',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Yanis Begraoui',
#    'nation': 'FRA',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Alexis Beka Beka',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Armel Bella Kotchap',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Raoul Bellanova',
#    'nation': 'ITA',
#    'position': 'DFMF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Jean-Ricner Bellegarde',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Strasbourg',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Fran Beltrán',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Celta Vigo',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Ismaël Bennacer',
#    'nation': 'ALG',
#    'position': 'MF',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Rodrigo Bentancur',
#    'nation': 'URU',
#    'position': 'MF',
#    'squad': 'Tottenham',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Patrick Berg',
#    'nation': 'NOR',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Mitchell van Bergen',
#    'nation': 'NED',
#    'position': 'FWDF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Mergim Berisha',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Augsburg',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Paul Bernardoni',
#    'nation': 'FRA',
#    'position': 'GK',
#    'squad': 'Angers',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Victor Bernth Kristiansen',
#    'nation': 'DEN',
#    'position': 'DF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Beto',
#    'nation': 'GNB',
#    'position': 'FW',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Alessandro Bianco',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Giulian Biancone',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Jaka Bijol',
#    'nation': 'SVN',
#    'position': 'DF',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'El Bilal Touré',
#    'nation': 'MLI',
#    'position': 'FW',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 21},
#   {'player': 'El Bilal Touré',
#    'nation': 'MLI',
#    'position': 'FW',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Samuele Birindelli',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Veljko Birman?evi?',
#    'nation': 'SRB',
#    'position': 'FWMF',
#    'squad': 'Toulouse',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Kristijan Bistrovi?',
#    'nation': 'CRO',
#    'position': 'MF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Blanco',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Cádiz',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Lautaro Blanco',
#    'nation': 'ARG',
#    'position': 'MFDF',
#    'squad': 'Elche',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Ludovic Blas',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Joaquín Blázquez',
#    'nation': 'ARG',
#    'position': 'GK',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Myron Boadu',
#    'nation': 'NED',
#    'position': 'FW',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Emil Bohinen',
#    'nation': 'NOR',
#    'position': 'MF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Quentin Boisgard',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Lorient',
#    'competition': 'Ligue 1',
#    'age': 25},
#   {'player': 'Federico Bonazzoli',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Sebastiaan Bornauw',
#    'nation': 'BEL',
#    'position': 'DF',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 23},
#   {'player': 'Erik Botheim',
#    'nation': 'NOR',
#    'position': 'FW',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Sven Botman',
#    'nation': 'NED',
#    'position': 'DF',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 23},
#   {'player': 'Kouamé Botué',
#    'nation': 'BFA',
#    'position': 'FWMF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 20},
#   {'player': 'Hicham Boudaoui',
#    'nation': 'ALG',
#    'position': 'MF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ismaëlben Boura',
#    'nation': 'FRA',
#    'position': 'DFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Edoardo Bove',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Jayden Braaf',
#    'nation': 'NED',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 20},
#   {'player': 'Domagoj Bradari?',
#    'nation': 'CRO',
#    'position': 'DF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Bilal Brahimi',
#    'nation': 'ALG',
#    'position': 'FWMF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Juan Brandáriz',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 23},
#   {'player': 'Lilian Brassier',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'James Bree',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Josip Brekalo',
#    'nation': 'CRO',
#    'position': 'FW',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 24},
#   {'player': 'Josip Brekalo',
#    'nation': 'CRO',
#    'position': 'MFFW',
#    'squad': 'Wolfsburg',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Gleison Bremer',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Armando Broja',
#    'nation': 'ALB',
#    'position': 'FW',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Moritz Broschinski',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Lewis Brunt',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Jacob Bruun Larsen',
#    'nation': 'DEN',
#    'position': 'FW',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Andreas Bruus',
#    'nation': 'DEN',
#    'position': 'DFFW',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Bryan',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Tottenham',
#    'competition': 'Premier League',
#    'age': 22},
#   {'player': 'Bryan',
#    'nation': 'ESP',
#    'position': 'DFMF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Lee Buchanan',
#    'nation': 'ENG',
#    'position': 'DFFW',
#    'squad': 'Werder Bremen',
#    'competition': 'Bundesliga',
#    'age': 21},
#   {'player': 'Hugo Bueno',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Santiago Bueno',
#    'nation': 'URU',
#    'position': 'DF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 24},
#   {'player': 'Alessandro Buongiorno',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Torino',
#    'competition': 'Serie A',
#    'age': 23},
#   {'player': 'Delano Burgzorg',
#    'nation': 'NED',
#    'position': 'FWMF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 24},
#   {'player': 'Jonathan Burkardt',
#    'nation': 'GER',
#    'position': 'MFFW',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 22},
#   {'player': 'Oliver Burke',
#    'nation': 'SCO',
#    'position': 'FWMF',
#    'squad': 'Werder Bremen',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Maxime Busi',
#    'nation': 'BEL',
#    'position': 'DF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Marcin Bu?ka',
#    'nation': 'POL',
#    'position': 'GK',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Juan Cabal',
#    'nation': 'COL',
#    'position': 'DF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Liberato Cacace',
#    'nation': 'NZL',
#    'position': 'DF',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Anthony Caci',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Mainz 05',
#    'competition': 'Bundesliga',
#    'age': 25},
#   {'player': 'Moisés Caicedo',
#    'nation': 'ECU',
#    'position': 'MF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 21},
#   {'player': 'Jens Cajuste',
#    'nation': 'SWE',
#    'position': 'MF',
#    'squad': 'Reims',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Kerim Calhanoglu',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 20},
#   {'player': 'Dominic Calvert-Lewin',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 25},
#   {'player': 'Mahdi Camara',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 24},
#   {'player': 'Mohamed Camara',
#    'nation': 'GUI',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 25},
#   {'player': 'Mohamed Camara',
#    'nation': 'MLI',
#    'position': 'MF',
#    'squad': 'Monaco',
#    'competition': 'Ligue 1',
#    'age': 23},
#   {'player': 'Ousmane Camara',
#    'nation': 'GUI',
#    'position': 'FWMF',
#    'squad': 'Auxerre',
#    'competition': 'Ligue 1',
#    'age': 21},
#   {'player': 'Eduardo Camavinga',
#    'nation': 'FRA',
#    'position': 'MFDF',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 20},
#   {'player': 'Nicolò Cambiaghi',
#    'nation': 'ITA',
#    'position': 'FWMF',
#    'squad': 'Empoli',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Andrea Cambiaso',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 22},
#   {'player': 'Sergio Camello',
#    'nation': 'ESP',
#    'position': 'FW',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 22},
#   {'player': 'Chem Campbell',
#    'nation': 'WAL',
#    'position': 'FWMF',
#    'squad': 'Wolves',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Matteo Cancellieri',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Lazio',
#    'competition': 'Serie A',
#    'age': 21},
#   {'player': 'Thomas Cannon',
#    'nation': 'IRL',
#    'position': 'FW',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 20},
#   {'player': 'Maxence Caqueret',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 22},
#   {'player': 'Andrea Carboni',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 22},
# ...
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 32},
#   {'player': 'Fabio Quagliarella',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 40},
#   {'player': 'Ivan Radovanovi?',
#    'nation': 'SRB',
#    'position': 'MFDF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'Antonio Raillo',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Ivan Rakiti?',
#    'nation': 'CRO',
#    'position': 'MF',
#    'squad': 'Sevilla',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Adil Rami',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Troyes',
#    'competition': 'Ligue 1',
#    'age': 37},
#   {'player': 'Sergio Ramos',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Paris S-G',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Aaron Ramsey',
#    'nation': 'WAL',
#    'position': 'MF',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Andrea Ranocchia',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Monza',
#    'competition': 'Serie A',
#    'age': 34},
#   {'player': 'Tim Ream',
#    'nation': 'USA',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 35},
#   {'player': 'Pepe Reina',
#    'nation': 'ESP',
#    'position': 'GK',
#    'squad': 'Villarreal',
#    'competition': 'La Liga',
#    'age': 40},
#   {'player': 'Marco Reus',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Dortmund',
#    'competition': 'Bundesliga',
#    'age': 33},
#   {'player': 'Franck Ribéry',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 39},
#   {'player': 'Manuel Riemann',
#    'nation': 'GER',
#    'position': 'GK',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Tomás Rincón',
#    'nation': 'VEN',
#    'position': 'MF',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 35},
#   {'player': 'Rémy Riou',
#    'nation': 'FRA',
#    'position': 'GK',
#    'squad': 'Lyon',
#    'competition': 'Ligue 1',
#    'age': 35},
#   {'player': 'Matt Ritchie',
#    'nation': 'SCO',
#    'position': 'FW',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Sergi Roberto',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Barcelona',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Sebastian Rode',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Rodrigo',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Leeds United',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Ángel Rodríguez',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 35},
#   {'player': 'Dani Rodríguez',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Mallorca',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Oriol Romeu',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Oriol Romeu',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Cristiano Ronaldo',
#    'nation': 'POR',
#    'position': 'FW',
#    'squad': 'Manchester Utd',
#    'competition': 'Premier League',
#    'age': 38},
#   {'player': 'Salomón Rondón',
#    'nation': 'VEN',
#    'position': 'FW',
#    'squad': 'Everton',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Marten de Roon',
#    'nation': 'NED',
#    'position': 'MF',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Sebastian Rudy',
#    'nation': 'GER',
#    'position': 'MF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Mário Rui',
#    'nation': 'POR',
#    'position': 'DF',
#    'squad': 'Napoli',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Víctor Ruiz',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Betis',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Samuel Sáiz',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 32},
#   {'player': 'Mamadou Sakho',
#    'nation': 'FRA',
#    'position': 'DF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Jacopo Sala',
#    'nation': 'ITA',
#    'position': 'MF',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Salvi',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Alexis Sánchez',
#    'nation': 'CHI',
#    'position': 'FW',
#    'squad': 'Marseille',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Alex Sandro',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Nicola Sansone',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Riccardo Saponara',
#    'nation': 'ITA',
#    'position': 'FW',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Téji Savanier',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Esteban Saveljich',
#    'nation': 'MNE',
#    'position': 'FW',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Stefan Savi?',
#    'nation': 'MNE',
#    'position': 'DF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 32},
#   {'player': 'Fabian Schär',
#    'nation': 'SUI',
#    'position': 'DF',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Kasper Schmeichel',
#    'nation': 'DEN',
#    'position': 'GK',
#    'squad': 'Nice',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Luigi Sepe',
#    'nation': 'ITA',
#    'position': 'GK',
#    'squad': 'Salernitana',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'David Silva',
#    'nation': 'ESP',
#    'position': 'MF',
#    'squad': 'Real Sociedad',
#    'competition': 'La Liga',
#    'age': 37},
#   {'player': 'Thiago Silva',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Chelsea',
#    'competition': 'Premier League',
#    'age': 38},
#   {'player': 'Marco Silvestri',
#    'nation': 'ITA',
#    'position': 'GK',
#    'squad': 'Udinese',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Tobias Sippel',
#    'nation': 'GER',
#    'position': 'GK',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Moussa Sissoko',
#    'nation': 'FRA',
#    'position': 'MF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 33},
#   {'player': '?ukasz Skorupski',
#    'nation': 'POL',
#    'position': 'GK',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Islam Slimani',
#    'nation': 'ALG',
#    'position': 'FW',
#    'squad': 'Brest',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Chris Smalling',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 33},
#   {'player': 'Adam Smith',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Bournemouth',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Cédric Soares',
#    'nation': 'POR',
#    'position': 'DF',
#    'squad': 'Arsenal',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Cédric Soares',
#    'nation': 'POR',
#    'position': 'DF',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Danilo Soares',
#    'nation': 'BRA',
#    'position': 'DF',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Augusto Solari',
#    'nation': 'ARG',
#    'position': 'MFFW',
#    'squad': 'Celta Vigo',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Yann Sommer',
#    'nation': 'SUI',
#    'position': 'GK',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Yann Sommer',
#    'nation': 'SUI',
#    'position': 'GK',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Roberto Soriano',
#    'nation': 'ITA',
#    'position': 'FWMF',
#    'squad': 'Bologna',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Florian Sotoca',
#    'nation': 'FRA',
#    'position': 'MFFW',
#    'squad': 'Lens',
#    'competition': 'Ligue 1',
#    'age': 32},
#   {'player': 'Arnaud Souquet',
#    'nation': 'FRA',
#    'position': 'DFFW',
#    'squad': 'Montpellier',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Dyego Sousa',
#    'nation': 'POR',
#    'position': 'FW',
#    'squad': 'Almería',
#    'competition': 'La Liga',
#    'age': 33},
#   {'player': 'Junior Stanislas',
#    'nation': 'ENG',
#    'position': 'MF',
#    'squad': 'Bournemouth',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Lars Stindl',
#    'nation': 'GER',
#    'position': 'FWMF',
#    'squad': "M'Gladbach",
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Cristhian Stuani',
#    'nation': 'URU',
#    'position': 'FW',
#    'squad': 'Girona',
#    'competition': 'La Liga',
#    'age': 36},
#   {'player': 'Damián Suárez',
#    'nation': 'URU',
#    'position': 'DF',
#    'squad': 'Getafe',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Mario Suárez',
#    'nation': 'ESP',
#    'position': 'DFMF',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 35},
#   {'player': 'Wojciech Szcz?sny',
#    'nation': 'POL',
#    'position': 'GK',
#    'squad': 'Juventus',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Ciprian T?t?ru?anu',
#    'nation': 'ROU',
#    'position': 'GK',
#    'squad': 'Milan',
#    'competition': 'Serie A',
#    'age': 37},
#   {'player': 'Simon Terodde',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Pietro Terracciano',
#    'nation': 'ITA',
#    'position': 'GK',
#    'squad': 'Fiorentina',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Rafael Tolói',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'James Tomkins',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Roberto Torres',
#    'nation': 'ESP',
#    'position': 'FWMF',
#    'squad': 'Osasuna',
#    'competition': 'La Liga',
#    'age': 33},
#   {'player': 'Yoann Touzghar',
#    'nation': 'TUN',
#    'position': 'FW',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 36},
#   {'player': 'Charles Traore',
#    'nation': 'MLI',
#    'position': 'DF',
#    'squad': 'Nantes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Hamari Traoré',
#    'nation': 'MLI',
#    'position': 'DF',
#    'squad': 'Rennes',
#    'competition': 'Ligue 1',
#    'age': 31},
#   {'player': 'Kevin Trapp',
#    'nation': 'GER',
#    'position': 'GK',
#    'squad': 'Eint Frankfurt',
#    'competition': 'Bundesliga',
#    'age': 32},
#   {'player': 'Óscar Trejo',
#    'nation': 'ARG',
#    'position': 'MFFW',
#    'squad': 'Rayo Vallecano',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Manu Trigueros',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Villarreal',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Christopher Trimmel',
#    'nation': 'AUT',
#    'position': 'DF',
#    'squad': 'Union Berlin',
#    'competition': 'Bundesliga',
#    'age': 35},
#   {'player': 'Kieran Trippier',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 32},
#   {'player': 'Alessandro Tuia',
#    'nation': 'ITA',
#    'position': 'DF',
#    'squad': 'Lecce',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Sven Ulreich',
#    'nation': 'GER',
#    'position': 'GK',
#    'squad': 'Bayern Munich',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Mark Uth',
#    'nation': 'GER',
#    'position': 'MFFW',
#    'squad': 'Köln',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Virgil van Dijk',
#    'nation': 'NED',
#    'position': 'DF',
#    'squad': 'Liverpool',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Jamie Vardy',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Leicester City',
#    'competition': 'Premier League',
#    'age': 36},
#   {'player': 'Lucas Vázquez',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Real Madrid',
#    'competition': 'La Liga',
#    'age': 31},
#   {'player': 'Matías Vecino',
#    'nation': 'URU',
#    'position': 'MF',
#    'squad': 'Lazio',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Miguel Veloso',
#    'nation': 'POR',
#    'position': 'MF',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 36},
#   {'player': 'Joël Veltman',
#    'nation': 'NED',
#    'position': 'DF',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Gonzalo Verdú',
#    'nation': 'ESP',
#    'position': 'DF',
#    'squad': 'Elche',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Aleix Vidal',
#    'nation': 'ESP',
#    'position': 'MFFW',
#    'squad': 'Espanyol',
#    'competition': 'La Liga',
#    'age': 33},
#   {'player': 'Kevin Vogt',
#    'nation': 'GER',
#    'position': 'DF',
#    'squad': 'Hoffenheim',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Stefan de Vrij',
#    'nation': 'NED',
#    'position': 'DF',
#    'squad': 'Inter',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Theo Walcott',
#    'nation': 'ENG',
#    'position': 'FWMF',
#    'squad': 'Southampton',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Kyle Walker',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Manchester City',
#    'competition': 'Premier League',
#    'age': 32},
#   {'player': 'Joel Ward',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Crystal Palace',
#    'competition': 'Premier League',
#    'age': 33},
#   {'player': 'Danny Welbeck',
#    'nation': 'ENG',
#    'position': 'FW',
#    'squad': 'Brighton',
#    'competition': 'Premier League',
#    'age': 32},
#   {'player': 'Georginio Wijnaldum',
#    'nation': 'NED',
#    'position': 'MF',
#    'squad': 'Roma',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Willian',
#    'nation': 'BRA',
#    'position': 'FW',
#    'squad': 'Fulham',
#    'competition': 'Premier League',
#    'age': 34},
#   {'player': 'Axel Witsel',
#    'nation': 'BEL',
#    'position': 'DFMF',
#    'squad': 'Atlético Madrid',
#    'competition': 'La Liga',
#    'age': 34},
#   {'player': 'Chris Wood',
#    'nation': 'NZL',
#    'position': 'FW',
#    'squad': 'Newcastle Utd',
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Chris Wood',
#    'nation': 'NZL',
#    'position': 'FW',
#    'squad': "Nott'ham Forest",
#    'competition': 'Premier League',
#    'age': 31},
#   {'player': 'Maya Yoshida',
#    'nation': 'JPN',
#    'position': 'DF',
#    'squad': 'Schalke 04',
#    'competition': 'Bundesliga',
#    'age': 34},
#   {'player': 'Ashley Young',
#    'nation': 'ENG',
#    'position': 'DF',
#    'squad': 'Aston Villa',
#    'competition': 'Premier League',
#    'age': 37},
#   {'player': 'Mohamed Youssouf',
#    'nation': 'COM',
#    'position': 'DF',
#    'squad': 'Ajaccio',
#    'competition': 'Ligue 1',
#    'age': 34},
#   {'player': 'Duván Zapata',
#    'nation': 'COL',
#    'position': 'FW',
#    'squad': 'Atalanta',
#    'competition': 'Serie A',
#    'age': 31},
#   {'player': 'Jeroen Zoet',
#    'nation': 'NED',
#    'position': 'GK',
#    'squad': 'Spezia',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Simon Zoller',
#    'nation': 'GER',
#    'position': 'FW',
#    'squad': 'Bochum',
#    'competition': 'Bundesliga',
#    'age': 31},
#   {'player': 'Milan ?uri?',
#    'nation': 'BIH',
#    'position': 'FW',
#    'squad': 'Hellas Verona',
#    'competition': 'Serie A',
#    'age': 32},
#   {'player': 'Filip ?uri?i?',
#    'nation': 'SRB',
#    'position': 'MFFW',
#    'squad': 'Sampdoria',
#    'competition': 'Serie A',
#    'age': 31}]}
