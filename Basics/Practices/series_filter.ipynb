# %% [markdown]
# # Practicing Series Filtering

# %%
import pandas as pd
# for later visualisation
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.patches import Rectangle

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Age of First Marriage

# %%
age_marriage = pd.read_csv('../../data/age_at_mar.csv', index_col=0).squeeze("columns")  # squeeze erstellt eine Serie
age_marriage.head()
# Out:
# 1    32
# 2    25
# 3    24
# 4    26
# 5    32
# Name: age, dtype: int64

# %%
age_marriage.shape
# Out:
# (5534,)

# %% [markdown]
# #### Histogram of the data

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.histplot(age_marriage, ax=ax)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### Returns of Standard and Poors (1990's)

# %%
sp500 = pd.read_csv('../../data/SP500.csv', index_col=0).squeeze('columns')
sp500.head()
# Out:
# 1   -0.258891
# 2   -0.865031
# 3   -0.980414
# 4    0.450432
# 5   -1.185667
# Name: dat, dtype: float64

# %%
sp500.shape
# Out:
# (2780,)

# %% [markdown]
# #### Histogramm of the data

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.histplot(sp500, ax=ax)
# Out:
# <Axes: xlabel='dat', ylabel='Count'>

# %% [markdown]
# ## Activities

# %% [markdown]
# ### 1. Rename the series
#
# Rename both series with the names specified below, given their variables:
#
# * <code>age_marriage</code>: should be named "Age of First Marriage"
# * <code>sp500</code>: should be named "S&P500 Returns 90s"

# %%
age_marriage.name = "Age of First Marriage"
sp500.name = "S&P500 Returns 90s"

# %% [markdown]
# ### Basic Analysis

# %% [markdown]
# #### 2. What's the maximum Age of Marriage?

# %%
age_marriage.max()
# Out:
# 43

# %% [markdown]
# #### 2. What's the median Age of Marriage?

# %%
age_marriage.median()
# Out:
# 23.0

# %% [markdown]
# #### 3. What's the mminimum Return from S&P500?

# %%
sp500.min()
# Out:
# -7.11274461287603

# %% [markdown]
# ### Simple Selection and Filtering

# %% [markdown]
# #### 5. How many Women marry at age 21?

# %%
age_marriage.loc[age_marriage == 21].shape
# Out:
# (495,)

# %% [markdown]
# #### 6. How many Women marry at 39y/o or older?

# %%
age_marriage.loc[age_marriage >= 39].shape
# Out:
# (39,)

# %% [markdown]
# #### 7. How many positive S&P500 retorns are there?

# %%
sp500.loc[sp500 > 0].shape
# Out:
# (1474,)

# %% [markdown]
# #### 8. How many returns are less or equal than -2?

# %%
sp500.loc[sp500 <= -2].shape
# Out:
# (63,)

# %% [markdown]
# ### Advanced Selection with Boolean Operators

# %% [markdown]
# #### 9. Select all women below 20 or above 39
#
# The segments depicted below:

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.histplot(age_marriage, ax=ax)
ax.add_patch(Rectangle((10, 0), 9, 450, alpha=.3, color='red'))
ax.add_patch(Rectangle((39, 0), 5, 450, alpha=.3, color='red'))

# %%
age_20_39 = age_marriage.loc[(age_marriage < 20) | (age_marriage > 39)]
age_20_39.shape
# Out:
# (1206,)

# %% [markdown]
# #### 10. Select all women whose ages are even and are older than 30 y/o

# %%
age_30_even = age_marriage.loc[(age_marriage > 30) & (age_marriage % 2 == 0)]

# %% [markdown]
# #### 11. Select the S&P500 returns between 1.5 and 3
# The ones depicted below

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.histplot(sp500, ax=ax)
ax.add_patch(Rectangle((1, 0), 1.5, 250, alpha=.3, color='red'))

# %%
sp_15_to_3 = sp500.loc[(sp500 > 1.5) & (sp500 <3)]
